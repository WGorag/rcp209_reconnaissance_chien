# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f2b3195e4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f2b31873dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet50V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet50V2(
    include_top=False,
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.8)(x)
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True,
    min_delta = 0.01
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 302s 608ms/step - loss: 4.0731 - categorical_accuracy: 0.2415 - val_loss: 0.8179 - val_categorical_accuracy: 0.7484
# Epoch 2/25
# 449/449 [==============================] - 269s 599ms/step - loss: 2.5432 - categorical_accuracy: 0.4394 - val_loss: 0.6860 - val_categorical_accuracy: 0.7844
# Epoch 3/25
# 449/449 [==============================] - 269s 599ms/step - loss: 2.2741 - categorical_accuracy: 0.4907 - val_loss: 0.6486 - val_categorical_accuracy: 0.7945
# Epoch 4/25
# 449/449 [==============================] - 269s 598ms/step - loss: 2.1459 - categorical_accuracy: 0.5166 - val_loss: 0.6359 - val_categorical_accuracy: 0.7991
# Epoch 5/25
# 449/449 [==============================] - 269s 600ms/step - loss: 2.0996 - categorical_accuracy: 0.5225 - val_loss: 0.6190 - val_categorical_accuracy: 0.8094
# Epoch 6/25
# 449/449 [==============================] - 269s 599ms/step - loss: 2.0043 - categorical_accuracy: 0.5411 - val_loss: 0.6031 - val_categorical_accuracy: 0.8162
# Epoch 7/25
# 449/449 [==============================] - 268s 597ms/step - loss: 1.9521 - categorical_accuracy: 0.5477 - val_loss: 0.5937 - val_categorical_accuracy: 0.8182
# Epoch 8/25
# 449/449 [==============================] - 269s 598ms/step - loss: 1.8977 - categorical_accuracy: 0.5541 - val_loss: 0.5941 - val_categorical_accuracy: 0.8182
# Epoch 9/25
# 449/449 [==============================] - 268s 596ms/step - loss: 1.8510 - categorical_accuracy: 0.5620 - val_loss: 0.5878 - val_categorical_accuracy: 0.8147
# Epoch 10/25
# 449/449 [==============================] - 269s 599ms/step - loss: 1.8215 - categorical_accuracy: 0.5627 - val_loss: 0.5745 - val_categorical_accuracy: 0.8207
# Epoch 11/25
# 449/449 [==============================] - 268s 596ms/step - loss: 1.7608 - categorical_accuracy: 0.5694 - val_loss: 0.5778 - val_categorical_accuracy: 0.8211
# Epoch 12/25
# 449/449 [==============================] - 268s 598ms/step - loss: 1.7369 - categorical_accuracy: 0.5723 - val_loss: 0.5805 - val_categorical_accuracy: 0.8168
# Epoch 13/25
# 449/449 [==============================] - 268s 596ms/step - loss: 1.6943 - categorical_accuracy: 0.5774 - val_loss: 0.5773 - val_categorical_accuracy: 0.8232
# Epoch 14/25
# 449/449 [==============================] - 269s 598ms/step - loss: 1.6342 - categorical_accuracy: 0.5870 - val_loss: 0.5688 - val_categorical_accuracy: 0.8232
# Epoch 15/25
# 449/449 [==============================] - 268s 597ms/step - loss: 1.6456 - categorical_accuracy: 0.5840 - val_loss: 0.5667 - val_categorical_accuracy: 0.8215

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 445,
#   'faux positif': 96,
#   'precision': 0.822550831792976},
#  'Japanese_spaniel': {'vrai positif': 603,
#   'faux positif': 50,
#   'precision': 0.9234303215926493},
#  'Maltese_dog': {'vrai positif': 880,
#   'faux positif': 207,
#   'precision': 0.8095676172953082},
#  'Pekinese': {'vrai positif': 467,
#   'faux positif': 88,
#   'precision': 0.8414414414414414},
#  'Shih': {'vrai positif': 618,
#   'faux positif': 263,
#   'precision': 0.7014755959137344},
#  'Blenheim_spaniel': {'vrai positif': 698,
#   'faux positif': 73,
#   'precision': 0.9053177691309987},
#  'papillon': {'vrai positif': 691,
#   'faux positif': 52,
#   'precision': 0.9300134589502019},
#  'toy_terrier': {'vrai positif': 440,
#   'faux positif': 95,
#   'precision': 0.822429906542056},
#  'Rhodesian_ridgeback': {'vrai positif': 460,
#   'faux positif': 325,
#   'precision': 0.5859872611464968},
#  'Afghan_hound': {'vrai positif': 860,
#   'faux positif': 49,
#   'precision': 0.9460946094609461},
#  'basset': {'vrai positif': 608,
#   'faux positif': 92,
#   'precision': 0.8685714285714285},
#  'beagle': {'vrai positif': 601,
#   'faux positif': 226,
#   'precision': 0.7267230955259976},
#  'bloodhound': {'vrai positif': 651,
#   'faux positif': 90,
#   'precision': 0.8785425101214575},
#  'bluetick': {'vrai positif': 532,
#   'faux positif': 43,
#   'precision': 0.9252173913043479},
#  'black': {'vrai positif': 437,
#   'faux positif': 59,
#   'precision': 0.8810483870967742},
#  'Walker_hound': {'vrai positif': 349,
#   'faux positif': 194,
#   'precision': 0.6427255985267035},
#  'English_foxhound': {'vrai positif': 422,
#   'faux positif': 178,
#   'precision': 0.7033333333333334},
#  'redbone': {'vrai positif': 314,
#   'faux positif': 85,
#   'precision': 0.7869674185463659},
#  'borzoi': {'vrai positif': 486,
#   'faux positif': 20,
#   'precision': 0.9604743083003953},
#  'Irish_wolfhound': {'vrai positif': 569,
#   'faux positif': 206,
#   'precision': 0.7341935483870968},
#  'Italian_greyhound': {'vrai positif': 524,
#   'faux positif': 112,
#   'precision': 0.8238993710691824},
#  'whippet': {'vrai positif': 515,
#   'faux positif': 88,
#   'precision': 0.8540630182421227},
#  'Ibizan_hound': {'vrai positif': 626,
#   'faux positif': 51,
#   'precision': 0.9246676514032496},
#  'Norwegian_elkhound': {'vrai positif': 708,
#   'faux positif': 67,
#   'precision': 0.9135483870967742},
#  'otterhound': {'vrai positif': 505,
#   'faux positif': 165,
#   'precision': 0.753731343283582},
#  'Saluki': {'vrai positif': 683,
#   'faux positif': 90,
#   'precision': 0.8835705045278137},
#  'Scottish_deerhound': {'vrai positif': 698,
#   'faux positif': 267,
#   'precision': 0.7233160621761658},
#  'Weimaraner': {'vrai positif': 555, 'faux positif': 45, 'precision': 0.925},
#  'Staffordshire_bullterrier': {'vrai positif': 286,
#   'faux positif': 106,
#   'precision': 0.7295918367346939},
#  'American_Staffordshire_terrier': {'vrai positif': 442,
#   'faux positif': 401,
#   'precision': 0.5243179122182681},
#  'Bedlington_terrier': {'vrai positif': 671,
#   'faux positif': 84,
#   'precision': 0.8887417218543047},
#  'Border_terrier': {'vrai positif': 547,
#   'faux positif': 48,
#   'precision': 0.9193277310924369},
#  'Kerry_blue_terrier': {'vrai positif': 640,
#   'faux positif': 69,
#   'precision': 0.9026798307475318},
#  'Irish_terrier': {'vrai positif': 506,
#   'faux positif': 146,
#   'precision': 0.7760736196319018},
#  'Norfolk_terrier': {'vrai positif': 451,
#   'faux positif': 188,
#   'precision': 0.7057902973395931},
#  'Norwich_terrier': {'vrai positif': 501,
#   'faux positif': 160,
#   'precision': 0.7579425113464447},
#  'Yorkshire_terrier': {'vrai positif': 423,
#   'faux positif': 228,
#   'precision': 0.6497695852534562},
#  'wire': {'vrai positif': 399, 'faux positif': 101, 'precision': 0.798},
#  'Lakeland_terrier': {'vrai positif': 462,
#   'faux positif': 190,
#   'precision': 0.7085889570552147},
#  'Sealyham_terrier': {'vrai positif': 718,
#   'faux positif': 102,
#   'precision': 0.875609756097561},
#  'Airedale': {'vrai positif': 577,
#   'faux positif': 85,
#   'precision': 0.8716012084592145},
#  'cairn': {'vrai positif': 630,
#   'faux positif': 244,
#   'precision': 0.7208237986270023},
#  'Australian_terrier': {'vrai positif': 642,
#   'faux positif': 445,
#   'precision': 0.5906163753449862},
#  'Dandie_Dinmont': {'vrai positif': 598,
#   'faux positif': 41,
#   'precision': 0.9358372456964006},
#  'Boston_bull': {'vrai positif': 619,
#   'faux positif': 95,
#   'precision': 0.8669467787114846},
#  'miniature_schnauzer': {'vrai positif': 501,
#   'faux positif': 187,
#   'precision': 0.7281976744186046},
#  'giant_schnauzer': {'vrai positif': 468,
#   'faux positif': 145,
#   'precision': 0.763458401305057},
#  'standard_schnauzer': {'vrai positif': 338,
#   'faux positif': 121,
#   'precision': 0.7363834422657952},
#  'Scotch_terrier': {'vrai positif': 580,
#   'faux positif': 136,
#   'precision': 0.8100558659217877},
#  'Tibetan_terrier': {'vrai positif': 544,
#   'faux positif': 224,
#   'precision': 0.7083333333333334},
#  'silky_terrier': {'vrai positif': 385,
#   'faux positif': 55,
#   'precision': 0.875},
#  'soft': {'vrai positif': 478,
#   'faux positif': 129,
#   'precision': 0.7874794069192751},
#  'West_Highland_white_terrier': {'vrai positif': 559,
#   'faux positif': 58,
#   'precision': 0.9059967585089141},
#  'Lhasa': {'vrai positif': 299,
#   'faux positif': 126,
#   'precision': 0.7035294117647058},
#  'flat': {'vrai positif': 506,
#   'faux positif': 128,
#   'precision': 0.7981072555205048},
#  'curly': {'vrai positif': 405,
#   'faux positif': 87,
#   'precision': 0.823170731707317},
#  'golden_retriever': {'vrai positif': 463,
#   'faux positif': 46,
#   'precision': 0.9096267190569745},
#  'Labrador_retriever': {'vrai positif': 533,
#   'faux positif': 151,
#   'precision': 0.7792397660818714},
#  'Chesapeake_Bay_retriever': {'vrai positif': 544,
#   'faux positif': 161,
#   'precision': 0.7716312056737589},
#  'German_short': {'vrai positif': 450,
#   'faux positif': 41,
#   'precision': 0.9164969450101833},
#  'vizsla': {'vrai positif': 530,
#   'faux positif': 242,
#   'precision': 0.6865284974093264},
#  'English_setter': {'vrai positif': 433,
#   'faux positif': 53,
#   'precision': 0.8909465020576132},
#  'Irish_setter': {'vrai positif': 558,
#   'faux positif': 47,
#   'precision': 0.9223140495867769},
#  'Gordon_setter': {'vrai positif': 529,
#   'faux positif': 36,
#   'precision': 0.9362831858407079},
#  'Brittany_spaniel': {'vrai positif': 369,
#   'faux positif': 55,
#   'precision': 0.8702830188679245},
#  'clumber': {'vrai positif': 526,
#   'faux positif': 98,
#   'precision': 0.842948717948718},
#  'English_springer': {'vrai positif': 551,
#   'faux positif': 162,
#   'precision': 0.7727910238429172},
#  'Welsh_springer_spaniel': {'vrai positif': 498,
#   'faux positif': 188,
#   'precision': 0.7259475218658892},
#  'cocker_spaniel': {'vrai positif': 444,
#   'faux positif': 56,
#   'precision': 0.888},
#  'Sussex_spaniel': {'vrai positif': 525,
#   'faux positif': 22,
#   'precision': 0.9597806215722121},
#  'Irish_water_spaniel': {'vrai positif': 469,
#   'faux positif': 88,
#   'precision': 0.8420107719928187},
#  'kuvasz': {'vrai positif': 434,
#   'faux positif': 59,
#   'precision': 0.8803245436105477},
#  'schipperke': {'vrai positif': 487,
#   'faux positif': 62,
#   'precision': 0.8870673952641166},
#  'groenendael': {'vrai positif': 513,
#   'faux positif': 135,
#   'precision': 0.7916666666666666},
#  'malinois': {'vrai positif': 453,
#   'faux positif': 107,
#   'precision': 0.8089285714285714},
#  'briard': {'vrai positif': 374,
#   'faux positif': 43,
#   'precision': 0.8968824940047961},
#  'kelpie': {'vrai positif': 350,
#   'faux positif': 144,
#   'precision': 0.708502024291498},
#  'komondor': {'vrai positif': 564,
#   'faux positif': 45,
#   'precision': 0.9261083743842364},
#  'Old_English_sheepdog': {'vrai positif': 590,
#   'faux positif': 43,
#   'precision': 0.9320695102685624},
#  'Shetland_sheepdog': {'vrai positif': 369,
#   'faux positif': 54,
#   'precision': 0.8723404255319149},
#  'collie': {'vrai positif': 346,
#   'faux positif': 260,
#   'precision': 0.570957095709571},
#  'Border_collie': {'vrai positif': 467,
#   'faux positif': 252,
#   'precision': 0.6495132127955494},
#  'Bouvier_des_Flandres': {'vrai positif': 448,
#   'faux positif': 82,
#   'precision': 0.8452830188679246},
#  'Rottweiler': {'vrai positif': 528,
#   'faux positif': 32,
#   'precision': 0.9428571428571428},
#  'German_shepherd': {'vrai positif': 430,
#   'faux positif': 66,
#   'precision': 0.8669354838709677},
#  'Doberman': {'vrai positif': 461,
#   'faux positif': 212,
#   'precision': 0.6849925705794948},
#  'miniature_pinscher': {'vrai positif': 515,
#   'faux positif': 176,
#   'precision': 0.7452966714905933},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 452,
#   'faux positif': 57,
#   'precision': 0.888015717092338},
#  'Bernese_mountain_dog': {'vrai positif': 771,
#   'faux positif': 90,
#   'precision': 0.8954703832752613},
#  'Appenzeller': {'vrai positif': 403,
#   'faux positif': 219,
#   'precision': 0.6479099678456591},
#  'EntleBucher': {'vrai positif': 613,
#   'faux positif': 157,
#   'precision': 0.7961038961038961},
#  'boxer': {'vrai positif': 371,
#   'faux positif': 62,
#   'precision': 0.8568129330254042},
#  'bull_mastiff': {'vrai positif': 540,
#   'faux positif': 131,
#   'precision': 0.8047690014903129},
#  'Tibetan_mastiff': {'vrai positif': 387,
#   'faux positif': 44,
#   'precision': 0.8979118329466357},
#  'French_bulldog': {'vrai positif': 522,
#   'faux positif': 81,
#   'precision': 0.8656716417910447},
#  'Great_Dane': {'vrai positif': 361,
#   'faux positif': 44,
#   'precision': 0.891358024691358},
#  'Saint_Bernard': {'vrai positif': 632,
#   'faux positif': 37,
#   'precision': 0.9446935724962631},
#  'Eskimo_dog': {'vrai positif': 209,
#   'faux positif': 277,
#   'precision': 0.43004115226337447},
#  'malamute': {'vrai positif': 489,
#   'faux positif': 275,
#   'precision': 0.6400523560209425},
#  'Siberian_husky': {'vrai positif': 359,
#   'faux positif': 267,
#   'precision': 0.5734824281150159},
#  'affenpinscher': {'vrai positif': 430,
#   'faux positif': 87,
#   'precision': 0.8317214700193424},
#  'basenji': {'vrai positif': 703,
#   'faux positif': 129,
#   'precision': 0.8449519230769231},
#  'pug': {'vrai positif': 684,
#   'faux positif': 56,
#   'precision': 0.9243243243243243},
#  'Leonberg': {'vrai positif': 751,
#   'faux positif': 73,
#   'precision': 0.9114077669902912},
#  'Newfoundland': {'vrai positif': 676,
#   'faux positif': 215,
#   'precision': 0.7586980920314254},
#  'Great_Pyrenees': {'vrai positif': 665,
#   'faux positif': 164,
#   'precision': 0.8021712907117008},
#  'Samoyed': {'vrai positif': 814,
#   'faux positif': 176,
#   'precision': 0.8222222222222222},
#  'Pomeranian': {'vrai positif': 745,
#   'faux positif': 28,
#   'precision': 0.963777490297542},
#  'chow': {'vrai positif': 689,
#   'faux positif': 8,
#   'precision': 0.9885222381635581},
#  'keeshond': {'vrai positif': 580,
#   'faux positif': 20,
#   'precision': 0.9666666666666667},
#  'Brabancon_griffon': {'vrai positif': 508,
#   'faux positif': 117,
#   'precision': 0.8128},
#  'Pembroke': {'vrai positif': 638,
#   'faux positif': 201,
#   'precision': 0.7604290822407628},
#  'Cardigan': {'vrai positif': 394,
#   'faux positif': 82,
#   'precision': 0.8277310924369747},
#  'toy_poodle': {'vrai positif': 329,
#   'faux positif': 196,
#   'precision': 0.6266666666666667},
#  'miniature_poodle': {'vrai positif': 191,
#   'faux positif': 267,
#   'precision': 0.4170305676855895},
#  'standard_poodle': {'vrai positif': 420,
#   'faux positif': 231,
#   'precision': 0.6451612903225806},
#  'Mexican_hairless': {'vrai positif': 557,
#   'faux positif': 57,
#   'precision': 0.9071661237785016},
#  'dingo': {'vrai positif': 564,
#   'faux positif': 138,
#   'precision': 0.8034188034188035},
#  'dhole': {'vrai positif': 510,
#   'faux positif': 39,
#   'precision': 0.9289617486338798},
#  'African_hunting_dog': {'vrai positif': 612,
#   'faux positif': 32,
#   'precision': 0.9503105590062112}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 3s 77ms/step - loss: 0.5615 - categorical_accuracy: 0.8375
# [0.5614524483680725, 0.8375115990638733]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
# Out:
# 4

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-15:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
        
len(model.trainable_variables)
# Out:
# 176

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 15/19
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-11 22:41:50.650825: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:41:50.656738: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:41:52.044782: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:41:52.044848: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:41:52.058970: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:41:52.059011: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 448/449 [============================>.] - ETA: 0s - loss: 1.6259 - categorical_accuracy: 0.5991
# 2023-03-11 22:46:38.825483: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:46:38.825529: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:46:38.836214: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 22:46:38.836244: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 449/449 [==============================] - 327s 676ms/step - loss: 1.6256 - categorical_accuracy: 0.5990 - val_loss: 0.5981 - val_categorical_accuracy: 0.8186
# Epoch 16/19
# 449/449 [==============================] - 303s 674ms/step - loss: 1.5051 - categorical_accuracy: 0.6222 - val_loss: 0.6028 - val_categorical_accuracy: 0.8209
# Epoch 17/19
# 449/449 [==============================] - 303s 674ms/step - loss: 1.4231 - categorical_accuracy: 0.6388 - val_loss: 0.5992 - val_categorical_accuracy: 0.8211
# Epoch 18/19
# 449/449 [==============================] - 303s 674ms/step - loss: 1.3721 - categorical_accuracy: 0.6470 - val_loss: 0.5917 - val_categorical_accuracy: 0.8271
# Epoch 19/19
# 449/449 [==============================] - 312s 696ms/step - loss: 1.2947 - categorical_accuracy: 0.6584 - val_loss: 0.5719 - val_categorical_accuracy: 0.8283

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 157,
#   'faux positif': 36,
#   'precision': 0.8134715025906736},
#  'Japanese_spaniel': {'vrai positif': 206,
#   'faux positif': 9,
#   'precision': 0.958139534883721},
#  'Maltese_dog': {'vrai positif': 291,
#   'faux positif': 47,
#   'precision': 0.8609467455621301},
#  'Pekinese': {'vrai positif': 161,
#   'faux positif': 28,
#   'precision': 0.8518518518518519},
#  'Shih': {'vrai positif': 208,
#   'faux positif': 71,
#   'precision': 0.7455197132616488},
#  'Blenheim_spaniel': {'vrai positif': 233,
#   'faux positif': 22,
#   'precision': 0.9137254901960784},
#  'papillon': {'vrai positif': 230,
#   'faux positif': 7,
#   'precision': 0.9704641350210971},
#  'toy_terrier': {'vrai positif': 149,
#   'faux positif': 38,
#   'precision': 0.7967914438502673},
#  'Rhodesian_ridgeback': {'vrai positif': 187,
#   'faux positif': 87,
#   'precision': 0.6824817518248175},
#  'Afghan_hound': {'vrai positif': 277,
#   'faux positif': 17,
#   'precision': 0.9421768707482994},
#  'basset': {'vrai positif': 206,
#   'faux positif': 31,
#   'precision': 0.869198312236287},
#  'beagle': {'vrai positif': 207,
#   'faux positif': 77,
#   'precision': 0.7288732394366197},
#  'bloodhound': {'vrai positif': 213,
#   'faux positif': 30,
#   'precision': 0.8765432098765432},
#  'bluetick': {'vrai positif': 197,
#   'faux positif': 23,
#   'precision': 0.8954545454545455},
#  'black': {'vrai positif': 154,
#   'faux positif': 20,
#   'precision': 0.8850574712643678},
#  'Walker_hound': {'vrai positif': 127,
#   'faux positif': 52,
#   'precision': 0.7094972067039106},
#  'English_foxhound': {'vrai positif': 138,
#   'faux positif': 46,
#   'precision': 0.75},
#  'redbone': {'vrai positif': 124,
#   'faux positif': 28,
#   'precision': 0.8157894736842105},
#  'borzoi': {'vrai positif': 159,
#   'faux positif': 12,
#   'precision': 0.9298245614035088},
#  'Irish_wolfhound': {'vrai positif': 204,
#   'faux positif': 77,
#   'precision': 0.7259786476868327},
#  'Italian_greyhound': {'vrai positif': 182,
#   'faux positif': 53,
#   'precision': 0.774468085106383},
#  'whippet': {'vrai positif': 162,
#   'faux positif': 33,
#   'precision': 0.8307692307692308},
#  'Ibizan_hound': {'vrai positif': 207,
#   'faux positif': 20,
#   'precision': 0.9118942731277533},
#  'Norwegian_elkhound': {'vrai positif': 238,
#   'faux positif': 8,
#   'precision': 0.967479674796748},
#  'otterhound': {'vrai positif': 165,
#   'faux positif': 38,
#   'precision': 0.812807881773399},
#  'Saluki': {'vrai positif': 232,
#   'faux positif': 37,
#   'precision': 0.862453531598513},
#  'Scottish_deerhound': {'vrai positif': 242,
#   'faux positif': 76,
#   'precision': 0.7610062893081762},
#  'Weimaraner': {'vrai positif': 184,
#   'faux positif': 19,
#   'precision': 0.9064039408866995},
#  'Staffordshire_bullterrier': {'vrai positif': 92,
#   'faux positif': 26,
#   'precision': 0.7796610169491526},
#  'American_Staffordshire_terrier': {'vrai positif': 140,
#   'faux positif': 129,
#   'precision': 0.5204460966542751},
#  'Bedlington_terrier': {'vrai positif': 223,
#   'faux positif': 15,
#   'precision': 0.9369747899159664},
#  'Border_terrier': {'vrai positif': 192,
#   'faux positif': 18,
#   'precision': 0.9142857142857143},
#  'Kerry_blue_terrier': {'vrai positif': 215,
#   'faux positif': 12,
#   'precision': 0.947136563876652},
#  'Irish_terrier': {'vrai positif': 174,
#   'faux positif': 47,
#   'precision': 0.7873303167420814},
#  'Norfolk_terrier': {'vrai positif': 168,
#   'faux positif': 82,
#   'precision': 0.672},
#  'Norwich_terrier': {'vrai positif': 164,
#   'faux positif': 33,
#   'precision': 0.8324873096446701},
#  'Yorkshire_terrier': {'vrai positif': 127,
#   'faux positif': 69,
#   'precision': 0.6479591836734694},
#  'wire': {'vrai positif': 135,
#   'faux positif': 31,
#   'precision': 0.8132530120481928},
#  'Lakeland_terrier': {'vrai positif': 157,
#   'faux positif': 55,
#   'precision': 0.7405660377358491},
#  'Sealyham_terrier': {'vrai positif': 240,
#   'faux positif': 30,
#   'precision': 0.8888888888888888},
#  'Airedale': {'vrai positif': 213,
#   'faux positif': 41,
#   'precision': 0.8385826771653543},
#  'cairn': {'vrai positif': 204,
#   'faux positif': 66,
#   'precision': 0.7555555555555555},
#  'Australian_terrier': {'vrai positif': 204,
#   'faux positif': 90,
#   'precision': 0.6938775510204082},
#  'Dandie_Dinmont': {'vrai positif': 206,
#   'faux positif': 13,
#   'precision': 0.9406392694063926},
#  'Boston_bull': {'vrai positif': 207,
#   'faux positif': 20,
#   'precision': 0.9118942731277533},
#  'miniature_schnauzer': {'vrai positif': 162,
#   'faux positif': 70,
#   'precision': 0.6982758620689655},
#  'giant_schnauzer': {'vrai positif': 176,
#   'faux positif': 61,
#   'precision': 0.7426160337552743},
#  'standard_schnauzer': {'vrai positif': 115,
#   'faux positif': 42,
#   'precision': 0.732484076433121},
#  'Scotch_terrier': {'vrai positif': 196,
#   'faux positif': 24,
#   'precision': 0.8909090909090909},
#  'Tibetan_terrier': {'vrai positif': 173,
#   'faux positif': 52,
#   'precision': 0.7688888888888888},
#  'silky_terrier': {'vrai positif': 160,
#   'faux positif': 58,
#   'precision': 0.7339449541284404},
#  'soft': {'vrai positif': 142,
#   'faux positif': 35,
#   'precision': 0.8022598870056498},
#  'West_Highland_white_terrier': {'vrai positif': 194,
#   'faux positif': 22,
#   'precision': 0.8981481481481481},
#  'Lhasa': {'vrai positif': 132,
#   'faux positif': 64,
#   'precision': 0.673469387755102},
#  'flat': {'vrai positif': 180,
#   'faux positif': 46,
#   'precision': 0.7964601769911505},
#  'curly': {'vrai positif': 133,
#   'faux positif': 34,
#   'precision': 0.7964071856287425},
#  'golden_retriever': {'vrai positif': 159,
#   'faux positif': 31,
#   'precision': 0.8368421052631579},
#  'Labrador_retriever': {'vrai positif': 169,
#   'faux positif': 24,
#   'precision': 0.8756476683937824},
#  'Chesapeake_Bay_retriever': {'vrai positif': 193,
#   'faux positif': 54,
#   'precision': 0.7813765182186235},
#  'German_short': {'vrai positif': 165,
#   'faux positif': 19,
#   'precision': 0.8967391304347826},
#  'vizsla': {'vrai positif': 169,
#   'faux positif': 32,
#   'precision': 0.8407960199004975},
#  'English_setter': {'vrai positif': 148,
#   'faux positif': 28,
#   'precision': 0.8409090909090909},
#  'Irish_setter': {'vrai positif': 182,
#   'faux positif': 12,
#   'precision': 0.9381443298969072},
#  'Gordon_setter': {'vrai positif': 188,
#   'faux positif': 10,
#   'precision': 0.9494949494949495},
#  'Brittany_spaniel': {'vrai positif': 151,
#   'faux positif': 19,
#   'precision': 0.888235294117647},
#  'clumber': {'vrai positif': 175, 'faux positif': 25, 'precision': 0.875},
#  'English_springer': {'vrai positif': 183,
#   'faux positif': 41,
#   'precision': 0.8169642857142857},
#  'Welsh_springer_spaniel': {'vrai positif': 169,
#   'faux positif': 35,
#   'precision': 0.8284313725490197},
#  'cocker_spaniel': {'vrai positif': 150,
#   'faux positif': 19,
#   'precision': 0.8875739644970414},
#  'Sussex_spaniel': {'vrai positif': 175,
#   'faux positif': 1,
#   'precision': 0.9943181818181818},
#  'Irish_water_spaniel': {'vrai positif': 153,
#   'faux positif': 42,
#   'precision': 0.7846153846153846},
#  'kuvasz': {'vrai positif': 155,
#   'faux positif': 12,
#   'precision': 0.9281437125748503},
#  'schipperke': {'vrai positif': 167,
#   'faux positif': 20,
#   'precision': 0.893048128342246},
#  'groenendael': {'vrai positif': 174,
#   'faux positif': 48,
#   'precision': 0.7837837837837838},
#  'malinois': {'vrai positif': 164,
#   'faux positif': 51,
#   'precision': 0.7627906976744186},
#  'briard': {'vrai positif': 134,
#   'faux positif': 24,
#   'precision': 0.8481012658227848},
#  'kelpie': {'vrai positif': 119,
#   'faux positif': 45,
#   'precision': 0.725609756097561},
#  'komondor': {'vrai positif': 190,
#   'faux positif': 15,
#   'precision': 0.926829268292683},
#  'Old_English_sheepdog': {'vrai positif': 196,
#   'faux positif': 15,
#   'precision': 0.9289099526066351},
#  'Shetland_sheepdog': {'vrai positif': 156,
#   'faux positif': 27,
#   'precision': 0.8524590163934426},
#  'collie': {'vrai positif': 96,
#   'faux positif': 45,
#   'precision': 0.6808510638297872},
#  'Border_collie': {'vrai positif': 159,
#   'faux positif': 77,
#   'precision': 0.673728813559322},
#  'Bouvier_des_Flandres': {'vrai positif': 143,
#   'faux positif': 16,
#   'precision': 0.89937106918239},
#  'Rottweiler': {'vrai positif': 174,
#   'faux positif': 19,
#   'precision': 0.9015544041450777},
#  'German_shepherd': {'vrai positif': 139,
#   'faux positif': 11,
#   'precision': 0.9266666666666666},
#  'Doberman': {'vrai positif': 158,
#   'faux positif': 53,
#   'precision': 0.7488151658767772},
#  'miniature_pinscher': {'vrai positif': 175,
#   'faux positif': 72,
#   'precision': 0.708502024291498},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 149,
#   'faux positif': 18,
#   'precision': 0.8922155688622755},
#  'Bernese_mountain_dog': {'vrai positif': 265,
#   'faux positif': 50,
#   'precision': 0.8412698412698413},
#  'Appenzeller': {'vrai positif': 112,
#   'faux positif': 46,
#   'precision': 0.7088607594936709},
#  'EntleBucher': {'vrai positif': 208,
#   'faux positif': 58,
#   'precision': 0.7819548872180451},
#  'boxer': {'vrai positif': 141,
#   'faux positif': 50,
#   'precision': 0.7382198952879581},
#  'bull_mastiff': {'vrai positif': 172,
#   'faux positif': 33,
#   'precision': 0.8390243902439024},
#  'Tibetan_mastiff': {'vrai positif': 125,
#   'faux positif': 4,
#   'precision': 0.9689922480620154},
#  'French_bulldog': {'vrai positif': 174,
#   'faux positif': 18,
#   'precision': 0.90625},
#  'Great_Dane': {'vrai positif': 133,
#   'faux positif': 11,
#   'precision': 0.9236111111111112},
#  'Saint_Bernard': {'vrai positif': 206,
#   'faux positif': 6,
#   'precision': 0.9716981132075472},
#  'Eskimo_dog': {'vrai positif': 73,
#   'faux positif': 92,
#   'precision': 0.44242424242424244},
#  'malamute': {'vrai positif': 140,
#   'faux positif': 55,
#   'precision': 0.717948717948718},
#  'Siberian_husky': {'vrai positif': 154,
#   'faux positif': 116,
#   'precision': 0.5703703703703704},
#  'affenpinscher': {'vrai positif': 152,
#   'faux positif': 20,
#   'precision': 0.8837209302325582},
#  'basenji': {'vrai positif': 233,
#   'faux positif': 48,
#   'precision': 0.8291814946619217},
#  'pug': {'vrai positif': 233,
#   'faux positif': 19,
#   'precision': 0.9246031746031746},
#  'Leonberg': {'vrai positif': 245,
#   'faux positif': 36,
#   'precision': 0.8718861209964412},
#  'Newfoundland': {'vrai positif': 227,
#   'faux positif': 73,
#   'precision': 0.7566666666666667},
#  'Great_Pyrenees': {'vrai positif': 221,
#   'faux positif': 49,
#   'precision': 0.8185185185185185},
#  'Samoyed': {'vrai positif': 269,
#   'faux positif': 42,
#   'precision': 0.864951768488746},
#  'Pomeranian': {'vrai positif': 242,
#   'faux positif': 9,
#   'precision': 0.9641434262948207},
#  'chow': {'vrai positif': 232,
#   'faux positif': 1,
#   'precision': 0.9957081545064378},
#  'keeshond': {'vrai positif': 195,
#   'faux positif': 3,
#   'precision': 0.9848484848484849},
#  'Brabancon_griffon': {'vrai positif': 171,
#   'faux positif': 29,
#   'precision': 0.855},
#  'Pembroke': {'vrai positif': 209,
#   'faux positif': 73,
#   'precision': 0.7411347517730497},
#  'Cardigan': {'vrai positif': 129,
#   'faux positif': 33,
#   'precision': 0.7962962962962963},
#  'toy_poodle': {'vrai positif': 112,
#   'faux positif': 59,
#   'precision': 0.6549707602339181},
#  'miniature_poodle': {'vrai positif': 60,
#   'faux positif': 85,
#   'precision': 0.41379310344827586},
#  'standard_poodle': {'vrai positif': 158,
#   'faux positif': 88,
#   'precision': 0.6422764227642277},
#  'Mexican_hairless': {'vrai positif': 189,
#   'faux positif': 11,
#   'precision': 0.945},
#  'dingo': {'vrai positif': 189,
#   'faux positif': 39,
#   'precision': 0.8289473684210527},
#  'dhole': {'vrai positif': 169,
#   'faux positif': 5,
#   'precision': 0.9712643678160919},
#  'African_hunting_dog': {'vrai positif': 210,
#   'faux positif': 3,
#   'precision': 0.9859154929577465}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 2s 59ms/step - loss: 0.5541 - categorical_accuracy: 0.8524
# [0.5540802478790283, 0.8523676991462708]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# American_Staffordshire_terrier

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 23,818,872
# Trainable params: 23,769,336
# Non-trainable params: 49,536
# _________________________________________________________________

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 85ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 649 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2a3ac24940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 190ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 650 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2a3a3ac430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 246ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 0s 375ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 0s 452ms/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)
