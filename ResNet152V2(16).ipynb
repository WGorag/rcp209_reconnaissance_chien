# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 16
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fad0450eee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fad04568c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet152V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet152V2(
    include_top=False,
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.8)(x)
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True,
     min_delta = 0.01
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 898/898 [==============================] - 391s 402ms/step - loss: 3.6857 - categorical_accuracy: 0.3134 - val_loss: 0.6707 - val_categorical_accuracy: 0.8019
# Epoch 2/25
# 898/898 [==============================] - 337s 376ms/step - loss: 2.4446 - categorical_accuracy: 0.5023 - val_loss: 0.6033 - val_categorical_accuracy: 0.8273
# Epoch 3/25
# 898/898 [==============================] - 328s 366ms/step - loss: 2.4009 - categorical_accuracy: 0.5287 - val_loss: 0.5871 - val_categorical_accuracy: 0.8361
# Epoch 4/25
# 898/898 [==============================] - 333s 371ms/step - loss: 2.2762 - categorical_accuracy: 0.5501 - val_loss: 0.5875 - val_categorical_accuracy: 0.8359
# Epoch 5/25
# 898/898 [==============================] - 329s 367ms/step - loss: 2.2202 - categorical_accuracy: 0.5589 - val_loss: 0.5732 - val_categorical_accuracy: 0.8429
# Epoch 6/25
# 898/898 [==============================] - 331s 368ms/step - loss: 2.1159 - categorical_accuracy: 0.5693 - val_loss: 0.5799 - val_categorical_accuracy: 0.8429
# Epoch 7/25
# 898/898 [==============================] - 327s 364ms/step - loss: 2.0889 - categorical_accuracy: 0.5742 - val_loss: 0.5571 - val_categorical_accuracy: 0.8450
# Epoch 8/25
# 898/898 [==============================] - 322s 359ms/step - loss: 2.0036 - categorical_accuracy: 0.5767 - val_loss: 0.5733 - val_categorical_accuracy: 0.8397
# Epoch 9/25
# 898/898 [==============================] - 322s 359ms/step - loss: 1.8732 - categorical_accuracy: 0.5868 - val_loss: 0.5392 - val_categorical_accuracy: 0.8481
# Epoch 10/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.8324 - categorical_accuracy: 0.5899 - val_loss: 0.5255 - val_categorical_accuracy: 0.8479
# Epoch 11/25
# 898/898 [==============================] - 324s 361ms/step - loss: 1.7578 - categorical_accuracy: 0.5932 - val_loss: 0.5239 - val_categorical_accuracy: 0.8456
# Epoch 12/25
# 898/898 [==============================] - 321s 358ms/step - loss: 1.6519 - categorical_accuracy: 0.6013 - val_loss: 0.5095 - val_categorical_accuracy: 0.8524
# Epoch 13/25
# 898/898 [==============================] - 322s 358ms/step - loss: 1.5917 - categorical_accuracy: 0.6079 - val_loss: 0.4949 - val_categorical_accuracy: 0.8491
# Epoch 14/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.5374 - categorical_accuracy: 0.6104 - val_loss: 0.4871 - val_categorical_accuracy: 0.8512
# Epoch 15/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.4758 - categorical_accuracy: 0.6180 - val_loss: 0.4805 - val_categorical_accuracy: 0.8533
# Epoch 16/25
# 898/898 [==============================] - 323s 360ms/step - loss: 1.4183 - categorical_accuracy: 0.6218 - val_loss: 0.4743 - val_categorical_accuracy: 0.8559
# Epoch 17/25
# 898/898 [==============================] - 321s 358ms/step - loss: 1.3546 - categorical_accuracy: 0.6343 - val_loss: 0.4725 - val_categorical_accuracy: 0.8514
# Epoch 18/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.3501 - categorical_accuracy: 0.6306 - val_loss: 0.4726 - val_categorical_accuracy: 0.8530
# Epoch 19/25
# 898/898 [==============================] - 323s 360ms/step - loss: 1.3361 - categorical_accuracy: 0.6370 - val_loss: 0.4709 - val_categorical_accuracy: 0.8530
# Epoch 20/25
# 898/898 [==============================] - 321s 357ms/step - loss: 1.3013 - categorical_accuracy: 0.6346 - val_loss: 0.4699 - val_categorical_accuracy: 0.8524
# Epoch 21/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.2710 - categorical_accuracy: 0.6451 - val_loss: 0.4645 - val_categorical_accuracy: 0.8541
# Epoch 22/25
# 898/898 [==============================] - 328s 366ms/step - loss: 1.2699 - categorical_accuracy: 0.6415 - val_loss: 0.4626 - val_categorical_accuracy: 0.8582
# Epoch 23/25
# 898/898 [==============================] - 326s 363ms/step - loss: 1.2649 - categorical_accuracy: 0.6465 - val_loss: 0.4642 - val_categorical_accuracy: 0.8603
# Epoch 24/25
# 898/898 [==============================] - 323s 359ms/step - loss: 1.2306 - categorical_accuracy: 0.6512 - val_loss: 0.4625 - val_categorical_accuracy: 0.8574
# Epoch 25/25
# 898/898 [==============================] - 323s 360ms/step - loss: 1.2263 - categorical_accuracy: 0.6526 - val_loss: 0.4608 - val_categorical_accuracy: 0.8506

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 679,
#   'faux positif': 145,
#   'precision': 0.8240291262135923},
#  'Japanese_spaniel': {'vrai positif': 1055,
#   'faux positif': 86,
#   'precision': 0.9246275197195443},
#  'Maltese_dog': {'vrai positif': 1472,
#   'faux positif': 459,
#   'precision': 0.7622993267736924},
#  'Pekinese': {'vrai positif': 802,
#   'faux positif': 88,
#   'precision': 0.9011235955056179},
#  'Shih': {'vrai positif': 987,
#   'faux positif': 378,
#   'precision': 0.7230769230769231},
#  'Blenheim_spaniel': {'vrai positif': 1162,
#   'faux positif': 71,
#   'precision': 0.9424168694241687},
#  'papillon': {'vrai positif': 1139,
#   'faux positif': 73,
#   'precision': 0.9397689768976898},
#  'toy_terrier': {'vrai positif': 772,
#   'faux positif': 127,
#   'precision': 0.8587319243604005},
#  'Rhodesian_ridgeback': {'vrai positif': 933,
#   'faux positif': 437,
#   'precision': 0.6810218978102189},
#  'Afghan_hound': {'vrai positif': 1466,
#   'faux positif': 56,
#   'precision': 0.9632063074901446},
#  'basset': {'vrai positif': 945,
#   'faux positif': 121,
#   'precision': 0.8864915572232646},
#  'beagle': {'vrai positif': 1055,
#   'faux positif': 497,
#   'precision': 0.6797680412371134},
#  'bloodhound': {'vrai positif': 1077,
#   'faux positif': 128,
#   'precision': 0.8937759336099586},
#  'bluetick': {'vrai positif': 953,
#   'faux positif': 9,
#   'precision': 0.9906444906444907},
#  'black': {'vrai positif': 902,
#   'faux positif': 148,
#   'precision': 0.8590476190476191},
#  'Walker_hound': {'vrai positif': 399,
#   'faux positif': 160,
#   'precision': 0.7137745974955277},
#  'English_foxhound': {'vrai positif': 711,
#   'faux positif': 305,
#   'precision': 0.6998031496062992},
#  'redbone': {'vrai positif': 660,
#   'faux positif': 115,
#   'precision': 0.8516129032258064},
#  'borzoi': {'vrai positif': 780,
#   'faux positif': 16,
#   'precision': 0.9798994974874372},
#  'Irish_wolfhound': {'vrai positif': 1176,
#   'faux positif': 260,
#   'precision': 0.8189415041782729},
#  'Italian_greyhound': {'vrai positif': 959,
#   'faux positif': 290,
#   'precision': 0.7678142514011209},
#  'whippet': {'vrai positif': 793,
#   'faux positif': 123,
#   'precision': 0.8657205240174672},
#  'Ibizan_hound': {'vrai positif': 1090,
#   'faux positif': 67,
#   'precision': 0.9420916162489196},
#  'Norwegian_elkhound': {'vrai positif': 1181,
#   'faux positif': 22,
#   'precision': 0.9817123857024106},
#  'otterhound': {'vrai positif': 832,
#   'faux positif': 94,
#   'precision': 0.8984881209503239},
#  'Saluki': {'vrai positif': 1086,
#   'faux positif': 28,
#   'precision': 0.9748653500897666},
#  'Scottish_deerhound': {'vrai positif': 1248,
#   'faux positif': 193,
#   'precision': 0.8660652324774463},
#  'Weimaraner': {'vrai positif': 948,
#   'faux positif': 72,
#   'precision': 0.9294117647058824},
#  'Staffordshire_bullterrier': {'vrai positif': 532,
#   'faux positif': 193,
#   'precision': 0.7337931034482759},
#  'American_Staffordshire_terrier': {'vrai positif': 753,
#   'faux positif': 608,
#   'precision': 0.553269654665687},
#  'Bedlington_terrier': {'vrai positif': 1108,
#   'faux positif': 61,
#   'precision': 0.9478186484174508},
#  'Border_terrier': {'vrai positif': 1037,
#   'faux positif': 39,
#   'precision': 0.9637546468401487},
#  'Kerry_blue_terrier': {'vrai positif': 1024,
#   'faux positif': 75,
#   'precision': 0.9317561419472248},
#  'Irish_terrier': {'vrai positif': 865,
#   'faux positif': 100,
#   'precision': 0.8963730569948186},
#  'Norfolk_terrier': {'vrai positif': 858,
#   'faux positif': 241,
#   'precision': 0.7807097361237488},
#  'Norwich_terrier': {'vrai positif': 912,
#   'faux positif': 132,
#   'precision': 0.8735632183908046},
#  'Yorkshire_terrier': {'vrai positif': 704,
#   'faux positif': 115,
#   'precision': 0.8595848595848596},
#  'wire': {'vrai positif': 643,
#   'faux positif': 15,
#   'precision': 0.9772036474164134},
#  'Lakeland_terrier': {'vrai positif': 1028,
#   'faux positif': 474,
#   'precision': 0.6844207723035952},
#  'Sealyham_terrier': {'vrai positif': 1161,
#   'faux positif': 182,
#   'precision': 0.8644825018615041},
#  'Airedale': {'vrai positif': 1043,
#   'faux positif': 163,
#   'precision': 0.8648424543946932},
#  'cairn': {'vrai positif': 1101,
#   'faux positif': 169,
#   'precision': 0.8669291338582678},
#  'Australian_terrier': {'vrai positif': 993,
#   'faux positif': 600,
#   'precision': 0.623352165725047},
#  'Dandie_Dinmont': {'vrai positif': 961,
#   'faux positif': 68,
#   'precision': 0.9339164237123421},
#  'Boston_bull': {'vrai positif': 1072,
#   'faux positif': 62,
#   'precision': 0.9453262786596119},
#  'miniature_schnauzer': {'vrai positif': 794,
#   'faux positif': 175,
#   'precision': 0.8194014447884417},
#  'giant_schnauzer': {'vrai positif': 795,
#   'faux positif': 184,
#   'precision': 0.8120531154239019},
#  'standard_schnauzer': {'vrai positif': 684,
#   'faux positif': 216,
#   'precision': 0.76},
#  'Scotch_terrier': {'vrai positif': 832,
#   'faux positif': 71,
#   'precision': 0.9213732004429679},
#  'Tibetan_terrier': {'vrai positif': 990,
#   'faux positif': 128,
#   'precision': 0.8855098389982111},
#  'silky_terrier': {'vrai positif': 754,
#   'faux positif': 355,
#   'precision': 0.6798917944093779},
#  'soft': {'vrai positif': 867,
#   'faux positif': 260,
#   'precision': 0.769299023957409},
#  'West_Highland_white_terrier': {'vrai positif': 977,
#   'faux positif': 225,
#   'precision': 0.8128119800332779},
#  'Lhasa': {'vrai positif': 760,
#   'faux positif': 266,
#   'precision': 0.7407407407407407},
#  'flat': {'vrai positif': 881,
#   'faux positif': 192,
#   'precision': 0.821062441752097},
#  'curly': {'vrai positif': 902,
#   'faux positif': 75,
#   'precision': 0.9232343909928352},
#  'golden_retriever': {'vrai positif': 829,
#   'faux positif': 114,
#   'precision': 0.8791092258748674},
#  'Labrador_retriever': {'vrai positif': 1002,
#   'faux positif': 342,
#   'precision': 0.7455357142857143},
#  'Chesapeake_Bay_retriever': {'vrai positif': 954,
#   'faux positif': 97,
#   'precision': 0.9077069457659372},
#  'German_short': {'vrai positif': 826,
#   'faux positif': 91,
#   'precision': 0.9007633587786259},
#  'vizsla': {'vrai positif': 809,
#   'faux positif': 115,
#   'precision': 0.8755411255411255},
#  'English_setter': {'vrai positif': 762,
#   'faux positif': 89,
#   'precision': 0.8954171562867215},
#  'Irish_setter': {'vrai positif': 890,
#   'faux positif': 66,
#   'precision': 0.9309623430962343},
#  'Gordon_setter': {'vrai positif': 884,
#   'faux positif': 55,
#   'precision': 0.9414270500532481},
#  'Brittany_spaniel': {'vrai positif': 820,
#   'faux positif': 309,
#   'precision': 0.7263064658990257},
#  'clumber': {'vrai positif': 897,
#   'faux positif': 90,
#   'precision': 0.9088145896656535},
#  'English_springer': {'vrai positif': 969,
#   'faux positif': 268,
#   'precision': 0.7833468067906225},
#  'Welsh_springer_spaniel': {'vrai positif': 801,
#   'faux positif': 87,
#   'precision': 0.902027027027027},
#  'cocker_spaniel': {'vrai positif': 810,
#   'faux positif': 108,
#   'precision': 0.8823529411764706},
#  'Sussex_spaniel': {'vrai positif': 900,
#   'faux positif': 77,
#   'precision': 0.9211873080859775},
#  'Irish_water_spaniel': {'vrai positif': 845,
#   'faux positif': 132,
#   'precision': 0.8648925281473899},
#  'kuvasz': {'vrai positif': 689,
#   'faux positif': 124,
#   'precision': 0.8474784747847478},
#  'schipperke': {'vrai positif': 848,
#   'faux positif': 145,
#   'precision': 0.8539778449144008},
#  'groenendael': {'vrai positif': 905,
#   'faux positif': 182,
#   'precision': 0.8325666973321068},
#  'malinois': {'vrai positif': 867,
#   'faux positif': 81,
#   'precision': 0.9145569620253164},
#  'briard': {'vrai positif': 819,
#   'faux positif': 49,
#   'precision': 0.9435483870967742},
#  'kelpie': {'vrai positif': 641, 'faux positif': 159, 'precision': 0.80125},
#  'komondor': {'vrai positif': 908,
#   'faux positif': 56,
#   'precision': 0.941908713692946},
#  'Old_English_sheepdog': {'vrai positif': 1016,
#   'faux positif': 100,
#   'precision': 0.910394265232975},
#  'Shetland_sheepdog': {'vrai positif': 769,
#   'faux positif': 124,
#   'precision': 0.8611422172452408},
#  'collie': {'vrai positif': 504,
#   'faux positif': 267,
#   'precision': 0.6536964980544747},
#  'Border_collie': {'vrai positif': 823,
#   'faux positif': 509,
#   'precision': 0.6178678678678678},
#  'Bouvier_des_Flandres': {'vrai positif': 814,
#   'faux positif': 233,
#   'precision': 0.7774594078319007},
#  'Rottweiler': {'vrai positif': 920,
#   'faux positif': 34,
#   'precision': 0.9643605870020965},
#  'German_shepherd': {'vrai positif': 766,
#   'faux positif': 85,
#   'precision': 0.900117508813161},
#  'Doberman': {'vrai positif': 813,
#   'faux positif': 107,
#   'precision': 0.883695652173913},
#  'miniature_pinscher': {'vrai positif': 999,
#   'faux positif': 211,
#   'precision': 0.8256198347107438},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 765,
#   'faux positif': 71,
#   'precision': 0.9150717703349283},
#  'Bernese_mountain_dog': {'vrai positif': 1241,
#   'faux positif': 58,
#   'precision': 0.9553502694380293},
#  'Appenzeller': {'vrai positif': 698,
#   'faux positif': 407,
#   'precision': 0.6316742081447964},
#  'EntleBucher': {'vrai positif': 1057,
#   'faux positif': 293,
#   'precision': 0.782962962962963},
#  'boxer': {'vrai positif': 837,
#   'faux positif': 105,
#   'precision': 0.8885350318471338},
#  'bull_mastiff': {'vrai positif': 895,
#   'faux positif': 47,
#   'precision': 0.9501061571125266},
#  'Tibetan_mastiff': {'vrai positif': 726,
#   'faux positif': 29,
#   'precision': 0.9615894039735099},
#  'French_bulldog': {'vrai positif': 927,
#   'faux positif': 83,
#   'precision': 0.9178217821782179},
#  'Great_Dane': {'vrai positif': 783,
#   'faux positif': 80,
#   'precision': 0.9073001158748552},
#  'Saint_Bernard': {'vrai positif': 1052,
#   'faux positif': 43,
#   'precision': 0.960730593607306},
#  'Eskimo_dog': {'vrai positif': 328,
#   'faux positif': 421,
#   'precision': 0.4379172229639519},
#  'malamute': {'vrai positif': 931,
#   'faux positif': 351,
#   'precision': 0.7262090483619345},
#  'Siberian_husky': {'vrai positif': 650,
#   'faux positif': 457,
#   'precision': 0.5871725383920506},
#  'affenpinscher': {'vrai positif': 821,
#   'faux positif': 112,
#   'precision': 0.879957127545552},
#  'basenji': {'vrai positif': 1242,
#   'faux positif': 136,
#   'precision': 0.9013062409288825},
#  'pug': {'vrai positif': 1192,
#   'faux positif': 20,
#   'precision': 0.9834983498349835},
#  'Leonberg': {'vrai positif': 1296,
#   'faux positif': 23,
#   'precision': 0.9825625473843821},
#  'Newfoundland': {'vrai positif': 1093,
#   'faux positif': 280,
#   'precision': 0.7960670065549891},
#  'Great_Pyrenees': {'vrai positif': 1083,
#   'faux positif': 286,
#   'precision': 0.7910883856829802},
#  'Samoyed': {'vrai positif': 1317,
#   'faux positif': 176,
#   'precision': 0.8821165438713998},
#  'Pomeranian': {'vrai positif': 1295,
#   'faux positif': 81,
#   'precision': 0.9411337209302325},
#  'chow': {'vrai positif': 1219,
#   'faux positif': 35,
#   'precision': 0.9720893141945773},
#  'keeshond': {'vrai positif': 996,
#   'faux positif': 3,
#   'precision': 0.996996996996997},
#  'Brabancon_griffon': {'vrai positif': 868,
#   'faux positif': 75,
#   'precision': 0.9204665959703076},
#  'Pembroke': {'vrai positif': 1113,
#   'faux positif': 358,
#   'precision': 0.7566281441196465},
#  'Cardigan': {'vrai positif': 720,
#   'faux positif': 111,
#   'precision': 0.8664259927797834},
#  'toy_poodle': {'vrai positif': 735,
#   'faux positif': 484,
#   'precision': 0.6029532403609515},
#  'miniature_poodle': {'vrai positif': 287,
#   'faux positif': 152,
#   'precision': 0.6537585421412301},
#  'standard_poodle': {'vrai positif': 775,
#   'faux positif': 270,
#   'precision': 0.7416267942583732},
#  'Mexican_hairless': {'vrai positif': 925,
#   'faux positif': 19,
#   'precision': 0.9798728813559322},
#  'dingo': {'vrai positif': 788,
#   'faux positif': 85,
#   'precision': 0.9026345933562429},
#  'dhole': {'vrai positif': 896,
#   'faux positif': 51,
#   'precision': 0.9461457233368532},
#  'African_hunting_dog': {'vrai positif': 1025,
#   'faux positif': 12,
#   'precision': 0.9884281581485053}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 68/68 [==============================] - 10s 142ms/step - loss: 0.4880 - categorical_accuracy: 0.8552
# [0.48800599575042725, 0.8551532030105591]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
print(len(model.variables))
print(len(model.trainable_variables))
print(len(base_model.variables))
print(len(base_model.trainable_variables))
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# 820
# 4
# 814
# 0
# Number of layers in the base model:  564

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-5:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
len(model.trainable_variables)
# Out:
# 516

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %%
model.save('Modele_fine_v3.h5')

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 25/29
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-12 20:30:32.819486: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:32.823116: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:32.847657: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:32.847690: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:33.443972: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:33.444018: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:33.460899: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:33.460926: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:34.054312: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 20:30:34.054360: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 898/898 [==============================] - 637s 654ms/step - loss: 1.1886 - categorical_accuracy: 0.6661 - val_loss: 0.4879 - val_categorical_accuracy: 0.8463
# Epoch 26/29
# 898/898 [==============================] - 583s 650ms/step - loss: 1.0609 - categorical_accuracy: 0.6917 - val_loss: 0.4797 - val_categorical_accuracy: 0.8514
# Epoch 27/29
# 898/898 [==============================] - 583s 649ms/step - loss: 0.9818 - categorical_accuracy: 0.7145 - val_loss: 0.5028 - val_categorical_accuracy: 0.8498
# Epoch 28/29
# 898/898 [==============================] - 583s 649ms/step - loss: 0.9304 - categorical_accuracy: 0.7229 - val_loss: 0.5179 - val_categorical_accuracy: 0.8430
# Epoch 29/29
# 898/898 [==============================] - 583s 649ms/step - loss: 0.8733 - categorical_accuracy: 0.7365 - val_loss: 0.4835 - val_categorical_accuracy: 0.8590

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 139,
#   'faux positif': 26,
#   'precision': 0.8424242424242424},
#  'Japanese_spaniel': {'vrai positif': 209,
#   'faux positif': 15,
#   'precision': 0.9330357142857143},
#  'Maltese_dog': {'vrai positif': 291,
#   'faux positif': 85,
#   'precision': 0.773936170212766},
#  'Pekinese': {'vrai positif': 149,
#   'faux positif': 19,
#   'precision': 0.8869047619047619},
#  'Shih': {'vrai positif': 195,
#   'faux positif': 69,
#   'precision': 0.7386363636363636},
#  'Blenheim_spaniel': {'vrai positif': 231,
#   'faux positif': 6,
#   'precision': 0.9746835443037974},
#  'papillon': {'vrai positif': 234,
#   'faux positif': 28,
#   'precision': 0.8931297709923665},
#  'toy_terrier': {'vrai positif': 163,
#   'faux positif': 39,
#   'precision': 0.806930693069307},
#  'Rhodesian_ridgeback': {'vrai positif': 176,
#   'faux positif': 48,
#   'precision': 0.7857142857142857},
#  'Afghan_hound': {'vrai positif': 291, 'faux positif': 9, 'precision': 0.97},
#  'basset': {'vrai positif': 186,
#   'faux positif': 21,
#   'precision': 0.8985507246376812},
#  'beagle': {'vrai positif': 215,
#   'faux positif': 92,
#   'precision': 0.7003257328990228},
#  'bloodhound': {'vrai positif': 214,
#   'faux positif': 17,
#   'precision': 0.9264069264069265},
#  'bluetick': {'vrai positif': 190,
#   'faux positif': 19,
#   'precision': 0.9090909090909091},
#  'black': {'vrai positif': 172,
#   'faux positif': 21,
#   'precision': 0.8911917098445595},
#  'Walker_hound': {'vrai positif': 103,
#   'faux positif': 31,
#   'precision': 0.7686567164179104},
#  'English_foxhound': {'vrai positif': 145,
#   'faux positif': 44,
#   'precision': 0.7671957671957672},
#  'redbone': {'vrai positif': 137,
#   'faux positif': 15,
#   'precision': 0.9013157894736842},
#  'borzoi': {'vrai positif': 165,
#   'faux positif': 10,
#   'precision': 0.9428571428571428},
#  'Irish_wolfhound': {'vrai positif': 245,
#   'faux positif': 69,
#   'precision': 0.7802547770700637},
#  'Italian_greyhound': {'vrai positif': 197,
#   'faux positif': 68,
#   'precision': 0.7433962264150943},
#  'whippet': {'vrai positif': 158,
#   'faux positif': 33,
#   'precision': 0.8272251308900523},
#  'Ibizan_hound': {'vrai positif': 219,
#   'faux positif': 11,
#   'precision': 0.9521739130434783},
#  'Norwegian_elkhound': {'vrai positif': 236,
#   'faux positif': 9,
#   'precision': 0.963265306122449},
#  'otterhound': {'vrai positif': 160,
#   'faux positif': 9,
#   'precision': 0.9467455621301775},
#  'Saluki': {'vrai positif': 221,
#   'faux positif': 9,
#   'precision': 0.9608695652173913},
#  'Scottish_deerhound': {'vrai positif': 244,
#   'faux positif': 35,
#   'precision': 0.8745519713261649},
#  'Weimaraner': {'vrai positif': 191,
#   'faux positif': 28,
#   'precision': 0.8721461187214612},
#  'Staffordshire_bullterrier': {'vrai positif': 112,
#   'faux positif': 49,
#   'precision': 0.6956521739130435},
#  'American_Staffordshire_terrier': {'vrai positif': 140,
#   'faux positif': 99,
#   'precision': 0.5857740585774058},
#  'Bedlington_terrier': {'vrai positif': 225,
#   'faux positif': 9,
#   'precision': 0.9615384615384616},
#  'Border_terrier': {'vrai positif': 205,
#   'faux positif': 6,
#   'precision': 0.9715639810426541},
#  'Kerry_blue_terrier': {'vrai positif': 211,
#   'faux positif': 16,
#   'precision': 0.9295154185022027},
#  'Irish_terrier': {'vrai positif': 185,
#   'faux positif': 30,
#   'precision': 0.8604651162790697},
#  'Norfolk_terrier': {'vrai positif': 164,
#   'faux positif': 47,
#   'precision': 0.7772511848341233},
#  'Norwich_terrier': {'vrai positif': 159,
#   'faux positif': 15,
#   'precision': 0.9137931034482759},
#  'Yorkshire_terrier': {'vrai positif': 129,
#   'faux positif': 39,
#   'precision': 0.7678571428571429},
#  'wire': {'vrai positif': 147,
#   'faux positif': 12,
#   'precision': 0.9245283018867925},
#  'Lakeland_terrier': {'vrai positif': 203,
#   'faux positif': 61,
#   'precision': 0.7689393939393939},
#  'Sealyham_terrier': {'vrai positif': 232,
#   'faux positif': 20,
#   'precision': 0.9206349206349206},
#  'Airedale': {'vrai positif': 228,
#   'faux positif': 47,
#   'precision': 0.8290909090909091},
#  'cairn': {'vrai positif': 231,
#   'faux positif': 86,
#   'precision': 0.7287066246056783},
#  'Australian_terrier': {'vrai positif': 195,
#   'faux positif': 123,
#   'precision': 0.6132075471698113},
#  'Dandie_Dinmont': {'vrai positif': 187,
#   'faux positif': 22,
#   'precision': 0.8947368421052632},
#  'Boston_bull': {'vrai positif': 215,
#   'faux positif': 6,
#   'precision': 0.9728506787330317},
#  'miniature_schnauzer': {'vrai positif': 152,
#   'faux positif': 45,
#   'precision': 0.7715736040609137},
#  'giant_schnauzer': {'vrai positif': 168,
#   'faux positif': 48,
#   'precision': 0.7777777777777778},
#  'standard_schnauzer': {'vrai positif': 125,
#   'faux positif': 33,
#   'precision': 0.7911392405063291},
#  'Scotch_terrier': {'vrai positif': 170,
#   'faux positif': 20,
#   'precision': 0.8947368421052632},
#  'Tibetan_terrier': {'vrai positif': 211,
#   'faux positif': 47,
#   'precision': 0.8178294573643411},
#  'silky_terrier': {'vrai positif': 143,
#   'faux positif': 69,
#   'precision': 0.6745283018867925},
#  'soft': {'vrai positif': 173,
#   'faux positif': 26,
#   'precision': 0.8693467336683417},
#  'West_Highland_white_terrier': {'vrai positif': 203,
#   'faux positif': 42,
#   'precision': 0.8285714285714286},
#  'Lhasa': {'vrai positif': 136,
#   'faux positif': 48,
#   'precision': 0.7391304347826086},
#  'flat': {'vrai positif': 175,
#   'faux positif': 33,
#   'precision': 0.8413461538461539},
#  'curly': {'vrai positif': 188,
#   'faux positif': 23,
#   'precision': 0.8909952606635071},
#  'golden_retriever': {'vrai positif': 173,
#   'faux positif': 34,
#   'precision': 0.8357487922705314},
#  'Labrador_retriever': {'vrai positif': 196,
#   'faux positif': 58,
#   'precision': 0.7716535433070866},
#  'Chesapeake_Bay_retriever': {'vrai positif': 196,
#   'faux positif': 22,
#   'precision': 0.8990825688073395},
#  'German_short': {'vrai positif': 161,
#   'faux positif': 10,
#   'precision': 0.9415204678362573},
#  'vizsla': {'vrai positif': 181,
#   'faux positif': 37,
#   'precision': 0.8302752293577982},
#  'English_setter': {'vrai positif': 154,
#   'faux positif': 11,
#   'precision': 0.9333333333333333},
#  'Irish_setter': {'vrai positif': 187,
#   'faux positif': 16,
#   'precision': 0.9211822660098522},
#  'Gordon_setter': {'vrai positif': 180,
#   'faux positif': 3,
#   'precision': 0.9836065573770492},
#  'Brittany_spaniel': {'vrai positif': 162,
#   'faux positif': 61,
#   'precision': 0.726457399103139},
#  'clumber': {'vrai positif': 173,
#   'faux positif': 6,
#   'precision': 0.9664804469273743},
#  'English_springer': {'vrai positif': 186,
#   'faux positif': 53,
#   'precision': 0.7782426778242678},
#  'Welsh_springer_spaniel': {'vrai positif': 157,
#   'faux positif': 19,
#   'precision': 0.8920454545454546},
#  'cocker_spaniel': {'vrai positif': 161,
#   'faux positif': 7,
#   'precision': 0.9583333333333334},
#  'Sussex_spaniel': {'vrai positif': 180,
#   'faux positif': 7,
#   'precision': 0.9625668449197861},
#  'Irish_water_spaniel': {'vrai positif': 168,
#   'faux positif': 26,
#   'precision': 0.865979381443299},
#  'kuvasz': {'vrai positif': 145,
#   'faux positif': 18,
#   'precision': 0.8895705521472392},
#  'schipperke': {'vrai positif': 171,
#   'faux positif': 25,
#   'precision': 0.8724489795918368},
#  'groenendael': {'vrai positif': 184,
#   'faux positif': 40,
#   'precision': 0.8214285714285714},
#  'malinois': {'vrai positif': 175,
#   'faux positif': 15,
#   'precision': 0.9210526315789473},
#  'briard': {'vrai positif': 179, 'faux positif': 21, 'precision': 0.895},
#  'kelpie': {'vrai positif': 135,
#   'faux positif': 36,
#   'precision': 0.7894736842105263},
#  'komondor': {'vrai positif': 186,
#   'faux positif': 11,
#   'precision': 0.9441624365482234},
#  'Old_English_sheepdog': {'vrai positif': 206,
#   'faux positif': 16,
#   'precision': 0.9279279279279279},
#  'Shetland_sheepdog': {'vrai positif': 152,
#   'faux positif': 24,
#   'precision': 0.8636363636363636},
#  'collie': {'vrai positif': 108,
#   'faux positif': 68,
#   'precision': 0.6136363636363636},
#  'Border_collie': {'vrai positif': 158,
#   'faux positif': 101,
#   'precision': 0.61003861003861},
#  'Bouvier_des_Flandres': {'vrai positif': 159,
#   'faux positif': 31,
#   'precision': 0.8368421052631579},
#  'Rottweiler': {'vrai positif': 185, 'faux positif': 15, 'precision': 0.925},
#  'German_shepherd': {'vrai positif': 158,
#   'faux positif': 17,
#   'precision': 0.9028571428571428},
#  'Doberman': {'vrai positif': 159,
#   'faux positif': 14,
#   'precision': 0.9190751445086706},
#  'miniature_pinscher': {'vrai positif': 198,
#   'faux positif': 45,
#   'precision': 0.8148148148148148},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 160,
#   'faux positif': 9,
#   'precision': 0.9467455621301775},
#  'Bernese_mountain_dog': {'vrai positif': 265,
#   'faux positif': 17,
#   'precision': 0.9397163120567376},
#  'Appenzeller': {'vrai positif': 134,
#   'faux positif': 47,
#   'precision': 0.7403314917127072},
#  'EntleBucher': {'vrai positif': 216,
#   'faux positif': 59,
#   'precision': 0.7854545454545454},
#  'boxer': {'vrai positif': 170,
#   'faux positif': 24,
#   'precision': 0.8762886597938144},
#  'bull_mastiff': {'vrai positif': 176,
#   'faux positif': 6,
#   'precision': 0.967032967032967},
#  'Tibetan_mastiff': {'vrai positif': 145,
#   'faux positif': 5,
#   'precision': 0.9666666666666667},
#  'French_bulldog': {'vrai positif': 186,
#   'faux positif': 20,
#   'precision': 0.9029126213592233},
#  'Great_Dane': {'vrai positif': 169,
#   'faux positif': 23,
#   'precision': 0.8802083333333334},
#  'Saint_Bernard': {'vrai positif': 211,
#   'faux positif': 3,
#   'precision': 0.985981308411215},
#  'Eskimo_dog': {'vrai positif': 60,
#   'faux positif': 73,
#   'precision': 0.45112781954887216},
#  'malamute': {'vrai positif': 174,
#   'faux positif': 62,
#   'precision': 0.7372881355932204},
#  'Siberian_husky': {'vrai positif': 138,
#   'faux positif': 122,
#   'precision': 0.5307692307692308},
#  'affenpinscher': {'vrai positif': 156,
#   'faux positif': 15,
#   'precision': 0.9122807017543859},
#  'basenji': {'vrai positif': 249,
#   'faux positif': 22,
#   'precision': 0.9188191881918819},
#  'pug': {'vrai positif': 239,
#   'faux positif': 7,
#   'precision': 0.9715447154471545},
#  'Leonberg': {'vrai positif': 259,
#   'faux positif': 4,
#   'precision': 0.9847908745247148},
#  'Newfoundland': {'vrai positif': 214,
#   'faux positif': 41,
#   'precision': 0.8392156862745098},
#  'Great_Pyrenees': {'vrai positif': 214,
#   'faux positif': 60,
#   'precision': 0.781021897810219},
#  'Samoyed': {'vrai positif': 261,
#   'faux positif': 43,
#   'precision': 0.8585526315789473},
#  'Pomeranian': {'vrai positif': 259,
#   'faux positif': 15,
#   'precision': 0.9452554744525548},
#  'chow': {'vrai positif': 245,
#   'faux positif': 1,
#   'precision': 0.9959349593495935},
#  'keeshond': {'vrai positif': 200, 'faux positif': 0, 'precision': 1.0},
#  'Brabancon_griffon': {'vrai positif': 171,
#   'faux positif': 15,
#   'precision': 0.9193548387096774},
#  'Pembroke': {'vrai positif': 214,
#   'faux positif': 54,
#   'precision': 0.7985074626865671},
#  'Cardigan': {'vrai positif': 146,
#   'faux positif': 23,
#   'precision': 0.863905325443787},
#  'toy_poodle': {'vrai positif': 144,
#   'faux positif': 108,
#   'precision': 0.5714285714285714},
#  'miniature_poodle': {'vrai positif': 49,
#   'faux positif': 32,
#   'precision': 0.6049382716049383},
#  'standard_poodle': {'vrai positif': 162,
#   'faux positif': 49,
#   'precision': 0.7677725118483413},
#  'Mexican_hairless': {'vrai positif': 178,
#   'faux positif': 4,
#   'precision': 0.978021978021978},
#  'dingo': {'vrai positif': 167,
#   'faux positif': 20,
#   'precision': 0.893048128342246},
#  'dhole': {'vrai positif': 179,
#   'faux positif': 3,
#   'precision': 0.9835164835164835},
#  'African_hunting_dog': {'vrai positif': 206,
#   'faux positif': 4,
#   'precision': 0.9809523809523809}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 68/68 [==============================] - 9s 129ms/step - loss: 0.5093 - categorical_accuracy: 0.8449
# [0.509300172328949, 0.844939649105072]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# American_Staffordshire_terrier

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 58,585,720
# Trainable params: 58,437,880
# Non-trainable params: 147,840
# _________________________________________________________________

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 87ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 1614 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fabf50c9040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 161ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 1615 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fabe7902af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 384ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 1s 500ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 1s 1s/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)

# %%
model.save('Modele_fine_v3.h5')
