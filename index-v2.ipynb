# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f8b827813a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f8b82905d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet50V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet101V2(
    include_top=False, # Exclude ImageNet classifier at the top
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 7s 0us/step

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x) # Average pooling operation
x = layers.BatchNormalization()(x) # Introduce batch norm
x = layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 345s 737ms/step - loss: 1.8189 - categorical_accuracy: 0.5334 - val_loss: 0.6295 - val_categorical_accuracy: 0.8009
# Epoch 2/25
# 449/449 [==============================] - 330s 735ms/step - loss: 1.1471 - categorical_accuracy: 0.6836 - val_loss: 0.5945 - val_categorical_accuracy: 0.8174
# Epoch 3/25
# 449/449 [==============================] - 326s 725ms/step - loss: 0.9983 - categorical_accuracy: 0.7176 - val_loss: 0.5937 - val_categorical_accuracy: 0.8166
# Epoch 4/25
# 449/449 [==============================] - 328s 730ms/step - loss: 0.9503 - categorical_accuracy: 0.7321 - val_loss: 0.5908 - val_categorical_accuracy: 0.8281
# Epoch 5/25
# 449/449 [==============================] - 324s 721ms/step - loss: 0.8733 - categorical_accuracy: 0.7505 - val_loss: 0.5931 - val_categorical_accuracy: 0.8215
# Epoch 6/25
# 449/449 [==============================] - 327s 727ms/step - loss: 0.8314 - categorical_accuracy: 0.7606 - val_loss: 0.6179 - val_categorical_accuracy: 0.8186
# Epoch 7/25
# 449/449 [==============================] - 328s 730ms/step - loss: 0.8023 - categorical_accuracy: 0.7680 - val_loss: 0.6263 - val_categorical_accuracy: 0.8197
# Epoch 8/25
# 449/449 [==============================] - 329s 732ms/step - loss: 0.7793 - categorical_accuracy: 0.7734 - val_loss: 0.6543 - val_categorical_accuracy: 0.8168
# Epoch 9/25
# 449/449 [==============================] - 326s 726ms/step - loss: 0.7240 - categorical_accuracy: 0.7861 - val_loss: 0.6444 - val_categorical_accuracy: 0.8205

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 267,
#   'faux positif': 66,
#   'precision': 0.8018018018018018},
#  'Japanese_spaniel': {'vrai positif': 401,
#   'faux positif': 71,
#   'precision': 0.8495762711864406},
#  'Maltese_dog': {'vrai positif': 492,
#   'faux positif': 28,
#   'precision': 0.9461538461538461},
#  'Pekinese': {'vrai positif': 292,
#   'faux positif': 20,
#   'precision': 0.9358974358974359},
#  'Shih': {'vrai positif': 299,
#   'faux positif': 71,
#   'precision': 0.8081081081081081},
#  'Blenheim_spaniel': {'vrai positif': 399,
#   'faux positif': 21,
#   'precision': 0.95},
#  'papillon': {'vrai positif': 411,
#   'faux positif': 10,
#   'precision': 0.9762470308788599},
#  'toy_terrier': {'vrai positif': 297,
#   'faux positif': 123,
#   'precision': 0.7071428571428572},
#  'Rhodesian_ridgeback': {'vrai positif': 310,
#   'faux positif': 112,
#   'precision': 0.7345971563981043},
#  'Afghan_hound': {'vrai positif': 526,
#   'faux positif': 26,
#   'precision': 0.9528985507246377},
#  'basset': {'vrai positif': 335,
#   'faux positif': 46,
#   'precision': 0.8792650918635171},
#  'beagle': {'vrai positif': 295,
#   'faux positif': 59,
#   'precision': 0.8333333333333334},
#  'bloodhound': {'vrai positif': 389,
#   'faux positif': 57,
#   'precision': 0.8721973094170403},
#  'bluetick': {'vrai positif': 360,
#   'faux positif': 100,
#   'precision': 0.782608695652174},
#  'black': {'vrai positif': 306,
#   'faux positif': 85,
#   'precision': 0.782608695652174},
#  'Walker_hound': {'vrai positif': 155,
#   'faux positif': 74,
#   'precision': 0.6768558951965066},
#  'English_foxhound': {'vrai positif': 269,
#   'faux positif': 190,
#   'precision': 0.5860566448801743},
#  'redbone': {'vrai positif': 242,
#   'faux positif': 104,
#   'precision': 0.6994219653179191},
#  'borzoi': {'vrai positif': 274,
#   'faux positif': 12,
#   'precision': 0.958041958041958},
#  'Irish_wolfhound': {'vrai positif': 344,
#   'faux positif': 107,
#   'precision': 0.7627494456762749},
#  'Italian_greyhound': {'vrai positif': 332,
#   'faux positif': 126,
#   'precision': 0.7248908296943232},
#  'whippet': {'vrai positif': 290,
#   'faux positif': 40,
#   'precision': 0.8787878787878788},
#  'Ibizan_hound': {'vrai positif': 391,
#   'faux positif': 16,
#   'precision': 0.9606879606879607},
#  'Norwegian_elkhound': {'vrai positif': 401,
#   'faux positif': 5,
#   'precision': 0.9876847290640394},
#  'otterhound': {'vrai positif': 279, 'faux positif': 9, 'precision': 0.96875},
#  'Saluki': {'vrai positif': 376,
#   'faux positif': 44,
#   'precision': 0.8952380952380953},
#  'Scottish_deerhound': {'vrai positif': 410,
#   'faux positif': 137,
#   'precision': 0.7495429616087751},
#  'Weimaraner': {'vrai positif': 297,
#   'faux positif': 11,
#   'precision': 0.9642857142857143},
#  'Staffordshire_bullterrier': {'vrai positif': 213,
#   'faux positif': 111,
#   'precision': 0.6574074074074074},
#  'American_Staffordshire_terrier': {'vrai positif': 277,
#   'faux positif': 164,
#   'precision': 0.6281179138321995},
#  'Bedlington_terrier': {'vrai positif': 376,
#   'faux positif': 22,
#   'precision': 0.9447236180904522},
#  'Border_terrier': {'vrai positif': 372,
#   'faux positif': 14,
#   'precision': 0.9637305699481865},
#  'Kerry_blue_terrier': {'vrai positif': 375,
#   'faux positif': 62,
#   'precision': 0.8581235697940504},
#  'Irish_terrier': {'vrai positif': 332,
#   'faux positif': 43,
#   'precision': 0.8853333333333333},
#  'Norfolk_terrier': {'vrai positif': 278,
#   'faux positif': 124,
#   'precision': 0.6915422885572139},
#  'Norwich_terrier': {'vrai positif': 284,
#   'faux positif': 36,
#   'precision': 0.8875},
#  'Yorkshire_terrier': {'vrai positif': 222,
#   'faux positif': 99,
#   'precision': 0.6915887850467289},
#  'wire': {'vrai positif': 307,
#   'faux positif': 108,
#   'precision': 0.7397590361445783},
#  'Lakeland_terrier': {'vrai positif': 285,
#   'faux positif': 76,
#   'precision': 0.7894736842105263},
#  'Sealyham_terrier': {'vrai positif': 417,
#   'faux positif': 31,
#   'precision': 0.9308035714285714},
#  'Airedale': {'vrai positif': 382,
#   'faux positif': 103,
#   'precision': 0.7876288659793814},
#  'cairn': {'vrai positif': 378,
#   'faux positif': 68,
#   'precision': 0.8475336322869955},
#  'Australian_terrier': {'vrai positif': 364,
#   'faux positif': 165,
#   'precision': 0.6880907372400756},
#  'Dandie_Dinmont': {'vrai positif': 348,
#   'faux positif': 15,
#   'precision': 0.9586776859504132},
#  'Boston_bull': {'vrai positif': 347,
#   'faux positif': 28,
#   'precision': 0.9253333333333333},
#  'miniature_schnauzer': {'vrai positif': 266,
#   'faux positif': 103,
#   'precision': 0.7208672086720868},
#  'giant_schnauzer': {'vrai positif': 320,
#   'faux positif': 200,
#   'precision': 0.6153846153846154},
#  'standard_schnauzer': {'vrai positif': 208,
#   'faux positif': 75,
#   'precision': 0.734982332155477},
#  'Scotch_terrier': {'vrai positif': 310,
#   'faux positif': 29,
#   'precision': 0.9144542772861357},
#  'Tibetan_terrier': {'vrai positif': 399,
#   'faux positif': 167,
#   'precision': 0.7049469964664311},
#  'silky_terrier': {'vrai positif': 290,
#   'faux positif': 175,
#   'precision': 0.6236559139784946},
#  'soft': {'vrai positif': 293,
#   'faux positif': 36,
#   'precision': 0.8905775075987842},
#  'West_Highland_white_terrier': {'vrai positif': 362,
#   'faux positif': 70,
#   'precision': 0.8379629629629629},
#  'Lhasa': {'vrai positif': 319,
#   'faux positif': 216,
#   'precision': 0.5962616822429907},
#  'flat': {'vrai positif': 297,
#   'faux positif': 53,
#   'precision': 0.8485714285714285},
#  'curly': {'vrai positif': 291,
#   'faux positif': 28,
#   'precision': 0.9122257053291536},
#  'golden_retriever': {'vrai positif': 296,
#   'faux positif': 74,
#   'precision': 0.8},
#  'Labrador_retriever': {'vrai positif': 246,
#   'faux positif': 77,
#   'precision': 0.7616099071207431},
#  'Chesapeake_Bay_retriever': {'vrai positif': 325,
#   'faux positif': 102,
#   'precision': 0.7611241217798594},
#  'German_short': {'vrai positif': 276,
#   'faux positif': 12,
#   'precision': 0.9583333333333334},
#  'vizsla': {'vrai positif': 318,
#   'faux positif': 50,
#   'precision': 0.8641304347826086},
#  'English_setter': {'vrai positif': 330,
#   'faux positif': 85,
#   'precision': 0.7951807228915663},
#  'Irish_setter': {'vrai positif': 327,
#   'faux positif': 40,
#   'precision': 0.8910081743869209},
#  'Gordon_setter': {'vrai positif': 324,
#   'faux positif': 9,
#   'precision': 0.972972972972973},
#  'Brittany_spaniel': {'vrai positif': 245,
#   'faux positif': 55,
#   'precision': 0.8166666666666667},
#  'clumber': {'vrai positif': 315,
#   'faux positif': 27,
#   'precision': 0.9210526315789473},
#  'English_springer': {'vrai positif': 351,
#   'faux positif': 113,
#   'precision': 0.7564655172413793},
#  'Welsh_springer_spaniel': {'vrai positif': 308,
#   'faux positif': 41,
#   'precision': 0.8825214899713467},
#  'cocker_spaniel': {'vrai positif': 228,
#   'faux positif': 41,
#   'precision': 0.8475836431226765},
#  'Sussex_spaniel': {'vrai positif': 332,
#   'faux positif': 36,
#   'precision': 0.9021739130434783},
#  'Irish_water_spaniel': {'vrai positif': 294,
#   'faux positif': 47,
#   'precision': 0.8621700879765396},
#  'kuvasz': {'vrai positif': 261,
#   'faux positif': 91,
#   'precision': 0.7414772727272727},
#  'schipperke': {'vrai positif': 315,
#   'faux positif': 22,
#   'precision': 0.9347181008902077},
#  'groenendael': {'vrai positif': 312,
#   'faux positif': 22,
#   'precision': 0.9341317365269461},
#  'malinois': {'vrai positif': 271,
#   'faux positif': 48,
#   'precision': 0.8495297805642633},
#  'briard': {'vrai positif': 251,
#   'faux positif': 46,
#   'precision': 0.8451178451178452},
#  'kelpie': {'vrai positif': 286,
#   'faux positif': 110,
#   'precision': 0.7222222222222222},
#  'komondor': {'vrai positif': 318,
#   'faux positif': 25,
#   'precision': 0.9271137026239067},
#  'Old_English_sheepdog': {'vrai positif': 348,
#   'faux positif': 34,
#   'precision': 0.9109947643979057},
#  'Shetland_sheepdog': {'vrai positif': 293,
#   'faux positif': 53,
#   'precision': 0.846820809248555},
#  'collie': {'vrai positif': 178,
#   'faux positif': 99,
#   'precision': 0.6425992779783394},
#  'Border_collie': {'vrai positif': 261,
#   'faux positif': 138,
#   'precision': 0.6541353383458647},
#  'Bouvier_des_Flandres': {'vrai positif': 238,
#   'faux positif': 40,
#   'precision': 0.8561151079136691},
#  'Rottweiler': {'vrai positif': 302,
#   'faux positif': 21,
#   'precision': 0.934984520123839},
#  'German_shepherd': {'vrai positif': 311,
#   'faux positif': 70,
#   'precision': 0.8162729658792651},
#  'Doberman': {'vrai positif': 296,
#   'faux positif': 63,
#   'precision': 0.8245125348189415},
#  'miniature_pinscher': {'vrai positif': 321,
#   'faux positif': 66,
#   'precision': 0.8294573643410853},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 288,
#   'faux positif': 122,
#   'precision': 0.7024390243902439},
#  'Bernese_mountain_dog': {'vrai positif': 453,
#   'faux positif': 37,
#   'precision': 0.9244897959183673},
#  'Appenzeller': {'vrai positif': 222,
#   'faux positif': 135,
#   'precision': 0.6218487394957983},
#  'EntleBucher': {'vrai positif': 338,
#   'faux positif': 114,
#   'precision': 0.7477876106194691},
#  'boxer': {'vrai positif': 238,
#   'faux positif': 20,
#   'precision': 0.9224806201550387},
#  'bull_mastiff': {'vrai positif': 324,
#   'faux positif': 85,
#   'precision': 0.7921760391198044},
#  'Tibetan_mastiff': {'vrai positif': 291,
#   'faux positif': 50,
#   'precision': 0.8533724340175953},
#  'French_bulldog': {'vrai positif': 323,
#   'faux positif': 118,
#   'precision': 0.7324263038548753},
#  'Great_Dane': {'vrai positif': 263,
#   'faux positif': 66,
#   'precision': 0.7993920972644377},
#  'Saint_Bernard': {'vrai positif': 361,
#   'faux positif': 28,
#   'precision': 0.9280205655526992},
#  'Eskimo_dog': {'vrai positif': 242,
#   'faux positif': 356,
#   'precision': 0.40468227424749165},
#  'malamute': {'vrai positif': 284,
#   'faux positif': 80,
#   'precision': 0.7802197802197802},
#  'Siberian_husky': {'vrai positif': 133,
#   'faux positif': 64,
#   'precision': 0.6751269035532995},
#  'affenpinscher': {'vrai positif': 299,
#   'faux positif': 57,
#   'precision': 0.8398876404494382},
#  'basenji': {'vrai positif': 398,
#   'faux positif': 23,
#   'precision': 0.9453681710213777},
#  'pug': {'vrai positif': 376,
#   'faux positif': 17,
#   'precision': 0.9567430025445293},
#  'Leonberg': {'vrai positif': 448,
#   'faux positif': 12,
#   'precision': 0.9739130434782609},
#  'Newfoundland': {'vrai positif': 378,
#   'faux positif': 113,
#   'precision': 0.769857433808554},
#  'Great_Pyrenees': {'vrai positif': 363,
#   'faux positif': 67,
#   'precision': 0.8441860465116279},
#  'Samoyed': {'vrai positif': 469,
#   'faux positif': 24,
#   'precision': 0.9513184584178499},
#  'Pomeranian': {'vrai positif': 477,
#   'faux positif': 31,
#   'precision': 0.9389763779527559},
#  'chow': {'vrai positif': 415,
#   'faux positif': 7,
#   'precision': 0.9834123222748815},
#  'keeshond': {'vrai positif': 356,
#   'faux positif': 6,
#   'precision': 0.9834254143646409},
#  'Brabancon_griffon': {'vrai positif': 316,
#   'faux positif': 22,
#   'precision': 0.9349112426035503},
#  'Pembroke': {'vrai positif': 315, 'faux positif': 60, 'precision': 0.84},
#  'Cardigan': {'vrai positif': 281,
#   'faux positif': 101,
#   'precision': 0.7356020942408377},
#  'toy_poodle': {'vrai positif': 145, 'faux positif': 105, 'precision': 0.58},
#  'miniature_poodle': {'vrai positif': 156,
#   'faux positif': 183,
#   'precision': 0.46017699115044247},
#  'standard_poodle': {'vrai positif': 266,
#   'faux positif': 190,
#   'precision': 0.5833333333333334},
#  'Mexican_hairless': {'vrai positif': 333,
#   'faux positif': 14,
#   'precision': 0.9596541786743515},
#  'dingo': {'vrai positif': 254,
#   'faux positif': 77,
#   'precision': 0.7673716012084593},
#  'dhole': {'vrai positif': 331,
#   'faux positif': 57,
#   'precision': 0.8530927835051546},
#  'African_hunting_dog': {'vrai positif': 365,
#   'faux positif': 14,
#   'precision': 0.9630606860158312}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 6s 186ms/step - loss: 0.5918 - categorical_accuracy: 0.8375
# [0.5917617678642273, 0.8375115990638733]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
base_model.trainable = True
print(len(model.trainable_variables))
print("Number of layers in the base model: ", len(base_model.layers))
# base_model.summary()
# Out:
# 346
# Number of layers in the base model:  377

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in base_model.layers[:360]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = False
        
len(model.trainable_variables)
# Out:
# 210

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 9/13
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-07 20:04:03.321766: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.321814: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.347836: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.347872: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.938369: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.938414: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.956663: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:03.956703: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:04.495223: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-07 20:04:04.495279: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 449/449 [==============================] - 466s 987ms/step - loss: 0.7954 - categorical_accuracy: 0.7654 - val_loss: 0.5484 - val_categorical_accuracy: 0.8417
# Epoch 10/13
# 449/449 [==============================] - 421s 937ms/step - loss: 0.7198 - categorical_accuracy: 0.7840 - val_loss: 0.5381 - val_categorical_accuracy: 0.8432
# Epoch 11/13
# 449/449 [==============================] - 419s 933ms/step - loss: 0.6903 - categorical_accuracy: 0.7893 - val_loss: 0.5352 - val_categorical_accuracy: 0.8425
# Epoch 12/13
# 449/449 [==============================] - 420s 936ms/step - loss: 0.6415 - categorical_accuracy: 0.8052 - val_loss: 0.5299 - val_categorical_accuracy: 0.8429
# Epoch 13/13
# 449/449 [==============================] - 419s 933ms/step - loss: 0.6079 - categorical_accuracy: 0.8119 - val_loss: 0.5293 - val_categorical_accuracy: 0.8413

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 148,
#   'faux positif': 44,
#   'precision': 0.7708333333333334},
#  'Japanese_spaniel': {'vrai positif': 220,
#   'faux positif': 20,
#   'precision': 0.9166666666666666},
#  'Maltese_dog': {'vrai positif': 287,
#   'faux positif': 21,
#   'precision': 0.9318181818181818},
#  'Pekinese': {'vrai positif': 170,
#   'faux positif': 12,
#   'precision': 0.9340659340659341},
#  'Shih': {'vrai positif': 188,
#   'faux positif': 40,
#   'precision': 0.8245614035087719},
#  'Blenheim_spaniel': {'vrai positif': 230,
#   'faux positif': 8,
#   'precision': 0.9663865546218487},
#  'papillon': {'vrai positif': 235,
#   'faux positif': 9,
#   'precision': 0.9631147540983607},
#  'toy_terrier': {'vrai positif': 161,
#   'faux positif': 59,
#   'precision': 0.7318181818181818},
#  'Rhodesian_ridgeback': {'vrai positif': 174,
#   'faux positif': 61,
#   'precision': 0.7404255319148936},
#  'Afghan_hound': {'vrai positif': 299,
#   'faux positif': 22,
#   'precision': 0.9314641744548287},
#  'basset': {'vrai positif': 190,
#   'faux positif': 26,
#   'precision': 0.8796296296296297},
#  'beagle': {'vrai positif': 203,
#   'faux positif': 42,
#   'precision': 0.8285714285714286},
#  'bloodhound': {'vrai positif': 220,
#   'faux positif': 29,
#   'precision': 0.8835341365461847},
#  'bluetick': {'vrai positif': 206,
#   'faux positif': 23,
#   'precision': 0.8995633187772926},
#  'black': {'vrai positif': 174,
#   'faux positif': 41,
#   'precision': 0.8093023255813954},
#  'Walker_hound': {'vrai positif': 102,
#   'faux positif': 35,
#   'precision': 0.7445255474452555},
#  'English_foxhound': {'vrai positif': 147,
#   'faux positif': 71,
#   'precision': 0.6743119266055045},
#  'redbone': {'vrai positif': 136,
#   'faux positif': 32,
#   'precision': 0.8095238095238095},
#  'borzoi': {'vrai positif': 168,
#   'faux positif': 5,
#   'precision': 0.9710982658959537},
#  'Irish_wolfhound': {'vrai positif': 180,
#   'faux positif': 40,
#   'precision': 0.8181818181818182},
#  'Italian_greyhound': {'vrai positif': 164,
#   'faux positif': 53,
#   'precision': 0.7557603686635944},
#  'whippet': {'vrai positif': 180,
#   'faux positif': 33,
#   'precision': 0.8450704225352113},
#  'Ibizan_hound': {'vrai positif': 211,
#   'faux positif': 10,
#   'precision': 0.9547511312217195},
#  'Norwegian_elkhound': {'vrai positif': 231,
#   'faux positif': 14,
#   'precision': 0.9428571428571428},
#  'otterhound': {'vrai positif': 156,
#   'faux positif': 12,
#   'precision': 0.9285714285714286},
#  'Saluki': {'vrai positif': 215,
#   'faux positif': 16,
#   'precision': 0.9307359307359307},
#  'Scottish_deerhound': {'vrai positif': 237,
#   'faux positif': 83,
#   'precision': 0.740625},
#  'Weimaraner': {'vrai positif': 177,
#   'faux positif': 6,
#   'precision': 0.9672131147540983},
#  'Staffordshire_bullterrier': {'vrai positif': 136,
#   'faux positif': 92,
#   'precision': 0.5964912280701754},
#  'American_Staffordshire_terrier': {'vrai positif': 131,
#   'faux positif': 69,
#   'precision': 0.655},
#  'Bedlington_terrier': {'vrai positif': 211,
#   'faux positif': 11,
#   'precision': 0.9504504504504504},
#  'Border_terrier': {'vrai positif': 203,
#   'faux positif': 5,
#   'precision': 0.9759615384615384},
#  'Kerry_blue_terrier': {'vrai positif': 201,
#   'faux positif': 20,
#   'precision': 0.9095022624434389},
#  'Irish_terrier': {'vrai positif': 189,
#   'faux positif': 24,
#   'precision': 0.8873239436619719},
#  'Norfolk_terrier': {'vrai positif': 153,
#   'faux positif': 61,
#   'precision': 0.7149532710280374},
#  'Norwich_terrier': {'vrai positif': 194,
#   'faux positif': 40,
#   'precision': 0.8290598290598291},
#  'Yorkshire_terrier': {'vrai positif': 150,
#   'faux positif': 77,
#   'precision': 0.6607929515418502},
#  'wire': {'vrai positif': 165,
#   'faux positif': 24,
#   'precision': 0.873015873015873},
#  'Lakeland_terrier': {'vrai positif': 193,
#   'faux positif': 53,
#   'precision': 0.7845528455284553},
#  'Sealyham_terrier': {'vrai positif': 234,
#   'faux positif': 17,
#   'precision': 0.9322709163346613},
#  'Airedale': {'vrai positif': 216,
#   'faux positif': 52,
#   'precision': 0.8059701492537313},
#  'cairn': {'vrai positif': 212,
#   'faux positif': 30,
#   'precision': 0.8760330578512396},
#  'Australian_terrier': {'vrai positif': 202,
#   'faux positif': 55,
#   'precision': 0.7859922178988327},
#  'Dandie_Dinmont': {'vrai positif': 208,
#   'faux positif': 11,
#   'precision': 0.9497716894977168},
#  'Boston_bull': {'vrai positif': 210,
#   'faux positif': 20,
#   'precision': 0.9130434782608695},
#  'miniature_schnauzer': {'vrai positif': 157,
#   'faux positif': 59,
#   'precision': 0.7268518518518519},
#  'giant_schnauzer': {'vrai positif': 173,
#   'faux positif': 68,
#   'precision': 0.7178423236514523},
#  'standard_schnauzer': {'vrai positif': 123,
#   'faux positif': 44,
#   'precision': 0.7365269461077845},
#  'Scotch_terrier': {'vrai positif': 180,
#   'faux positif': 12,
#   'precision': 0.9375},
#  'Tibetan_terrier': {'vrai positif': 201,
#   'faux positif': 56,
#   'precision': 0.7821011673151751},
#  'silky_terrier': {'vrai positif': 164,
#   'faux positif': 54,
#   'precision': 0.7522935779816514},
#  'soft': {'vrai positif': 175,
#   'faux positif': 22,
#   'precision': 0.8883248730964467},
#  'West_Highland_white_terrier': {'vrai positif': 205,
#   'faux positif': 43,
#   'precision': 0.8266129032258065},
#  'Lhasa': {'vrai positif': 188,
#   'faux positif': 97,
#   'precision': 0.6596491228070176},
#  'flat': {'vrai positif': 166,
#   'faux positif': 28,
#   'precision': 0.8556701030927835},
#  'curly': {'vrai positif': 174,
#   'faux positif': 19,
#   'precision': 0.9015544041450777},
#  'golden_retriever': {'vrai positif': 168,
#   'faux positif': 44,
#   'precision': 0.7924528301886793},
#  'Labrador_retriever': {'vrai positif': 154,
#   'faux positif': 43,
#   'precision': 0.7817258883248731},
#  'Chesapeake_Bay_retriever': {'vrai positif': 183,
#   'faux positif': 33,
#   'precision': 0.8472222222222222},
#  'German_short': {'vrai positif': 172,
#   'faux positif': 4,
#   'precision': 0.9772727272727273},
#  'vizsla': {'vrai positif': 182,
#   'faux positif': 30,
#   'precision': 0.8584905660377359},
#  'English_setter': {'vrai positif': 179,
#   'faux positif': 33,
#   'precision': 0.8443396226415094},
#  'Irish_setter': {'vrai positif': 187, 'faux positif': 13, 'precision': 0.935},
#  'Gordon_setter': {'vrai positif': 176,
#   'faux positif': 5,
#   'precision': 0.9723756906077348},
#  'Brittany_spaniel': {'vrai positif': 149,
#   'faux positif': 37,
#   'precision': 0.8010752688172043},
#  'clumber': {'vrai positif': 175,
#   'faux positif': 5,
#   'precision': 0.9722222222222222},
#  'English_springer': {'vrai positif': 193,
#   'faux positif': 45,
#   'precision': 0.8109243697478992},
#  'Welsh_springer_spaniel': {'vrai positif': 172,
#   'faux positif': 19,
#   'precision': 0.900523560209424},
#  'cocker_spaniel': {'vrai positif': 145,
#   'faux positif': 34,
#   'precision': 0.8100558659217877},
#  'Sussex_spaniel': {'vrai positif': 185,
#   'faux positif': 14,
#   'precision': 0.9296482412060302},
#  'Irish_water_spaniel': {'vrai positif': 169,
#   'faux positif': 20,
#   'precision': 0.8941798941798942},
#  'kuvasz': {'vrai positif': 143,
#   'faux positif': 26,
#   'precision': 0.8461538461538461},
#  'schipperke': {'vrai positif': 185,
#   'faux positif': 30,
#   'precision': 0.8604651162790697},
#  'groenendael': {'vrai positif': 170,
#   'faux positif': 3,
#   'precision': 0.9826589595375722},
#  'malinois': {'vrai positif': 157,
#   'faux positif': 20,
#   'precision': 0.8870056497175142},
#  'briard': {'vrai positif': 150,
#   'faux positif': 27,
#   'precision': 0.847457627118644},
#  'kelpie': {'vrai positif': 149,
#   'faux positif': 35,
#   'precision': 0.8097826086956522},
#  'komondor': {'vrai positif': 175,
#   'faux positif': 12,
#   'precision': 0.9358288770053476},
#  'Old_English_sheepdog': {'vrai positif': 195,
#   'faux positif': 15,
#   'precision': 0.9285714285714286},
#  'Shetland_sheepdog': {'vrai positif': 155,
#   'faux positif': 18,
#   'precision': 0.8959537572254336},
#  'collie': {'vrai positif': 107,
#   'faux positif': 81,
#   'precision': 0.5691489361702128},
#  'Border_collie': {'vrai positif': 140,
#   'faux positif': 72,
#   'precision': 0.660377358490566},
#  'Bouvier_des_Flandres': {'vrai positif': 153,
#   'faux positif': 45,
#   'precision': 0.7727272727272727},
#  'Rottweiler': {'vrai positif': 173,
#   'faux positif': 13,
#   'precision': 0.9301075268817204},
#  'German_shepherd': {'vrai positif': 173,
#   'faux positif': 32,
#   'precision': 0.8439024390243902},
#  'Doberman': {'vrai positif': 154,
#   'faux positif': 9,
#   'precision': 0.9447852760736196},
#  'miniature_pinscher': {'vrai positif': 200,
#   'faux positif': 48,
#   'precision': 0.8064516129032258},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 158,
#   'faux positif': 23,
#   'precision': 0.8729281767955801},
#  'Bernese_mountain_dog': {'vrai positif': 250,
#   'faux positif': 10,
#   'precision': 0.9615384615384616},
#  'Appenzeller': {'vrai positif': 131,
#   'faux positif': 60,
#   'precision': 0.6858638743455497},
#  'EntleBucher': {'vrai positif': 209,
#   'faux positif': 97,
#   'precision': 0.6830065359477124},
#  'boxer': {'vrai positif': 154,
#   'faux positif': 19,
#   'precision': 0.8901734104046243},
#  'bull_mastiff': {'vrai positif': 170,
#   'faux positif': 24,
#   'precision': 0.8762886597938144},
#  'Tibetan_mastiff': {'vrai positif': 158,
#   'faux positif': 7,
#   'precision': 0.9575757575757575},
#  'French_bulldog': {'vrai positif': 174,
#   'faux positif': 26,
#   'precision': 0.87},
#  'Great_Dane': {'vrai positif': 149,
#   'faux positif': 37,
#   'precision': 0.8010752688172043},
#  'Saint_Bernard': {'vrai positif': 200,
#   'faux positif': 10,
#   'precision': 0.9523809523809523},
#  'Eskimo_dog': {'vrai positif': 70,
#   'faux positif': 74,
#   'precision': 0.4861111111111111},
#  'malamute': {'vrai positif': 176,
#   'faux positif': 59,
#   'precision': 0.7489361702127659},
#  'Siberian_husky': {'vrai positif': 143,
#   'faux positif': 114,
#   'precision': 0.556420233463035},
#  'affenpinscher': {'vrai positif': 159,
#   'faux positif': 11,
#   'precision': 0.9352941176470588},
#  'basenji': {'vrai positif': 225,
#   'faux positif': 12,
#   'precision': 0.9493670886075949},
#  'pug': {'vrai positif': 229,
#   'faux positif': 10,
#   'precision': 0.9581589958158996},
#  'Leonberg': {'vrai positif': 250,
#   'faux positif': 21,
#   'precision': 0.922509225092251},
#  'Newfoundland': {'vrai positif': 223,
#   'faux positif': 57,
#   'precision': 0.7964285714285714},
#  'Great_Pyrenees': {'vrai positif': 227,
#   'faux positif': 50,
#   'precision': 0.8194945848375451},
#  'Samoyed': {'vrai positif': 270,
#   'faux positif': 11,
#   'precision': 0.9608540925266904},
#  'Pomeranian': {'vrai positif': 264,
#   'faux positif': 3,
#   'precision': 0.9887640449438202},
#  'chow': {'vrai positif': 238, 'faux positif': 0, 'precision': 1.0},
#  'keeshond': {'vrai positif': 200, 'faux positif': 0, 'precision': 1.0},
#  'Brabancon_griffon': {'vrai positif': 176,
#   'faux positif': 10,
#   'precision': 0.946236559139785},
#  'Pembroke': {'vrai positif': 191,
#   'faux positif': 53,
#   'precision': 0.7827868852459017},
#  'Cardigan': {'vrai positif': 142,
#   'faux positif': 47,
#   'precision': 0.7513227513227513},
#  'toy_poodle': {'vrai positif': 80,
#   'faux positif': 47,
#   'precision': 0.6299212598425197},
#  'miniature_poodle': {'vrai positif': 101,
#   'faux positif': 104,
#   'precision': 0.4926829268292683},
#  'standard_poodle': {'vrai positif': 149,
#   'faux positif': 80,
#   'precision': 0.6506550218340611},
#  'Mexican_hairless': {'vrai positif': 186,
#   'faux positif': 5,
#   'precision': 0.9738219895287958},
#  'dingo': {'vrai positif': 149,
#   'faux positif': 62,
#   'precision': 0.7061611374407583},
#  'dhole': {'vrai positif': 183,
#   'faux positif': 12,
#   'precision': 0.9384615384615385},
#  'African_hunting_dog': {'vrai positif': 205,
#   'faux positif': 10,
#   'precision': 0.9534883720930233}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 150ms/step - loss: 0.5415 - categorical_accuracy: 0.8449
# [0.5415120720863342, 0.844939649105072]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# American_Staffordshire_terrier

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 42,880,632
# Trainable params: 5,856,760
# Non-trainable params: 37,023,872
# _________________________________________________________________

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        # plt.imsave(f'results_{name_image}/{name_image}_{layer_name}_{i}.jpg',f[0,:,:,i])
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 72ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 649 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8a6a077ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 119ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 650 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8a697b7dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 202ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 0s 297ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 1s 773ms/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)

# %% [markdown]
# A faire : visualiser les features map optionnel

# %%
model.save('Modele_fine_v2.h5')
