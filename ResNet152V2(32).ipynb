# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fe2854693a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fe2853af8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet152V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet152V2(
    include_top=False, # Exclude ImageNet classifier at the top
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x) # Average pooling operation
x = layers.BatchNormalization()(x) # Introduce batch norm
x = layers.Dropout(0.8)(x)  # Regularize with dropout
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True,
     min_delta = 0.01
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 397s 864ms/step - loss: 3.7911 - categorical_accuracy: 0.2904 - val_loss: 0.5989 - val_categorical_accuracy: 0.8162
# Epoch 2/25
# 449/449 [==============================] - 405s 903ms/step - loss: 2.2564 - categorical_accuracy: 0.5026 - val_loss: 0.5380 - val_categorical_accuracy: 0.8341
# Epoch 3/25
# 449/449 [==============================] - 399s 888ms/step - loss: 2.0160 - categorical_accuracy: 0.5554 - val_loss: 0.5217 - val_categorical_accuracy: 0.8405
# Epoch 4/25
# 449/449 [==============================] - 395s 880ms/step - loss: 1.9475 - categorical_accuracy: 0.5749 - val_loss: 0.5169 - val_categorical_accuracy: 0.8452
# Epoch 5/25
# 449/449 [==============================] - 394s 878ms/step - loss: 1.8986 - categorical_accuracy: 0.5886 - val_loss: 0.4967 - val_categorical_accuracy: 0.8563
# Epoch 6/25
# 449/449 [==============================] - 392s 873ms/step - loss: 1.8426 - categorical_accuracy: 0.5900 - val_loss: 0.4949 - val_categorical_accuracy: 0.8539
# Epoch 7/25
# 449/449 [==============================] - 393s 875ms/step - loss: 1.7715 - categorical_accuracy: 0.6082 - val_loss: 0.4913 - val_categorical_accuracy: 0.8561
# Epoch 8/25
# 449/449 [==============================] - 394s 878ms/step - loss: 1.7269 - categorical_accuracy: 0.6121 - val_loss: 0.4969 - val_categorical_accuracy: 0.8506
# Epoch 9/25
# 449/449 [==============================] - 387s 863ms/step - loss: 1.6803 - categorical_accuracy: 0.6168 - val_loss: 0.4827 - val_categorical_accuracy: 0.8537
# Epoch 10/25
# 449/449 [==============================] - 380s 847ms/step - loss: 1.6767 - categorical_accuracy: 0.6178 - val_loss: 0.4893 - val_categorical_accuracy: 0.8553
# Epoch 11/25
# 449/449 [==============================] - 380s 847ms/step - loss: 1.6177 - categorical_accuracy: 0.6270 - val_loss: 0.4746 - val_categorical_accuracy: 0.8497
# Epoch 12/25
# 449/449 [==============================] - 379s 845ms/step - loss: 1.5926 - categorical_accuracy: 0.6215 - val_loss: 0.4672 - val_categorical_accuracy: 0.8564
# Epoch 13/25
# 449/449 [==============================] - 381s 848ms/step - loss: 1.5449 - categorical_accuracy: 0.6308 - val_loss: 0.4672 - val_categorical_accuracy: 0.8574
# Epoch 14/25
# 449/449 [==============================] - 381s 849ms/step - loss: 1.4944 - categorical_accuracy: 0.6306 - val_loss: 0.4645 - val_categorical_accuracy: 0.8561
# Epoch 15/25
# 449/449 [==============================] - 384s 855ms/step - loss: 1.4715 - categorical_accuracy: 0.6325 - val_loss: 0.4478 - val_categorical_accuracy: 0.8615
# Epoch 16/25
# 449/449 [==============================] - 380s 847ms/step - loss: 1.4449 - categorical_accuracy: 0.6389 - val_loss: 0.4476 - val_categorical_accuracy: 0.8584
# Epoch 17/25
# 449/449 [==============================] - 380s 846ms/step - loss: 1.4260 - categorical_accuracy: 0.6416 - val_loss: 0.4484 - val_categorical_accuracy: 0.8603
# Epoch 18/25
# 449/449 [==============================] - 380s 846ms/step - loss: 1.3649 - categorical_accuracy: 0.6460 - val_loss: 0.4446 - val_categorical_accuracy: 0.8586
# Epoch 19/25
# 449/449 [==============================] - 381s 849ms/step - loss: 1.3542 - categorical_accuracy: 0.6452 - val_loss: 0.4349 - val_categorical_accuracy: 0.8646
# Epoch 20/25
# 449/449 [==============================] - 379s 844ms/step - loss: 1.3160 - categorical_accuracy: 0.6499 - val_loss: 0.4441 - val_categorical_accuracy: 0.8566
# Epoch 21/25
# 449/449 [==============================] - 379s 845ms/step - loss: 1.2890 - categorical_accuracy: 0.6523 - val_loss: 0.4360 - val_categorical_accuracy: 0.8640
# Epoch 22/25
# 449/449 [==============================] - 380s 846ms/step - loss: 1.2831 - categorical_accuracy: 0.6560 - val_loss: 0.4325 - val_categorical_accuracy: 0.8619
# Epoch 23/25
# 449/449 [==============================] - 379s 845ms/step - loss: 1.2416 - categorical_accuracy: 0.6555 - val_loss: 0.4320 - val_categorical_accuracy: 0.8646
# Epoch 24/25
# 449/449 [==============================] - 381s 849ms/step - loss: 1.2230 - categorical_accuracy: 0.6619 - val_loss: 0.4313 - val_categorical_accuracy: 0.8636

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 737,
#   'faux positif': 62,
#   'precision': 0.9224030037546934},
#  'Japanese_spaniel': {'vrai positif': 1073,
#   'faux positif': 163,
#   'precision': 0.8681229773462783},
#  'Maltese_dog': {'vrai positif': 1347,
#   'faux positif': 261,
#   'precision': 0.8376865671641791},
#  'Pekinese': {'vrai positif': 725,
#   'faux positif': 59,
#   'precision': 0.9247448979591837},
#  'Shih': {'vrai positif': 947,
#   'faux positif': 257,
#   'precision': 0.7865448504983389},
#  'Blenheim_spaniel': {'vrai positif': 1094,
#   'faux positif': 56,
#   'precision': 0.951304347826087},
#  'papillon': {'vrai positif': 1160,
#   'faux positif': 24,
#   'precision': 0.9797297297297297},
#  'toy_terrier': {'vrai positif': 826,
#   'faux positif': 165,
#   'precision': 0.8335015136226034},
#  'Rhodesian_ridgeback': {'vrai positif': 801,
#   'faux positif': 181,
#   'precision': 0.8156822810590632},
#  'Afghan_hound': {'vrai positif': 1405,
#   'faux positif': 23,
#   'precision': 0.9838935574229691},
#  'basset': {'vrai positif': 975,
#   'faux positif': 221,
#   'precision': 0.8152173913043478},
#  'beagle': {'vrai positif': 982,
#   'faux positif': 240,
#   'precision': 0.8036006546644845},
#  'bloodhound': {'vrai positif': 1027,
#   'faux positif': 105,
#   'precision': 0.907243816254417},
#  'bluetick': {'vrai positif': 925,
#   'faux positif': 43,
#   'precision': 0.9555785123966942},
#  'black': {'vrai positif': 856,
#   'faux positif': 89,
#   'precision': 0.9058201058201059},
#  'Walker_hound': {'vrai positif': 586,
#   'faux positif': 257,
#   'precision': 0.6951364175563464},
#  'English_foxhound': {'vrai positif': 616,
#   'faux positif': 254,
#   'precision': 0.7080459770114943},
#  'redbone': {'vrai positif': 741,
#   'faux positif': 159,
#   'precision': 0.8233333333333334},
#  'borzoi': {'vrai positif': 845,
#   'faux positif': 109,
#   'precision': 0.8857442348008385},
#  'Irish_wolfhound': {'vrai positif': 884,
#   'faux positif': 218,
#   'precision': 0.8021778584392014},
#  'Italian_greyhound': {'vrai positif': 880,
#   'faux positif': 172,
#   'precision': 0.8365019011406845},
#  'whippet': {'vrai positif': 817,
#   'faux positif': 158,
#   'precision': 0.837948717948718},
#  'Ibizan_hound': {'vrai positif': 1017,
#   'faux positif': 129,
#   'precision': 0.887434554973822},
#  'Norwegian_elkhound': {'vrai positif': 1145,
#   'faux positif': 43,
#   'precision': 0.9638047138047138},
#  'otterhound': {'vrai positif': 789,
#   'faux positif': 111,
#   'precision': 0.8766666666666667},
#  'Saluki': {'vrai positif': 1093,
#   'faux positif': 101,
#   'precision': 0.9154103852596315},
#  'Scottish_deerhound': {'vrai positif': 1248,
#   'faux positif': 439,
#   'precision': 0.7397747480735033},
#  'Weimaraner': {'vrai positif': 892,
#   'faux positif': 25,
#   'precision': 0.9727371864776445},
#  'Staffordshire_bullterrier': {'vrai positif': 597,
#   'faux positif': 109,
#   'precision': 0.8456090651558074},
#  'American_Staffordshire_terrier': {'vrai positif': 824,
#   'faux positif': 382,
#   'precision': 0.6832504145936982},
#  'Bedlington_terrier': {'vrai positif': 1075,
#   'faux positif': 33,
#   'precision': 0.970216606498195},
#  'Border_terrier': {'vrai positif': 1005,
#   'faux positif': 39,
#   'precision': 0.9626436781609196},
#  'Kerry_blue_terrier': {'vrai positif': 968,
#   'faux positif': 42,
#   'precision': 0.9584158415841584},
#  'Irish_terrier': {'vrai positif': 958,
#   'faux positif': 160,
#   'precision': 0.8568872987477638},
#  'Norfolk_terrier': {'vrai positif': 766,
#   'faux positif': 203,
#   'precision': 0.7905056759545923},
#  'Norwich_terrier': {'vrai positif': 938,
#   'faux positif': 296,
#   'precision': 0.7601296596434359},
#  'Yorkshire_terrier': {'vrai positif': 853,
#   'faux positif': 200,
#   'precision': 0.8100664767331434},
#  'wire': {'vrai positif': 665,
#   'faux positif': 90,
#   'precision': 0.8807947019867549},
#  'Lakeland_terrier': {'vrai positif': 910,
#   'faux positif': 197,
#   'precision': 0.8220415537488708},
#  'Sealyham_terrier': {'vrai positif': 1106,
#   'faux positif': 93,
#   'precision': 0.9224353628023353},
#  'Airedale': {'vrai positif': 1107,
#   'faux positif': 294,
#   'precision': 0.7901498929336188},
#  'cairn': {'vrai positif': 1015,
#   'faux positif': 86,
#   'precision': 0.92188919164396},
#  'Australian_terrier': {'vrai positif': 958,
#   'faux positif': 243,
#   'precision': 0.79766860949209},
#  'Dandie_Dinmont': {'vrai positif': 1039,
#   'faux positif': 119,
#   'precision': 0.8972366148531952},
#  'Boston_bull': {'vrai positif': 1052,
#   'faux positif': 113,
#   'precision': 0.9030042918454936},
#  'miniature_schnauzer': {'vrai positif': 717,
#   'faux positif': 228,
#   'precision': 0.7587301587301587},
#  'giant_schnauzer': {'vrai positif': 748,
#   'faux positif': 375,
#   'precision': 0.666073018699911},
#  'standard_schnauzer': {'vrai positif': 619,
#   'faux positif': 158,
#   'precision': 0.7966537966537967},
#  'Scotch_terrier': {'vrai positif': 940,
#   'faux positif': 132,
#   'precision': 0.8768656716417911},
#  'Tibetan_terrier': {'vrai positif': 895,
#   'faux positif': 167,
#   'precision': 0.8427495291902072},
#  'silky_terrier': {'vrai positif': 841,
#   'faux positif': 218,
#   'precision': 0.7941454202077431},
#  'soft': {'vrai positif': 791,
#   'faux positif': 132,
#   'precision': 0.856988082340195},
#  'West_Highland_white_terrier': {'vrai positif': 951,
#   'faux positif': 237,
#   'precision': 0.8005050505050505},
#  'Lhasa': {'vrai positif': 794,
#   'faux positif': 231,
#   'precision': 0.7746341463414634},
#  'flat': {'vrai positif': 777,
#   'faux positif': 225,
#   'precision': 0.7754491017964071},
#  'curly': {'vrai positif': 820,
#   'faux positif': 190,
#   'precision': 0.8118811881188119},
#  'golden_retriever': {'vrai positif': 839,
#   'faux positif': 84,
#   'precision': 0.9089924160346695},
#  'Labrador_retriever': {'vrai positif': 893,
#   'faux positif': 144,
#   'precision': 0.8611378977820636},
#  'Chesapeake_Bay_retriever': {'vrai positif': 882,
#   'faux positif': 64,
#   'precision': 0.9323467230443975},
#  'German_short': {'vrai positif': 828,
#   'faux positif': 103,
#   'precision': 0.8893662728249194},
#  'vizsla': {'vrai positif': 873,
#   'faux positif': 174,
#   'precision': 0.833810888252149},
#  'English_setter': {'vrai positif': 712,
#   'faux positif': 51,
#   'precision': 0.9331585845347313},
#  'Irish_setter': {'vrai positif': 913,
#   'faux positif': 94,
#   'precision': 0.9066534260178749},
#  'Gordon_setter': {'vrai positif': 890,
#   'faux positif': 80,
#   'precision': 0.9175257731958762},
#  'Brittany_spaniel': {'vrai positif': 748,
#   'faux positif': 152,
#   'precision': 0.8311111111111111},
#  'clumber': {'vrai positif': 887,
#   'faux positif': 165,
#   'precision': 0.8431558935361216},
#  'English_springer': {'vrai positif': 891,
#   'faux positif': 152,
#   'precision': 0.8542665388302972},
#  'Welsh_springer_spaniel': {'vrai positif': 814,
#   'faux positif': 167,
#   'precision': 0.8297655453618756},
#  'cocker_spaniel': {'vrai positif': 668,
#   'faux positif': 45,
#   'precision': 0.9368863955119214},
#  'Sussex_spaniel': {'vrai positif': 823,
#   'faux positif': 14,
#   'precision': 0.983273596176822},
#  'Irish_water_spaniel': {'vrai positif': 760,
#   'faux positif': 45,
#   'precision': 0.9440993788819876},
#  'kuvasz': {'vrai positif': 747,
#   'faux positif': 167,
#   'precision': 0.8172866520787746},
#  'schipperke': {'vrai positif': 892,
#   'faux positif': 62,
#   'precision': 0.9350104821802935},
#  'groenendael': {'vrai positif': 866,
#   'faux positif': 63,
#   'precision': 0.9321851453175457},
#  'malinois': {'vrai positif': 813,
#   'faux positif': 97,
#   'precision': 0.8934065934065935},
#  'briard': {'vrai positif': 791,
#   'faux positif': 164,
#   'precision': 0.8282722513089005},
#  'kelpie': {'vrai positif': 696,
#   'faux positif': 121,
#   'precision': 0.8518971848225214},
#  'komondor': {'vrai positif': 920,
#   'faux positif': 45,
#   'precision': 0.9533678756476683},
#  'Old_English_sheepdog': {'vrai positif': 972,
#   'faux positif': 92,
#   'precision': 0.9135338345864662},
#  'Shetland_sheepdog': {'vrai positif': 655,
#   'faux positif': 276,
#   'precision': 0.7035445757250268},
#  'collie': {'vrai positif': 463,
#   'faux positif': 466,
#   'precision': 0.4983853606027987},
#  'Border_collie': {'vrai positif': 651,
#   'faux positif': 238,
#   'precision': 0.7322834645669292},
#  'Bouvier_des_Flandres': {'vrai positif': 669,
#   'faux positif': 113,
#   'precision': 0.8554987212276215},
#  'Rottweiler': {'vrai positif': 888,
#   'faux positif': 82,
#   'precision': 0.9154639175257732},
#  'German_shepherd': {'vrai positif': 874,
#   'faux positif': 98,
#   'precision': 0.8991769547325102},
#  'Doberman': {'vrai positif': 882,
#   'faux positif': 122,
#   'precision': 0.8784860557768924},
#  'miniature_pinscher': {'vrai positif': 973,
#   'faux positif': 74,
#   'precision': 0.9293218720152817},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 659,
#   'faux positif': 42,
#   'precision': 0.9400855920114123},
#  'Bernese_mountain_dog': {'vrai positif': 1278,
#   'faux positif': 191,
#   'precision': 0.8699795779441797},
#  'Appenzeller': {'vrai positif': 586,
#   'faux positif': 210,
#   'precision': 0.7361809045226131},
#  'EntleBucher': {'vrai positif': 982,
#   'faux positif': 432,
#   'precision': 0.6944837340876945},
#  'boxer': {'vrai positif': 700,
#   'faux positif': 30,
#   'precision': 0.958904109589041},
#  'bull_mastiff': {'vrai positif': 910,
#   'faux positif': 249,
#   'precision': 0.7851596203623814},
#  'Tibetan_mastiff': {'vrai positif': 772,
#   'faux positif': 44,
#   'precision': 0.946078431372549},
#  'French_bulldog': {'vrai positif': 856,
#   'faux positif': 51,
#   'precision': 0.9437706725468578},
#  'Great_Dane': {'vrai positif': 785,
#   'faux positif': 67,
#   'precision': 0.9213615023474179},
#  'Saint_Bernard': {'vrai positif': 988,
#   'faux positif': 27,
#   'precision': 0.9733990147783251},
#  'Eskimo_dog': {'vrai positif': 266,
#   'faux positif': 365,
#   'precision': 0.4215530903328051},
#  'malamute': {'vrai positif': 824,
#   'faux positif': 144,
#   'precision': 0.8512396694214877},
#  'Siberian_husky': {'vrai positif': 744,
#   'faux positif': 567,
#   'precision': 0.5675057208237986},
#  'affenpinscher': {'vrai positif': 827,
#   'faux positif': 67,
#   'precision': 0.9250559284116331},
#  'basenji': {'vrai positif': 1171,
#   'faux positif': 165,
#   'precision': 0.8764970059880239},
#  'pug': {'vrai positif': 1122,
#   'faux positif': 46,
#   'precision': 0.9606164383561644},
#  'Leonberg': {'vrai positif': 1223,
#   'faux positif': 58,
#   'precision': 0.9547228727556596},
#  'Newfoundland': {'vrai positif': 1002,
#   'faux positif': 263,
#   'precision': 0.792094861660079},
#  'Great_Pyrenees': {'vrai positif': 1051,
#   'faux positif': 162,
#   'precision': 0.8664468260511129},
#  'Samoyed': {'vrai positif': 1290,
#   'faux positif': 157,
#   'precision': 0.8914996544574982},
#  'Pomeranian': {'vrai positif': 1228,
#   'faux positif': 40,
#   'precision': 0.9684542586750788},
#  'chow': {'vrai positif': 1131,
#   'faux positif': 25,
#   'precision': 0.9783737024221453},
#  'keeshond': {'vrai positif': 934,
#   'faux positif': 2,
#   'precision': 0.9978632478632479},
#  'Brabancon_griffon': {'vrai positif': 860,
#   'faux positif': 48,
#   'precision': 0.947136563876652},
#  'Pembroke': {'vrai positif': 1054,
#   'faux positif': 331,
#   'precision': 0.7610108303249098},
#  'Cardigan': {'vrai positif': 684,
#   'faux positif': 129,
#   'precision': 0.8413284132841329},
#  'toy_poodle': {'vrai positif': 365,
#   'faux positif': 182,
#   'precision': 0.6672760511882998},
#  'miniature_poodle': {'vrai positif': 663,
#   'faux positif': 578,
#   'precision': 0.5342465753424658},
#  'standard_poodle': {'vrai positif': 654,
#   'faux positif': 153,
#   'precision': 0.8104089219330854},
#  'Mexican_hairless': {'vrai positif': 926,
#   'faux positif': 104,
#   'precision': 0.8990291262135922},
#  'dingo': {'vrai positif': 803,
#   'faux positif': 148,
#   'precision': 0.8443743427970557},
#  'dhole': {'vrai positif': 844,
#   'faux positif': 20,
#   'precision': 0.9768518518518519},
#  'African_hunting_dog': {'vrai positif': 1000,
#   'faux positif': 8,
#   'precision': 0.9920634920634921}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 9s 267ms/step - loss: 0.4619 - categorical_accuracy: 0.8663
# [0.4619216024875641, 0.8662952780723572]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
print(len(model.variables))
print(len(model.trainable_variables))
print(len(base_model.variables))
print(len(base_model.trainable_variables))
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# 820
# 4
# 814
# 0
# Number of layers in the base model:  564

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-5:]:
    print(layer)
    if not isinstance(layer, layers.BatchNormalization):
        print('ii')
        layer.trainable = True
len(model.trainable_variables)
# Out:
# <keras.engine.functional.Functional object at 0x7fe285819c40>
# ii
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x7fe1f42021f0>
# ii
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7fe285284280>
# <keras.layers.regularization.dropout.Dropout object at 0x7fe29e766d30>
# ii
# <keras.layers.core.dense.Dense object at 0x7fe284ff9d00>
# ii
# 516

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %%
model.save('Modele_fine_v3.h5')

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 24/28
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-12 15:21:59.389267: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.50MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 15:22:09.389562: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.12MiB (rounded to 6422528)requested by op model/resnet152v2/conv4_block29_1_conv/Conv2D-0-0-TransposeNCHWToNHWC-LayoutOptimizer
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-03-12 15:22:09.390672: W tensorflow/tsl/framework/bfc_allocator.cc:492] ****************************************************************************************************
# 2023-03-12 15:22:09.390719: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at transpose_op.cc:183 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,14,14,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-03-12 15:22:19.390907: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.12MiB (rounded to 6422528)requested by op model/resnet152v2/conv4_block29_1_bn/FusedBatchNormV3
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-03-12 15:22:19.392045: W tensorflow/tsl/framework/bfc_allocator.cc:492] ****************************************************************************************************
# 2023-03-12 15:22:19.392091: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at fused_batch_norm_op.cc:1355 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,256,14,14] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[29], line 3
#       1 EPOCHS = history.epoch[-1] + 5
# ----> 3 history_finetunning = model.fit(
#       4     train_dataset,
#       5     epochs=EPOCHS,
#       6     initial_epoch=history.epoch[-1],
#       7     validation_data=validation_dataset,
#       8     verbose=1,
#       9     callbacks =[metrics]
#      10 )
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[32,14,14,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/resnet152v2/conv4_block29_1_conv/Conv2D-0-0-TransposeNCHWToNHWC-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_412993]

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        # plt.imsave(f'results_{name_image}/{name_image}_{layer_name}_{i}.jpg',f[0,:,:,i])
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)

# %%
model.save('Modele_fine_v3.h5')
