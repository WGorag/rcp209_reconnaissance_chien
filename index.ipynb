# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fba9e5d4ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fba9e62a9d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet50V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet50V2(
    include_top=False, # Exclude ImageNet classifier at the top
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x) # Average pooling operation
x = layers.BatchNormalization()(x) # Introduce batch norm
x = layers.Dropout(0.8)(x)  # Regularize with dropout
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 280s 604ms/step - loss: 4.0917 - categorical_accuracy: 0.2343 - val_loss: 0.8058 - val_categorical_accuracy: 0.7599
# Epoch 2/25
# 449/449 [==============================] - 271s 603ms/step - loss: 2.5292 - categorical_accuracy: 0.4438 - val_loss: 0.6711 - val_categorical_accuracy: 0.7923
# Epoch 3/25
# 449/449 [==============================] - 267s 594ms/step - loss: 2.2681 - categorical_accuracy: 0.4885 - val_loss: 0.6259 - val_categorical_accuracy: 0.8073
# Epoch 4/25
# 449/449 [==============================] - 269s 599ms/step - loss: 2.1638 - categorical_accuracy: 0.5209 - val_loss: 0.6169 - val_categorical_accuracy: 0.8085
# Epoch 5/25
# 449/449 [==============================] - 268s 597ms/step - loss: 2.0881 - categorical_accuracy: 0.5254 - val_loss: 0.6043 - val_categorical_accuracy: 0.8139
# Epoch 6/25
# 449/449 [==============================] - 269s 600ms/step - loss: 2.0355 - categorical_accuracy: 0.5344 - val_loss: 0.5898 - val_categorical_accuracy: 0.8164
# Epoch 7/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.9780 - categorical_accuracy: 0.5418 - val_loss: 0.5898 - val_categorical_accuracy: 0.8184
# Epoch 8/25
# 449/449 [==============================] - 276s 616ms/step - loss: 1.9206 - categorical_accuracy: 0.5496 - val_loss: 0.5894 - val_categorical_accuracy: 0.8091
# Epoch 9/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.8775 - categorical_accuracy: 0.5558 - val_loss: 0.5756 - val_categorical_accuracy: 0.8186
# Epoch 10/25
# 449/449 [==============================] - 268s 597ms/step - loss: 1.8519 - categorical_accuracy: 0.5546 - val_loss: 0.5686 - val_categorical_accuracy: 0.8199
# Epoch 11/25
# 449/449 [==============================] - 268s 597ms/step - loss: 1.7553 - categorical_accuracy: 0.5723 - val_loss: 0.5719 - val_categorical_accuracy: 0.8178
# Epoch 12/25
# 449/449 [==============================] - 269s 599ms/step - loss: 1.7628 - categorical_accuracy: 0.5655 - val_loss: 0.5566 - val_categorical_accuracy: 0.8234
# Epoch 13/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.7093 - categorical_accuracy: 0.5717 - val_loss: 0.5603 - val_categorical_accuracy: 0.8261
# Epoch 14/25
# 449/449 [==============================] - 269s 600ms/step - loss: 1.6530 - categorical_accuracy: 0.5792 - val_loss: 0.5638 - val_categorical_accuracy: 0.8217
# Epoch 15/25
# 449/449 [==============================] - 269s 599ms/step - loss: 1.6349 - categorical_accuracy: 0.5765 - val_loss: 0.5563 - val_categorical_accuracy: 0.8254
# Epoch 16/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.5798 - categorical_accuracy: 0.5861 - val_loss: 0.5538 - val_categorical_accuracy: 0.8236
# Epoch 17/25
# 449/449 [==============================] - 272s 606ms/step - loss: 1.5513 - categorical_accuracy: 0.5891 - val_loss: 0.5424 - val_categorical_accuracy: 0.8271
# Epoch 18/25
# 449/449 [==============================] - 271s 603ms/step - loss: 1.4982 - categorical_accuracy: 0.5941 - val_loss: 0.5482 - val_categorical_accuracy: 0.8296
# Epoch 19/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.5169 - categorical_accuracy: 0.5934 - val_loss: 0.5494 - val_categorical_accuracy: 0.8256
# Epoch 20/25
# 449/449 [==============================] - 270s 602ms/step - loss: 1.4768 - categorical_accuracy: 0.5960 - val_loss: 0.5360 - val_categorical_accuracy: 0.8308
# Epoch 21/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.4682 - categorical_accuracy: 0.5976 - val_loss: 0.5478 - val_categorical_accuracy: 0.8265
# Epoch 22/25
# 449/449 [==============================] - 265s 591ms/step - loss: 1.4409 - categorical_accuracy: 0.6010 - val_loss: 0.5447 - val_categorical_accuracy: 0.8269
# Epoch 23/25
# 449/449 [==============================] - 268s 596ms/step - loss: 1.3932 - categorical_accuracy: 0.6088 - val_loss: 0.5451 - val_categorical_accuracy: 0.8267
# Epoch 24/25
# 449/449 [==============================] - 270s 601ms/step - loss: 1.4192 - categorical_accuracy: 0.6029 - val_loss: 0.5446 - val_categorical_accuracy: 0.8296
# Epoch 25/25
# 449/449 [==============================] - 271s 604ms/step - loss: 1.3872 - categorical_accuracy: 0.6117 - val_loss: 0.5396 - val_categorical_accuracy: 0.8328

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 659,
#   'faux positif': 234,
#   'precision': 0.7379619260918253},
#  'Japanese_spaniel': {'vrai positif': 1045,
#   'faux positif': 149,
#   'precision': 0.8752093802345059},
#  'Maltese_dog': {'vrai positif': 1385,
#   'faux positif': 266,
#   'precision': 0.838885523924894},
#  'Pekinese': {'vrai positif': 758,
#   'faux positif': 67,
#   'precision': 0.9187878787878788},
#  'Shih': {'vrai positif': 764,
#   'faux positif': 280,
#   'precision': 0.7318007662835249},
#  'Blenheim_spaniel': {'vrai positif': 1138,
#   'faux positif': 147,
#   'precision': 0.8856031128404669},
#  'papillon': {'vrai positif': 1164,
#   'faux positif': 122,
#   'precision': 0.9051321928460342},
#  'toy_terrier': {'vrai positif': 777,
#   'faux positif': 71,
#   'precision': 0.9162735849056604},
#  'Rhodesian_ridgeback': {'vrai positif': 725,
#   'faux positif': 224,
#   'precision': 0.7639620653319283},
#  'Afghan_hound': {'vrai positif': 1464,
#   'faux positif': 88,
#   'precision': 0.9432989690721649},
#  'basset': {'vrai positif': 965,
#   'faux positif': 54,
#   'precision': 0.9470068694798822},
#  'beagle': {'vrai positif': 1090,
#   'faux positif': 617,
#   'precision': 0.6385471587580551},
#  'bloodhound': {'vrai positif': 1132,
#   'faux positif': 167,
#   'precision': 0.8714395688991532},
#  'bluetick': {'vrai positif': 1023,
#   'faux positif': 119,
#   'precision': 0.8957968476357268},
#  'black': {'vrai positif': 755,
#   'faux positif': 124,
#   'precision': 0.8589306029579067},
#  'Walker_hound': {'vrai positif': 469,
#   'faux positif': 275,
#   'precision': 0.6303763440860215},
#  'English_foxhound': {'vrai positif': 569,
#   'faux positif': 311,
#   'precision': 0.6465909090909091},
#  'redbone': {'vrai positif': 614,
#   'faux positif': 251,
#   'precision': 0.7098265895953757},
#  'borzoi': {'vrai positif': 740,
#   'faux positif': 16,
#   'precision': 0.9788359788359788},
#  'Irish_wolfhound': {'vrai positif': 1135,
#   'faux positif': 196,
#   'precision': 0.8527422990232908},
#  'Italian_greyhound': {'vrai positif': 833,
#   'faux positif': 305,
#   'precision': 0.7319859402460457},
#  'whippet': {'vrai positif': 761,
#   'faux positif': 208,
#   'precision': 0.7853457172342622},
#  'Ibizan_hound': {'vrai positif': 1111,
#   'faux positif': 88,
#   'precision': 0.926605504587156},
#  'Norwegian_elkhound': {'vrai positif': 1200,
#   'faux positif': 111,
#   'precision': 0.9153318077803204},
#  'otterhound': {'vrai positif': 844,
#   'faux positif': 142,
#   'precision': 0.8559837728194726},
#  'Saluki': {'vrai positif': 1119,
#   'faux positif': 228,
#   'precision': 0.8307349665924276},
#  'Scottish_deerhound': {'vrai positif': 1255,
#   'faux positif': 266,
#   'precision': 0.8251150558842867},
#  'Weimaraner': {'vrai positif': 970,
#   'faux positif': 204,
#   'precision': 0.8262350936967632},
#  'Staffordshire_bullterrier': {'vrai positif': 641,
#   'faux positif': 218,
#   'precision': 0.7462165308498254},
#  'American_Staffordshire_terrier': {'vrai positif': 659,
#   'faux positif': 408,
#   'precision': 0.6176194939081537},
#  'Bedlington_terrier': {'vrai positif': 1031,
#   'faux positif': 73,
#   'precision': 0.9338768115942029},
#  'Border_terrier': {'vrai positif': 1038,
#   'faux positif': 157,
#   'precision': 0.8686192468619247},
#  'Kerry_blue_terrier': {'vrai positif': 950,
#   'faux positif': 94,
#   'precision': 0.9099616858237548},
#  'Irish_terrier': {'vrai positif': 922,
#   'faux positif': 219,
#   'precision': 0.8080631025416302},
#  'Norfolk_terrier': {'vrai positif': 767,
#   'faux positif': 325,
#   'precision': 0.7023809523809523},
#  'Norwich_terrier': {'vrai positif': 910,
#   'faux positif': 615,
#   'precision': 0.5967213114754099},
#  'Yorkshire_terrier': {'vrai positif': 680,
#   'faux positif': 197,
#   'precision': 0.7753705815279361},
#  'wire': {'vrai positif': 770,
#   'faux positif': 155,
#   'precision': 0.8324324324324325},
#  'Lakeland_terrier': {'vrai positif': 729,
#   'faux positif': 187,
#   'precision': 0.7958515283842795},
#  'Sealyham_terrier': {'vrai positif': 1152,
#   'faux positif': 77,
#   'precision': 0.9373474369406021},
#  'Airedale': {'vrai positif': 1108,
#   'faux positif': 194,
#   'precision': 0.8509984639016898},
#  'cairn': {'vrai positif': 924,
#   'faux positif': 162,
#   'precision': 0.850828729281768},
#  'Australian_terrier': {'vrai positif': 850,
#   'faux positif': 460,
#   'precision': 0.648854961832061},
#  'Dandie_Dinmont': {'vrai positif': 1053,
#   'faux positif': 71,
#   'precision': 0.9368327402135231},
#  'Boston_bull': {'vrai positif': 1023,
#   'faux positif': 139,
#   'precision': 0.8803786574870912},
#  'miniature_schnauzer': {'vrai positif': 692,
#   'faux positif': 295,
#   'precision': 0.7011144883485309},
#  'giant_schnauzer': {'vrai positif': 770,
#   'faux positif': 158,
#   'precision': 0.8297413793103449},
#  'standard_schnauzer': {'vrai positif': 616,
#   'faux positif': 326,
#   'precision': 0.6539278131634819},
#  'Scotch_terrier': {'vrai positif': 952,
#   'faux positif': 110,
#   'precision': 0.896421845574388},
#  'Tibetan_terrier': {'vrai positif': 1069,
#   'faux positif': 386,
#   'precision': 0.7347079037800688},
#  'silky_terrier': {'vrai positif': 865,
#   'faux positif': 201,
#   'precision': 0.8114446529080676},
#  'soft': {'vrai positif': 711,
#   'faux positif': 121,
#   'precision': 0.8545673076923077},
#  'West_Highland_white_terrier': {'vrai positif': 987,
#   'faux positif': 209,
#   'precision': 0.8252508361204013},
#  'Lhasa': {'vrai positif': 723,
#   'faux positif': 403,
#   'precision': 0.6420959147424512},
#  'flat': {'vrai positif': 892,
#   'faux positif': 310,
#   'precision': 0.7420965058236273},
#  'curly': {'vrai positif': 793,
#   'faux positif': 78,
#   'precision': 0.9104477611940298},
#  'golden_retriever': {'vrai positif': 762,
#   'faux positif': 88,
#   'precision': 0.8964705882352941},
#  'Labrador_retriever': {'vrai positif': 831,
#   'faux positif': 242,
#   'precision': 0.7744641192917054},
#  'Chesapeake_Bay_retriever': {'vrai positif': 876,
#   'faux positif': 210,
#   'precision': 0.8066298342541437},
#  'German_short': {'vrai positif': 772,
#   'faux positif': 81,
#   'precision': 0.9050410316529894},
#  'vizsla': {'vrai positif': 798,
#   'faux positif': 379,
#   'precision': 0.6779949022939677},
#  'English_setter': {'vrai positif': 816,
#   'faux positif': 47,
#   'precision': 0.9455388180764774},
#  'Irish_setter': {'vrai positif': 936,
#   'faux positif': 120,
#   'precision': 0.8863636363636364},
#  'Gordon_setter': {'vrai positif': 896,
#   'faux positif': 62,
#   'precision': 0.9352818371607515},
#  'Brittany_spaniel': {'vrai positif': 839,
#   'faux positif': 209,
#   'precision': 0.8005725190839694},
#  'clumber': {'vrai positif': 906,
#   'faux positif': 43,
#   'precision': 0.9546891464699684},
#  'English_springer': {'vrai positif': 938,
#   'faux positif': 212,
#   'precision': 0.8156521739130435},
#  'Welsh_springer_spaniel': {'vrai positif': 732,
#   'faux positif': 146,
#   'precision': 0.8337129840546698},
#  'cocker_spaniel': {'vrai positif': 660,
#   'faux positif': 65,
#   'precision': 0.9103448275862069},
#  'Sussex_spaniel': {'vrai positif': 804,
#   'faux positif': 45,
#   'precision': 0.9469964664310954},
#  'Irish_water_spaniel': {'vrai positif': 887,
#   'faux positif': 131,
#   'precision': 0.8713163064833006},
#  'kuvasz': {'vrai positif': 733,
#   'faux positif': 134,
#   'precision': 0.845444059976932},
#  'schipperke': {'vrai positif': 863,
#   'faux positif': 119,
#   'precision': 0.8788187372708758},
#  'groenendael': {'vrai positif': 898,
#   'faux positif': 150,
#   'precision': 0.8568702290076335},
#  'malinois': {'vrai positif': 709,
#   'faux positif': 155,
#   'precision': 0.8206018518518519},
#  'briard': {'vrai positif': 777,
#   'faux positif': 202,
#   'precision': 0.7936670071501533},
#  'kelpie': {'vrai positif': 614,
#   'faux positif': 269,
#   'precision': 0.695356738391846},
#  'komondor': {'vrai positif': 920,
#   'faux positif': 35,
#   'precision': 0.9633507853403142},
#  'Old_English_sheepdog': {'vrai positif': 979,
#   'faux positif': 124,
#   'precision': 0.8875793291024479},
#  'Shetland_sheepdog': {'vrai positif': 772,
#   'faux positif': 243,
#   'precision': 0.7605911330049261},
#  'collie': {'vrai positif': 389,
#   'faux positif': 156,
#   'precision': 0.7137614678899082},
#  'Border_collie': {'vrai positif': 796,
#   'faux positif': 531,
#   'precision': 0.5998492840994725},
#  'Bouvier_des_Flandres': {'vrai positif': 808,
#   'faux positif': 283,
#   'precision': 0.7406049495875344},
#  'Rottweiler': {'vrai positif': 923,
#   'faux positif': 126,
#   'precision': 0.8798856053384175},
#  'German_shepherd': {'vrai positif': 735,
#   'faux positif': 130,
#   'precision': 0.8497109826589595},
#  'Doberman': {'vrai positif': 740,
#   'faux positif': 172,
#   'precision': 0.8114035087719298},
#  'miniature_pinscher': {'vrai positif': 979,
#   'faux positif': 259,
#   'precision': 0.7907915993537964},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 809,
#   'faux positif': 128,
#   'precision': 0.8633938100320171},
#  'Bernese_mountain_dog': {'vrai positif': 1228,
#   'faux positif': 97,
#   'precision': 0.9267924528301886},
#  'Appenzeller': {'vrai positif': 590,
#   'faux positif': 448,
#   'precision': 0.5684007707129094},
#  'EntleBucher': {'vrai positif': 979,
#   'faux positif': 335,
#   'precision': 0.7450532724505328},
#  'boxer': {'vrai positif': 655,
#   'faux positif': 134,
#   'precision': 0.8301647655259823},
#  'bull_mastiff': {'vrai positif': 938,
#   'faux positif': 175,
#   'precision': 0.8427672955974843},
#  'Tibetan_mastiff': {'vrai positif': 758,
#   'faux positif': 105,
#   'precision': 0.8783314020857474},
#  'French_bulldog': {'vrai positif': 916,
#   'faux positif': 111,
#   'precision': 0.8919182083739046},
#  'Great_Dane': {'vrai positif': 600,
#   'faux positif': 134,
#   'precision': 0.8174386920980926},
#  'Saint_Bernard': {'vrai positif': 1017,
#   'faux positif': 37,
#   'precision': 0.9648956356736242},
#  'Eskimo_dog': {'vrai positif': 425,
#   'faux positif': 628,
#   'precision': 0.4036087369420703},
#  'malamute': {'vrai positif': 830,
#   'faux positif': 342,
#   'precision': 0.7081911262798635},
#  'Siberian_husky': {'vrai positif': 488,
#   'faux positif': 425,
#   'precision': 0.5345016429353778},
#  'affenpinscher': {'vrai positif': 855,
#   'faux positif': 120,
#   'precision': 0.8769230769230769},
#  'basenji': {'vrai positif': 1202,
#   'faux positif': 149,
#   'precision': 0.8897113249444856},
#  'pug': {'vrai positif': 1178,
#   'faux positif': 24,
#   'precision': 0.9800332778702163},
#  'Leonberg': {'vrai positif': 1273,
#   'faux positif': 96,
#   'precision': 0.9298758217677137},
#  'Newfoundland': {'vrai positif': 1073,
#   'faux positif': 184,
#   'precision': 0.8536197295147175},
#  'Great_Pyrenees': {'vrai positif': 1086,
#   'faux positif': 392,
#   'precision': 0.7347767253044655},
#  'Samoyed': {'vrai positif': 1336,
#   'faux positif': 194,
#   'precision': 0.873202614379085},
#  'Pomeranian': {'vrai positif': 1326,
#   'faux positif': 123,
#   'precision': 0.9151138716356108},
#  'chow': {'vrai positif': 1188,
#   'faux positif': 37,
#   'precision': 0.9697959183673469},
#  'keeshond': {'vrai positif': 954,
#   'faux positif': 32,
#   'precision': 0.9675456389452333},
#  'Brabancon_griffon': {'vrai positif': 886,
#   'faux positif': 9,
#   'precision': 0.9899441340782122},
#  'Pembroke': {'vrai positif': 1071,
#   'faux positif': 406,
#   'precision': 0.7251184834123223},
#  'Cardigan': {'vrai positif': 563,
#   'faux positif': 168,
#   'precision': 0.7701778385772914},
#  'toy_poodle': {'vrai positif': 536,
#   'faux positif': 320,
#   'precision': 0.6261682242990654},
#  'miniature_poodle': {'vrai positif': 553,
#   'faux positif': 662,
#   'precision': 0.4551440329218107},
#  'standard_poodle': {'vrai positif': 642,
#   'faux positif': 124,
#   'precision': 0.8381201044386423},
#  'Mexican_hairless': {'vrai positif': 837,
#   'faux positif': 43,
#   'precision': 0.9511363636363637},
#  'dingo': {'vrai positif': 860,
#   'faux positif': 258,
#   'precision': 0.7692307692307693},
#  'dhole': {'vrai positif': 829,
#   'faux positif': 44,
#   'precision': 0.9495990836197021},
#  'African_hunting_dog': {'vrai positif': 998,
#   'faux positif': 62,
#   'precision': 0.9415094339622642}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 3s 76ms/step - loss: 0.5782 - categorical_accuracy: 0.8282
# [0.5782290101051331, 0.8282265663146973]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
# Out:
# 4

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-15:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
        
len(model.trainable_variables)
# Out:
# 176

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 25/29
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-11 21:03:46.808583: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:03:46.808634: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:03:46.823806: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:03:46.823853: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 448/449 [============================>.] - ETA: 0s - loss: 1.3128 - categorical_accuracy: 0.6365
# 2023-03-11 21:08:39.189020: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:08:39.189070: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:08:39.199518: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:08:39.199547: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 449/449 [==============================] - 332s 688ms/step - loss: 1.3131 - categorical_accuracy: 0.6365 - val_loss: 0.5498 - val_categorical_accuracy: 0.8308
# Epoch 26/29
# 449/449 [==============================] - 305s 679ms/step - loss: 1.2151 - categorical_accuracy: 0.6584 - val_loss: 0.5483 - val_categorical_accuracy: 0.8308
# Epoch 27/29
# 449/449 [==============================] - 301s 670ms/step - loss: 1.1461 - categorical_accuracy: 0.6709 - val_loss: 0.5442 - val_categorical_accuracy: 0.8337
# Epoch 28/29
# 449/449 [==============================] - 301s 670ms/step - loss: 1.1184 - categorical_accuracy: 0.6771 - val_loss: 0.5323 - val_categorical_accuracy: 0.8341
# Epoch 29/29
# 449/449 [==============================] - 302s 672ms/step - loss: 1.0674 - categorical_accuracy: 0.6928 - val_loss: 0.5378 - val_categorical_accuracy: 0.8324

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 134,
#   'faux positif': 67,
#   'precision': 0.6666666666666666},
#  'Japanese_spaniel': {'vrai positif': 209,
#   'faux positif': 14,
#   'precision': 0.9372197309417041},
#  'Maltese_dog': {'vrai positif': 283,
#   'faux positif': 68,
#   'precision': 0.8062678062678063},
#  'Pekinese': {'vrai positif': 145,
#   'faux positif': 10,
#   'precision': 0.9354838709677419},
#  'Shih': {'vrai positif': 173,
#   'faux positif': 59,
#   'precision': 0.7456896551724138},
#  'Blenheim_spaniel': {'vrai positif': 230,
#   'faux positif': 30,
#   'precision': 0.8846153846153846},
#  'papillon': {'vrai positif': 236,
#   'faux positif': 44,
#   'precision': 0.8428571428571429},
#  'toy_terrier': {'vrai positif': 153, 'faux positif': 27, 'precision': 0.85},
#  'Rhodesian_ridgeback': {'vrai positif': 155,
#   'faux positif': 33,
#   'precision': 0.824468085106383},
#  'Afghan_hound': {'vrai positif': 290,
#   'faux positif': 17,
#   'precision': 0.9446254071661238},
#  'basset': {'vrai positif': 200,
#   'faux positif': 10,
#   'precision': 0.9523809523809523},
#  'beagle': {'vrai positif': 223,
#   'faux positif': 133,
#   'precision': 0.6264044943820225},
#  'bloodhound': {'vrai positif': 228,
#   'faux positif': 25,
#   'precision': 0.9011857707509882},
#  'bluetick': {'vrai positif': 203,
#   'faux positif': 17,
#   'precision': 0.9227272727272727},
#  'black': {'vrai positif': 149,
#   'faux positif': 37,
#   'precision': 0.8010752688172043},
#  'Walker_hound': {'vrai positif': 93,
#   'faux positif': 35,
#   'precision': 0.7265625},
#  'English_foxhound': {'vrai positif': 111,
#   'faux positif': 52,
#   'precision': 0.6809815950920245},
#  'redbone': {'vrai positif': 118,
#   'faux positif': 12,
#   'precision': 0.9076923076923077},
#  'borzoi': {'vrai positif': 150,
#   'faux positif': 6,
#   'precision': 0.9615384615384616},
#  'Irish_wolfhound': {'vrai positif': 243,
#   'faux positif': 45,
#   'precision': 0.84375},
#  'Italian_greyhound': {'vrai positif': 174,
#   'faux positif': 67,
#   'precision': 0.7219917012448133},
#  'whippet': {'vrai positif': 147,
#   'faux positif': 32,
#   'precision': 0.8212290502793296},
#  'Ibizan_hound': {'vrai positif': 222,
#   'faux positif': 20,
#   'precision': 0.9173553719008265},
#  'Norwegian_elkhound': {'vrai positif': 245,
#   'faux positif': 20,
#   'precision': 0.9245283018867925},
#  'otterhound': {'vrai positif': 165,
#   'faux positif': 18,
#   'precision': 0.9016393442622951},
#  'Saluki': {'vrai positif': 222,
#   'faux positif': 31,
#   'precision': 0.8774703557312253},
#  'Scottish_deerhound': {'vrai positif': 256,
#   'faux positif': 38,
#   'precision': 0.8707482993197279},
#  'Weimaraner': {'vrai positif': 196,
#   'faux positif': 47,
#   'precision': 0.8065843621399177},
#  'Staffordshire_bullterrier': {'vrai positif': 114,
#   'faux positif': 43,
#   'precision': 0.7261146496815286},
#  'American_Staffordshire_terrier': {'vrai positif': 123,
#   'faux positif': 88,
#   'precision': 0.5829383886255924},
#  'Bedlington_terrier': {'vrai positif': 210,
#   'faux positif': 11,
#   'precision': 0.9502262443438914},
#  'Border_terrier': {'vrai positif': 211,
#   'faux positif': 21,
#   'precision': 0.9094827586206896},
#  'Kerry_blue_terrier': {'vrai positif': 194,
#   'faux positif': 24,
#   'precision': 0.8899082568807339},
#  'Irish_terrier': {'vrai positif': 181,
#   'faux positif': 25,
#   'precision': 0.8786407766990292},
#  'Norfolk_terrier': {'vrai positif': 173,
#   'faux positif': 59,
#   'precision': 0.7456896551724138},
#  'Norwich_terrier': {'vrai positif': 169,
#   'faux positif': 83,
#   'precision': 0.6706349206349206},
#  'Yorkshire_terrier': {'vrai positif': 135,
#   'faux positif': 31,
#   'precision': 0.8132530120481928},
#  'wire': {'vrai positif': 151,
#   'faux positif': 19,
#   'precision': 0.888235294117647},
#  'Lakeland_terrier': {'vrai positif': 163,
#   'faux positif': 58,
#   'precision': 0.7375565610859729},
#  'Sealyham_terrier': {'vrai positif': 231,
#   'faux positif': 17,
#   'precision': 0.9314516129032258},
#  'Airedale': {'vrai positif': 208,
#   'faux positif': 36,
#   'precision': 0.8524590163934426},
#  'cairn': {'vrai positif': 215,
#   'faux positif': 82,
#   'precision': 0.7239057239057239},
#  'Australian_terrier': {'vrai positif': 167,
#   'faux positif': 73,
#   'precision': 0.6958333333333333},
#  'Dandie_Dinmont': {'vrai positif': 195,
#   'faux positif': 15,
#   'precision': 0.9285714285714286},
#  'Boston_bull': {'vrai positif': 200,
#   'faux positif': 25,
#   'precision': 0.8888888888888888},
#  'miniature_schnauzer': {'vrai positif': 152,
#   'faux positif': 65,
#   'precision': 0.7004608294930875},
#  'giant_schnauzer': {'vrai positif': 174,
#   'faux positif': 49,
#   'precision': 0.7802690582959642},
#  'standard_schnauzer': {'vrai positif': 107,
#   'faux positif': 45,
#   'precision': 0.7039473684210527},
#  'Scotch_terrier': {'vrai positif': 190,
#   'faux positif': 23,
#   'precision': 0.892018779342723},
#  'Tibetan_terrier': {'vrai positif': 216,
#   'faux positif': 81,
#   'precision': 0.7272727272727273},
#  'silky_terrier': {'vrai positif': 183,
#   'faux positif': 42,
#   'precision': 0.8133333333333334},
#  'soft': {'vrai positif': 147, 'faux positif': 21, 'precision': 0.875},
#  'West_Highland_white_terrier': {'vrai positif': 199,
#   'faux positif': 53,
#   'precision': 0.7896825396825397},
#  'Lhasa': {'vrai positif': 152,
#   'faux positif': 88,
#   'precision': 0.6333333333333333},
#  'flat': {'vrai positif': 181,
#   'faux positif': 49,
#   'precision': 0.7869565217391304},
#  'curly': {'vrai positif': 162,
#   'faux positif': 20,
#   'precision': 0.8901098901098901},
#  'golden_retriever': {'vrai positif': 162,
#   'faux positif': 16,
#   'precision': 0.9101123595505618},
#  'Labrador_retriever': {'vrai positif': 183,
#   'faux positif': 73,
#   'precision': 0.71484375},
#  'Chesapeake_Bay_retriever': {'vrai positif': 178,
#   'faux positif': 35,
#   'precision': 0.8356807511737089},
#  'German_short': {'vrai positif': 157,
#   'faux positif': 16,
#   'precision': 0.9075144508670521},
#  'vizsla': {'vrai positif': 169,
#   'faux positif': 63,
#   'precision': 0.728448275862069},
#  'English_setter': {'vrai positif': 176,
#   'faux positif': 8,
#   'precision': 0.9565217391304348},
#  'Irish_setter': {'vrai positif': 186,
#   'faux positif': 16,
#   'precision': 0.9207920792079208},
#  'Gordon_setter': {'vrai positif': 184,
#   'faux positif': 4,
#   'precision': 0.9787234042553191},
#  'Brittany_spaniel': {'vrai positif': 170,
#   'faux positif': 32,
#   'precision': 0.8415841584158416},
#  'clumber': {'vrai positif': 176,
#   'faux positif': 5,
#   'precision': 0.9723756906077348},
#  'English_springer': {'vrai positif': 190,
#   'faux positif': 28,
#   'precision': 0.8715596330275229},
#  'Welsh_springer_spaniel': {'vrai positif': 159,
#   'faux positif': 26,
#   'precision': 0.8594594594594595},
#  'cocker_spaniel': {'vrai positif': 139,
#   'faux positif': 23,
#   'precision': 0.8580246913580247},
#  'Sussex_spaniel': {'vrai positif': 167,
#   'faux positif': 6,
#   'precision': 0.9653179190751445},
#  'Irish_water_spaniel': {'vrai positif': 173,
#   'faux positif': 24,
#   'precision': 0.8781725888324873},
#  'kuvasz': {'vrai positif': 145,
#   'faux positif': 30,
#   'precision': 0.8285714285714286},
#  'schipperke': {'vrai positif': 180,
#   'faux positif': 31,
#   'precision': 0.8530805687203792},
#  'groenendael': {'vrai positif': 180,
#   'faux positif': 23,
#   'precision': 0.8866995073891626},
#  'malinois': {'vrai positif': 138,
#   'faux positif': 15,
#   'precision': 0.9019607843137255},
#  'briard': {'vrai positif': 146,
#   'faux positif': 34,
#   'precision': 0.8111111111111111},
#  'kelpie': {'vrai positif': 115,
#   'faux positif': 48,
#   'precision': 0.7055214723926381},
#  'komondor': {'vrai positif': 182,
#   'faux positif': 4,
#   'precision': 0.978494623655914},
#  'Old_English_sheepdog': {'vrai positif': 196,
#   'faux positif': 30,
#   'precision': 0.8672566371681416},
#  'Shetland_sheepdog': {'vrai positif': 137,
#   'faux positif': 18,
#   'precision': 0.8838709677419355},
#  'collie': {'vrai positif': 116,
#   'faux positif': 61,
#   'precision': 0.655367231638418},
#  'Border_collie': {'vrai positif': 153,
#   'faux positif': 84,
#   'precision': 0.6455696202531646},
#  'Bouvier_des_Flandres': {'vrai positif': 157,
#   'faux positif': 35,
#   'precision': 0.8177083333333334},
#  'Rottweiler': {'vrai positif': 180,
#   'faux positif': 17,
#   'precision': 0.9137055837563451},
#  'German_shepherd': {'vrai positif': 154,
#   'faux positif': 34,
#   'precision': 0.8191489361702128},
#  'Doberman': {'vrai positif': 147,
#   'faux positif': 22,
#   'precision': 0.8698224852071006},
#  'miniature_pinscher': {'vrai positif': 197,
#   'faux positif': 38,
#   'precision': 0.8382978723404255},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 179,
#   'faux positif': 24,
#   'precision': 0.8817733990147784},
#  'Bernese_mountain_dog': {'vrai positif': 264,
#   'faux positif': 25,
#   'precision': 0.9134948096885813},
#  'Appenzeller': {'vrai positif': 121,
#   'faux positif': 54,
#   'precision': 0.6914285714285714},
#  'EntleBucher': {'vrai positif': 209,
#   'faux positif': 53,
#   'precision': 0.7977099236641222},
#  'boxer': {'vrai positif': 156,
#   'faux positif': 15,
#   'precision': 0.9122807017543859},
#  'bull_mastiff': {'vrai positif': 194,
#   'faux positif': 31,
#   'precision': 0.8622222222222222},
#  'Tibetan_mastiff': {'vrai positif': 148,
#   'faux positif': 14,
#   'precision': 0.9135802469135802},
#  'French_bulldog': {'vrai positif': 183,
#   'faux positif': 22,
#   'precision': 0.8926829268292683},
#  'Great_Dane': {'vrai positif': 134,
#   'faux positif': 23,
#   'precision': 0.8535031847133758},
#  'Saint_Bernard': {'vrai positif': 201,
#   'faux positif': 6,
#   'precision': 0.9710144927536232},
#  'Eskimo_dog': {'vrai positif': 74,
#   'faux positif': 95,
#   'precision': 0.4378698224852071},
#  'malamute': {'vrai positif': 176,
#   'faux positif': 57,
#   'precision': 0.7553648068669528},
#  'Siberian_husky': {'vrai positif': 132,
#   'faux positif': 115,
#   'precision': 0.5344129554655871},
#  'affenpinscher': {'vrai positif': 169,
#   'faux positif': 12,
#   'precision': 0.9337016574585635},
#  'basenji': {'vrai positif': 245,
#   'faux positif': 25,
#   'precision': 0.9074074074074074},
#  'pug': {'vrai positif': 245,
#   'faux positif': 6,
#   'precision': 0.9760956175298805},
#  'Leonberg': {'vrai positif': 255,
#   'faux positif': 21,
#   'precision': 0.9239130434782609},
#  'Newfoundland': {'vrai positif': 226,
#   'faux positif': 42,
#   'precision': 0.8432835820895522},
#  'Great_Pyrenees': {'vrai positif': 222,
#   'faux positif': 65,
#   'precision': 0.7735191637630662},
#  'Samoyed': {'vrai positif': 271,
#   'faux positif': 40,
#   'precision': 0.8713826366559485},
#  'Pomeranian': {'vrai positif': 265,
#   'faux positif': 20,
#   'precision': 0.9298245614035088},
#  'chow': {'vrai positif': 239,
#   'faux positif': 2,
#   'precision': 0.991701244813278},
#  'keeshond': {'vrai positif': 190,
#   'faux positif': 5,
#   'precision': 0.9743589743589743},
#  'Brabancon_griffon': {'vrai positif': 176,
#   'faux positif': 0,
#   'precision': 1.0},
#  'Pembroke': {'vrai positif': 216,
#   'faux positif': 63,
#   'precision': 0.7741935483870968},
#  'Cardigan': {'vrai positif': 126,
#   'faux positif': 35,
#   'precision': 0.782608695652174},
#  'toy_poodle': {'vrai positif': 121,
#   'faux positif': 64,
#   'precision': 0.654054054054054},
#  'miniature_poodle': {'vrai positif': 97,
#   'faux positif': 97,
#   'precision': 0.5},
#  'standard_poodle': {'vrai positif': 142,
#   'faux positif': 47,
#   'precision': 0.7513227513227513},
#  'Mexican_hairless': {'vrai positif': 164,
#   'faux positif': 14,
#   'precision': 0.9213483146067416},
#  'dingo': {'vrai positif': 172,
#   'faux positif': 45,
#   'precision': 0.7926267281105991},
#  'dhole': {'vrai positif': 169,
#   'faux positif': 9,
#   'precision': 0.949438202247191},
#  'African_hunting_dog': {'vrai positif': 196,
#   'faux positif': 10,
#   'precision': 0.9514563106796117}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 2s 57ms/step - loss: 0.5676 - categorical_accuracy: 0.8319
# [0.567590594291687, 0.8319405913352966]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# American_Staffordshire_terrier
# 2023-03-11 21:29:16.219847: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-11 21:29:16.219897: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 23,818,872
# Trainable params: 23,769,336
# Non-trainable params: 49,536
# _________________________________________________________________

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        # plt.imsave(f'results_{name_image}/{name_image}_{layer_name}_{i}.jpg',f[0,:,:,i])
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 79ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 649 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb9e2e6d5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 137ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 650 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb9e259ff70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 220ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 0s 308ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 0s 389ms/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)
