# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f8610329a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f86103601f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet50V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet50V2(
    include_top=False, # Exclude ImageNet classifier at the top
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x) # Average pooling operation
x = layers.BatchNormalization()(x) # Introduce batch norm
x = layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 255s 555ms/step - loss: 1.9636 - categorical_accuracy: 0.4993 - val_loss: 0.7359 - val_categorical_accuracy: 0.7675
# Epoch 2/25
# 449/449 [==============================] - 248s 553ms/step - loss: 1.2448 - categorical_accuracy: 0.6509 - val_loss: 0.6945 - val_categorical_accuracy: 0.7809
# Epoch 3/25
# 449/449 [==============================] - 249s 556ms/step - loss: 1.1050 - categorical_accuracy: 0.6892 - val_loss: 0.7048 - val_categorical_accuracy: 0.7795
# Epoch 4/25
# 449/449 [==============================] - 250s 557ms/step - loss: 1.0006 - categorical_accuracy: 0.7131 - val_loss: 0.7010 - val_categorical_accuracy: 0.7854
# Epoch 5/25
# 449/449 [==============================] - 250s 558ms/step - loss: 0.9610 - categorical_accuracy: 0.7218 - val_loss: 0.7121 - val_categorical_accuracy: 0.7873
# Epoch 6/25
# 449/449 [==============================] - 250s 556ms/step - loss: 0.8855 - categorical_accuracy: 0.7429 - val_loss: 0.7038 - val_categorical_accuracy: 0.7883
# Epoch 7/25
# 449/449 [==============================] - 250s 556ms/step - loss: 0.8687 - categorical_accuracy: 0.7470 - val_loss: 0.7065 - val_categorical_accuracy: 0.7931

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 171,
#   'faux positif': 51,
#   'precision': 0.7702702702702703},
#  'Japanese_spaniel': {'vrai positif': 310,
#   'faux positif': 58,
#   'precision': 0.842391304347826},
#  'Maltese_dog': {'vrai positif': 406,
#   'faux positif': 140,
#   'precision': 0.7435897435897436},
#  'Pekinese': {'vrai positif': 187, 'faux positif': 13, 'precision': 0.935},
#  'Shih': {'vrai positif': 208,
#   'faux positif': 59,
#   'precision': 0.7790262172284644},
#  'Blenheim_spaniel': {'vrai positif': 305,
#   'faux positif': 9,
#   'precision': 0.9713375796178344},
#  'papillon': {'vrai positif': 304,
#   'faux positif': 21,
#   'precision': 0.9353846153846154},
#  'toy_terrier': {'vrai positif': 184,
#   'faux positif': 116,
#   'precision': 0.6133333333333333},
#  'Rhodesian_ridgeback': {'vrai positif': 191,
#   'faux positif': 131,
#   'precision': 0.593167701863354},
#  'Afghan_hound': {'vrai positif': 393,
#   'faux positif': 12,
#   'precision': 0.9703703703703703},
#  'basset': {'vrai positif': 278,
#   'faux positif': 86,
#   'precision': 0.7637362637362637},
#  'beagle': {'vrai positif': 242,
#   'faux positif': 57,
#   'precision': 0.8093645484949833},
#  'bloodhound': {'vrai positif': 296,
#   'faux positif': 58,
#   'precision': 0.8361581920903954},
#  'bluetick': {'vrai positif': 258,
#   'faux positif': 40,
#   'precision': 0.8657718120805369},
#  'black': {'vrai positif': 215,
#   'faux positif': 76,
#   'precision': 0.738831615120275},
#  'Walker_hound': {'vrai positif': 157,
#   'faux positif': 141,
#   'precision': 0.5268456375838926},
#  'English_foxhound': {'vrai positif': 175,
#   'faux positif': 95,
#   'precision': 0.6481481481481481},
#  'redbone': {'vrai positif': 173,
#   'faux positif': 75,
#   'precision': 0.6975806451612904},
#  'borzoi': {'vrai positif': 202,
#   'faux positif': 27,
#   'precision': 0.8820960698689956},
#  'Irish_wolfhound': {'vrai positif': 217,
#   'faux positif': 72,
#   'precision': 0.7508650519031141},
#  'Italian_greyhound': {'vrai positif': 248,
#   'faux positif': 106,
#   'precision': 0.7005649717514124},
#  'whippet': {'vrai positif': 199,
#   'faux positif': 48,
#   'precision': 0.805668016194332},
#  'Ibizan_hound': {'vrai positif': 269,
#   'faux positif': 29,
#   'precision': 0.9026845637583892},
#  'Norwegian_elkhound': {'vrai positif': 336,
#   'faux positif': 32,
#   'precision': 0.9130434782608695},
#  'otterhound': {'vrai positif': 212,
#   'faux positif': 42,
#   'precision': 0.8346456692913385},
#  'Saluki': {'vrai positif': 318,
#   'faux positif': 29,
#   'precision': 0.9164265129682997},
#  'Scottish_deerhound': {'vrai positif': 312,
#   'faux positif': 98,
#   'precision': 0.7609756097560976},
#  'Weimaraner': {'vrai positif': 272,
#   'faux positif': 87,
#   'precision': 0.7576601671309192},
#  'Staffordshire_bullterrier': {'vrai positif': 204,
#   'faux positif': 111,
#   'precision': 0.6476190476190476},
#  'American_Staffordshire_terrier': {'vrai positif': 145,
#   'faux positif': 77,
#   'precision': 0.6531531531531531},
#  'Bedlington_terrier': {'vrai positif': 301,
#   'faux positif': 15,
#   'precision': 0.9525316455696202},
#  'Border_terrier': {'vrai positif': 264,
#   'faux positif': 30,
#   'precision': 0.8979591836734694},
#  'Kerry_blue_terrier': {'vrai positif': 260,
#   'faux positif': 34,
#   'precision': 0.8843537414965986},
#  'Irish_terrier': {'vrai positif': 222,
#   'faux positif': 38,
#   'precision': 0.8538461538461538},
#  'Norfolk_terrier': {'vrai positif': 184,
#   'faux positif': 115,
#   'precision': 0.6153846153846154},
#  'Norwich_terrier': {'vrai positif': 263,
#   'faux positif': 156,
#   'precision': 0.6276849642004774},
#  'Yorkshire_terrier': {'vrai positif': 171,
#   'faux positif': 92,
#   'precision': 0.6501901140684411},
#  'wire': {'vrai positif': 196,
#   'faux positif': 27,
#   'precision': 0.8789237668161435},
#  'Lakeland_terrier': {'vrai positif': 246,
#   'faux positif': 138,
#   'precision': 0.640625},
#  'Sealyham_terrier': {'vrai positif': 329,
#   'faux positif': 25,
#   'precision': 0.9293785310734464},
#  'Airedale': {'vrai positif': 271,
#   'faux positif': 84,
#   'precision': 0.7633802816901408},
#  'cairn': {'vrai positif': 303,
#   'faux positif': 154,
#   'precision': 0.6630196936542669},
#  'Australian_terrier': {'vrai positif': 264,
#   'faux positif': 194,
#   'precision': 0.5764192139737991},
#  'Dandie_Dinmont': {'vrai positif': 273,
#   'faux positif': 50,
#   'precision': 0.8452012383900929},
#  'Boston_bull': {'vrai positif': 280,
#   'faux positif': 48,
#   'precision': 0.8536585365853658},
#  'miniature_schnauzer': {'vrai positif': 189,
#   'faux positif': 81,
#   'precision': 0.7},
#  'giant_schnauzer': {'vrai positif': 200,
#   'faux positif': 91,
#   'precision': 0.6872852233676976},
#  'standard_schnauzer': {'vrai positif': 181,
#   'faux positif': 126,
#   'precision': 0.5895765472312704},
#  'Scotch_terrier': {'vrai positif': 233,
#   'faux positif': 34,
#   'precision': 0.8726591760299626},
#  'Tibetan_terrier': {'vrai positif': 233,
#   'faux positif': 81,
#   'precision': 0.7420382165605095},
#  'silky_terrier': {'vrai positif': 169,
#   'faux positif': 49,
#   'precision': 0.7752293577981652},
#  'soft': {'vrai positif': 220,
#   'faux positif': 86,
#   'precision': 0.7189542483660131},
#  'West_Highland_white_terrier': {'vrai positif': 248,
#   'faux positif': 49,
#   'precision': 0.835016835016835},
#  'Lhasa': {'vrai positif': 166,
#   'faux positif': 141,
#   'precision': 0.5407166123778502},
#  'flat': {'vrai positif': 240,
#   'faux positif': 65,
#   'precision': 0.7868852459016393},
#  'curly': {'vrai positif': 222,
#   'faux positif': 50,
#   'precision': 0.8161764705882353},
#  'golden_retriever': {'vrai positif': 224,
#   'faux positif': 46,
#   'precision': 0.8296296296296296},
#  'Labrador_retriever': {'vrai positif': 225,
#   'faux positif': 82,
#   'precision': 0.7328990228013029},
#  'Chesapeake_Bay_retriever': {'vrai positif': 218,
#   'faux positif': 33,
#   'precision': 0.8685258964143426},
#  'German_short': {'vrai positif': 196,
#   'faux positif': 11,
#   'precision': 0.9468599033816425},
#  'vizsla': {'vrai positif': 222,
#   'faux positif': 55,
#   'precision': 0.8014440433212996},
#  'English_setter': {'vrai positif': 234,
#   'faux positif': 73,
#   'precision': 0.762214983713355},
#  'Irish_setter': {'vrai positif': 233,
#   'faux positif': 40,
#   'precision': 0.8534798534798534},
#  'Gordon_setter': {'vrai positif': 235,
#   'faux positif': 47,
#   'precision': 0.8333333333333334},
#  'Brittany_spaniel': {'vrai positif': 232,
#   'faux positif': 108,
#   'precision': 0.6823529411764706},
#  'clumber': {'vrai positif': 235,
#   'faux positif': 22,
#   'precision': 0.914396887159533},
#  'English_springer': {'vrai positif': 222,
#   'faux positif': 50,
#   'precision': 0.8161764705882353},
#  'Welsh_springer_spaniel': {'vrai positif': 211,
#   'faux positif': 28,
#   'precision': 0.8828451882845189},
#  'cocker_spaniel': {'vrai positif': 219,
#   'faux positif': 31,
#   'precision': 0.876},
#  'Sussex_spaniel': {'vrai positif': 242,
#   'faux positif': 61,
#   'precision': 0.7986798679867987},
#  'Irish_water_spaniel': {'vrai positif': 221,
#   'faux positif': 32,
#   'precision': 0.8735177865612648},
#  'kuvasz': {'vrai positif': 207,
#   'faux positif': 74,
#   'precision': 0.7366548042704626},
#  'schipperke': {'vrai positif': 199,
#   'faux positif': 18,
#   'precision': 0.9170506912442397},
#  'groenendael': {'vrai positif': 250,
#   'faux positif': 46,
#   'precision': 0.8445945945945946},
#  'malinois': {'vrai positif': 229,
#   'faux positif': 79,
#   'precision': 0.7435064935064936},
#  'briard': {'vrai positif': 222,
#   'faux positif': 92,
#   'precision': 0.7070063694267515},
#  'kelpie': {'vrai positif': 196,
#   'faux positif': 96,
#   'precision': 0.6712328767123288},
#  'komondor': {'vrai positif': 266,
#   'faux positif': 10,
#   'precision': 0.9637681159420289},
#  'Old_English_sheepdog': {'vrai positif': 274,
#   'faux positif': 13,
#   'precision': 0.9547038327526133},
#  'Shetland_sheepdog': {'vrai positif': 230,
#   'faux positif': 134,
#   'precision': 0.6318681318681318},
#  'collie': {'vrai positif': 123,
#   'faux positif': 156,
#   'precision': 0.44086021505376344},
#  'Border_collie': {'vrai positif': 113,
#   'faux positif': 68,
#   'precision': 0.6243093922651933},
#  'Bouvier_des_Flandres': {'vrai positif': 143,
#   'faux positif': 51,
#   'precision': 0.7371134020618557},
#  'Rottweiler': {'vrai positif': 234,
#   'faux positif': 44,
#   'precision': 0.841726618705036},
#  'German_shepherd': {'vrai positif': 187,
#   'faux positif': 15,
#   'precision': 0.9257425742574258},
#  'Doberman': {'vrai positif': 201, 'faux positif': 39, 'precision': 0.8375},
#  'miniature_pinscher': {'vrai positif': 257,
#   'faux positif': 111,
#   'precision': 0.6983695652173914},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 239,
#   'faux positif': 112,
#   'precision': 0.6809116809116809},
#  'Bernese_mountain_dog': {'vrai positif': 354,
#   'faux positif': 65,
#   'precision': 0.8448687350835322},
#  'Appenzeller': {'vrai positif': 160,
#   'faux positif': 114,
#   'precision': 0.583941605839416},
#  'EntleBucher': {'vrai positif': 213,
#   'faux positif': 53,
#   'precision': 0.8007518796992481},
#  'boxer': {'vrai positif': 201,
#   'faux positif': 77,
#   'precision': 0.7230215827338129},
#  'bull_mastiff': {'vrai positif': 214,
#   'faux positif': 24,
#   'precision': 0.8991596638655462},
#  'Tibetan_mastiff': {'vrai positif': 173,
#   'faux positif': 33,
#   'precision': 0.8398058252427184},
#  'French_bulldog': {'vrai positif': 247,
#   'faux positif': 55,
#   'precision': 0.8178807947019867},
#  'Great_Dane': {'vrai positif': 190,
#   'faux positif': 48,
#   'precision': 0.7983193277310925},
#  'Saint_Bernard': {'vrai positif': 280,
#   'faux positif': 10,
#   'precision': 0.9655172413793104},
#  'Eskimo_dog': {'vrai positif': 60,
#   'faux positif': 102,
#   'precision': 0.37037037037037035},
#  'malamute': {'vrai positif': 218,
#   'faux positif': 88,
#   'precision': 0.7124183006535948},
#  'Siberian_husky': {'vrai positif': 190,
#   'faux positif': 215,
#   'precision': 0.4691358024691358},
#  'affenpinscher': {'vrai positif': 183,
#   'faux positif': 57,
#   'precision': 0.7625},
#  'basenji': {'vrai positif': 319,
#   'faux positif': 82,
#   'precision': 0.7955112219451371},
#  'pug': {'vrai positif': 325,
#   'faux positif': 22,
#   'precision': 0.9365994236311239},
#  'Leonberg': {'vrai positif': 351,
#   'faux positif': 21,
#   'precision': 0.9435483870967742},
#  'Newfoundland': {'vrai positif': 274,
#   'faux positif': 65,
#   'precision': 0.8082595870206489},
#  'Great_Pyrenees': {'vrai positif': 286,
#   'faux positif': 63,
#   'precision': 0.8194842406876791},
#  'Samoyed': {'vrai positif': 364,
#   'faux positif': 44,
#   'precision': 0.8921568627450981},
#  'Pomeranian': {'vrai positif': 338,
#   'faux positif': 38,
#   'precision': 0.898936170212766},
#  'chow': {'vrai positif': 335,
#   'faux positif': 7,
#   'precision': 0.97953216374269},
#  'keeshond': {'vrai positif': 277,
#   'faux positif': 7,
#   'precision': 0.9753521126760564},
#  'Brabancon_griffon': {'vrai positif': 252,
#   'faux positif': 45,
#   'precision': 0.8484848484848485},
#  'Pembroke': {'vrai positif': 243,
#   'faux positif': 43,
#   'precision': 0.8496503496503497},
#  'Cardigan': {'vrai positif': 232,
#   'faux positif': 137,
#   'precision': 0.6287262872628726},
#  'toy_poodle': {'vrai positif': 141,
#   'faux positif': 89,
#   'precision': 0.6130434782608696},
#  'miniature_poodle': {'vrai positif': 142,
#   'faux positif': 200,
#   'precision': 0.4152046783625731},
#  'standard_poodle': {'vrai positif': 173,
#   'faux positif': 38,
#   'precision': 0.8199052132701422},
#  'Mexican_hairless': {'vrai positif': 239,
#   'faux positif': 34,
#   'precision': 0.8754578754578755},
#  'dingo': {'vrai positif': 227,
#   'faux positif': 50,
#   'precision': 0.8194945848375451},
#  'dhole': {'vrai positif': 219,
#   'faux positif': 3,
#   'precision': 0.9864864864864865},
#  'African_hunting_dog': {'vrai positif': 284,
#   'faux positif': 23,
#   'precision': 0.9250814332247557}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 3s 74ms/step - loss: 0.7010 - categorical_accuracy: 0.7809
# [0.7009603381156921, 0.7808728218078613]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
# Out:
# 4

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-15:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
        
len(model.trainable_variables)
# Out:
# 176

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 7/11
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-01 23:10:57.602628: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:10:57.602678: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:10:57.626069: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:10:57.626102: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.66GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 448/449 [============================>.] - ETA: 0s - loss: 0.9248 - categorical_accuracy: 0.7282
# 2023-03-01 23:15:32.610452: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:15:32.610496: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:15:32.621711: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-01 23:15:32.621738: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 449/449 [==============================] - 310s 650ms/step - loss: 0.9245 - categorical_accuracy: 0.7282 - val_loss: 0.6579 - val_categorical_accuracy: 0.8021
# Epoch 8/11
# 449/449 [==============================] - 285s 635ms/step - loss: 0.8070 - categorical_accuracy: 0.7625 - val_loss: 0.6570 - val_categorical_accuracy: 0.8069
# Epoch 9/11
# 449/449 [==============================] - 290s 646ms/step - loss: 0.7152 - categorical_accuracy: 0.7812 - val_loss: 0.6344 - val_categorical_accuracy: 0.8079
# Epoch 10/11
# 449/449 [==============================] - 285s 634ms/step - loss: 0.6638 - categorical_accuracy: 0.7955 - val_loss: 0.6368 - val_categorical_accuracy: 0.8102
# Epoch 11/11
# 449/449 [==============================] - 285s 634ms/step - loss: 0.6423 - categorical_accuracy: 0.8006 - val_loss: 0.6324 - val_categorical_accuracy: 0.8116

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 133,
#   'faux positif': 43,
#   'precision': 0.7556818181818182},
#  'Japanese_spaniel': {'vrai positif': 207,
#   'faux positif': 26,
#   'precision': 0.8884120171673819},
#  'Maltese_dog': {'vrai positif': 283,
#   'faux positif': 61,
#   'precision': 0.8226744186046512},
#  'Pekinese': {'vrai positif': 144,
#   'faux positif': 18,
#   'precision': 0.8888888888888888},
#  'Shih': {'vrai positif': 197,
#   'faux positif': 71,
#   'precision': 0.7350746268656716},
#  'Blenheim_spaniel': {'vrai positif': 224,
#   'faux positif': 15,
#   'precision': 0.9372384937238494},
#  'papillon': {'vrai positif': 224,
#   'faux positif': 30,
#   'precision': 0.8818897637795275},
#  'toy_terrier': {'vrai positif': 134,
#   'faux positif': 55,
#   'precision': 0.708994708994709},
#  'Rhodesian_ridgeback': {'vrai positif': 148,
#   'faux positif': 75,
#   'precision': 0.6636771300448431},
#  'Afghan_hound': {'vrai positif': 276,
#   'faux positif': 8,
#   'precision': 0.971830985915493},
#  'basset': {'vrai positif': 193,
#   'faux positif': 29,
#   'precision': 0.8693693693693694},
#  'beagle': {'vrai positif': 201,
#   'faux positif': 89,
#   'precision': 0.6931034482758621},
#  'bloodhound': {'vrai positif': 207,
#   'faux positif': 29,
#   'precision': 0.8771186440677966},
#  'bluetick': {'vrai positif': 184,
#   'faux positif': 31,
#   'precision': 0.8558139534883721},
#  'black': {'vrai positif': 148,
#   'faux positif': 27,
#   'precision': 0.8457142857142858},
#  'Walker_hound': {'vrai positif': 101,
#   'faux positif': 88,
#   'precision': 0.5343915343915344},
#  'English_foxhound': {'vrai positif': 120,
#   'faux positif': 53,
#   'precision': 0.6936416184971098},
#  'redbone': {'vrai positif': 132,
#   'faux positif': 58,
#   'precision': 0.6947368421052632},
#  'borzoi': {'vrai positif': 141,
#   'faux positif': 14,
#   'precision': 0.9096774193548387},
#  'Irish_wolfhound': {'vrai positif': 175,
#   'faux positif': 50,
#   'precision': 0.7777777777777778},
#  'Italian_greyhound': {'vrai positif': 177,
#   'faux positif': 46,
#   'precision': 0.7937219730941704},
#  'whippet': {'vrai positif': 174,
#   'faux positif': 43,
#   'precision': 0.8018433179723502},
#  'Ibizan_hound': {'vrai positif': 215,
#   'faux positif': 24,
#   'precision': 0.899581589958159},
#  'Norwegian_elkhound': {'vrai positif': 241,
#   'faux positif': 23,
#   'precision': 0.9128787878787878},
#  'otterhound': {'vrai positif': 145,
#   'faux positif': 30,
#   'precision': 0.8285714285714286},
#  'Saluki': {'vrai positif': 230,
#   'faux positif': 21,
#   'precision': 0.9163346613545816},
#  'Scottish_deerhound': {'vrai positif': 231,
#   'faux positif': 70,
#   'precision': 0.7674418604651163},
#  'Weimaraner': {'vrai positif': 191,
#   'faux positif': 61,
#   'precision': 0.7579365079365079},
#  'Staffordshire_bullterrier': {'vrai positif': 138,
#   'faux positif': 67,
#   'precision': 0.6731707317073171},
#  'American_Staffordshire_terrier': {'vrai positif': 131,
#   'faux positif': 81,
#   'precision': 0.6179245283018868},
#  'Bedlington_terrier': {'vrai positif': 219,
#   'faux positif': 12,
#   'precision': 0.948051948051948},
#  'Border_terrier': {'vrai positif': 196,
#   'faux positif': 25,
#   'precision': 0.8868778280542986},
#  'Kerry_blue_terrier': {'vrai positif': 193,
#   'faux positif': 13,
#   'precision': 0.9368932038834952},
#  'Irish_terrier': {'vrai positif': 165,
#   'faux positif': 27,
#   'precision': 0.859375},
#  'Norfolk_terrier': {'vrai positif': 157,
#   'faux positif': 98,
#   'precision': 0.615686274509804},
#  'Norwich_terrier': {'vrai positif': 192,
#   'faux positif': 95,
#   'precision': 0.6689895470383276},
#  'Yorkshire_terrier': {'vrai positif': 138,
#   'faux positif': 69,
#   'precision': 0.6666666666666666},
#  'wire': {'vrai positif': 146,
#   'faux positif': 29,
#   'precision': 0.8342857142857143},
#  'Lakeland_terrier': {'vrai positif': 163,
#   'faux positif': 67,
#   'precision': 0.7086956521739131},
#  'Sealyham_terrier': {'vrai positif': 237,
#   'faux positif': 0,
#   'precision': 1.0},
#  'Airedale': {'vrai positif': 197,
#   'faux positif': 46,
#   'precision': 0.8106995884773662},
#  'cairn': {'vrai positif': 225,
#   'faux positif': 92,
#   'precision': 0.7097791798107256},
#  'Australian_terrier': {'vrai positif': 182,
#   'faux positif': 82,
#   'precision': 0.6893939393939394},
#  'Dandie_Dinmont': {'vrai positif': 197,
#   'faux positif': 37,
#   'precision': 0.8418803418803419},
#  'Boston_bull': {'vrai positif': 205,
#   'faux positif': 26,
#   'precision': 0.8874458874458875},
#  'miniature_schnauzer': {'vrai positif': 148,
#   'faux positif': 64,
#   'precision': 0.6981132075471698},
#  'giant_schnauzer': {'vrai positif': 157,
#   'faux positif': 63,
#   'precision': 0.7136363636363636},
#  'standard_schnauzer': {'vrai positif': 116,
#   'faux positif': 31,
#   'precision': 0.7891156462585034},
#  'Scotch_terrier': {'vrai positif': 166,
#   'faux positif': 19,
#   'precision': 0.8972972972972973},
#  'Tibetan_terrier': {'vrai positif': 179,
#   'faux positif': 47,
#   'precision': 0.7920353982300885},
#  'silky_terrier': {'vrai positif': 138,
#   'faux positif': 41,
#   'precision': 0.770949720670391},
#  'soft': {'vrai positif': 159,
#   'faux positif': 66,
#   'precision': 0.7066666666666667},
#  'West_Highland_white_terrier': {'vrai positif': 179,
#   'faux positif': 37,
#   'precision': 0.8287037037037037},
#  'Lhasa': {'vrai positif': 134,
#   'faux positif': 74,
#   'precision': 0.6442307692307693},
#  'flat': {'vrai positif': 166,
#   'faux positif': 36,
#   'precision': 0.8217821782178217},
#  'curly': {'vrai positif': 161,
#   'faux positif': 45,
#   'precision': 0.7815533980582524},
#  'golden_retriever': {'vrai positif': 168,
#   'faux positif': 28,
#   'precision': 0.8571428571428571},
#  'Labrador_retriever': {'vrai positif': 172,
#   'faux positif': 79,
#   'precision': 0.6852589641434262},
#  'Chesapeake_Bay_retriever': {'vrai positif': 162,
#   'faux positif': 29,
#   'precision': 0.8481675392670157},
#  'German_short': {'vrai positif': 156,
#   'faux positif': 8,
#   'precision': 0.9512195121951219},
#  'vizsla': {'vrai positif': 162, 'faux positif': 30, 'precision': 0.84375},
#  'English_setter': {'vrai positif': 169,
#   'faux positif': 26,
#   'precision': 0.8666666666666667},
#  'Irish_setter': {'vrai positif': 177,
#   'faux positif': 25,
#   'precision': 0.8762376237623762},
#  'Gordon_setter': {'vrai positif': 162,
#   'faux positif': 23,
#   'precision': 0.8756756756756757},
#  'Brittany_spaniel': {'vrai positif': 156,
#   'faux positif': 34,
#   'precision': 0.8210526315789474},
#  'clumber': {'vrai positif': 172,
#   'faux positif': 10,
#   'precision': 0.945054945054945},
#  'English_springer': {'vrai positif': 178,
#   'faux positif': 31,
#   'precision': 0.8516746411483254},
#  'Welsh_springer_spaniel': {'vrai positif': 155,
#   'faux positif': 28,
#   'precision': 0.8469945355191257},
#  'cocker_spaniel': {'vrai positif': 156,
#   'faux positif': 32,
#   'precision': 0.8297872340425532},
#  'Sussex_spaniel': {'vrai positif': 175,
#   'faux positif': 9,
#   'precision': 0.9510869565217391},
#  'Irish_water_spaniel': {'vrai positif': 149,
#   'faux positif': 13,
#   'precision': 0.9197530864197531},
#  'kuvasz': {'vrai positif': 145,
#   'faux positif': 36,
#   'precision': 0.8011049723756906},
#  'schipperke': {'vrai positif': 169,
#   'faux positif': 17,
#   'precision': 0.9086021505376344},
#  'groenendael': {'vrai positif': 180,
#   'faux positif': 30,
#   'precision': 0.8571428571428571},
#  'malinois': {'vrai positif': 169,
#   'faux positif': 40,
#   'precision': 0.8086124401913876},
#  'briard': {'vrai positif': 158,
#   'faux positif': 49,
#   'precision': 0.7632850241545893},
#  'kelpie': {'vrai positif': 145,
#   'faux positif': 42,
#   'precision': 0.7754010695187166},
#  'komondor': {'vrai positif': 194,
#   'faux positif': 8,
#   'precision': 0.9603960396039604},
#  'Old_English_sheepdog': {'vrai positif': 203,
#   'faux positif': 12,
#   'precision': 0.9441860465116279},
#  'Shetland_sheepdog': {'vrai positif': 152,
#   'faux positif': 63,
#   'precision': 0.7069767441860465},
#  'collie': {'vrai positif': 103,
#   'faux positif': 67,
#   'precision': 0.6058823529411764},
#  'Border_collie': {'vrai positif': 133,
#   'faux positif': 68,
#   'precision': 0.6616915422885572},
#  'Bouvier_des_Flandres': {'vrai positif': 134,
#   'faux positif': 62,
#   'precision': 0.6836734693877551},
#  'Rottweiler': {'vrai positif': 183,
#   'faux positif': 35,
#   'precision': 0.8394495412844036},
#  'German_shepherd': {'vrai positif': 145,
#   'faux positif': 11,
#   'precision': 0.9294871794871795},
#  'Doberman': {'vrai positif': 157,
#   'faux positif': 33,
#   'precision': 0.8263157894736842},
#  'miniature_pinscher': {'vrai positif': 200,
#   'faux positif': 64,
#   'precision': 0.7575757575757576},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 160,
#   'faux positif': 33,
#   'precision': 0.8290155440414507},
#  'Bernese_mountain_dog': {'vrai positif': 263,
#   'faux positif': 44,
#   'precision': 0.8566775244299675},
#  'Appenzeller': {'vrai positif': 122,
#   'faux positif': 71,
#   'precision': 0.6321243523316062},
#  'EntleBucher': {'vrai positif': 191,
#   'faux positif': 39,
#   'precision': 0.8304347826086956},
#  'boxer': {'vrai positif': 131,
#   'faux positif': 22,
#   'precision': 0.8562091503267973},
#  'bull_mastiff': {'vrai positif': 160,
#   'faux positif': 57,
#   'precision': 0.7373271889400922},
#  'Tibetan_mastiff': {'vrai positif': 156,
#   'faux positif': 32,
#   'precision': 0.8297872340425532},
#  'French_bulldog': {'vrai positif': 178,
#   'faux positif': 32,
#   'precision': 0.8476190476190476},
#  'Great_Dane': {'vrai positif': 129,
#   'faux positif': 37,
#   'precision': 0.7771084337349398},
#  'Saint_Bernard': {'vrai positif': 198,
#   'faux positif': 13,
#   'precision': 0.9383886255924171},
#  'Eskimo_dog': {'vrai positif': 54,
#   'faux positif': 101,
#   'precision': 0.34838709677419355},
#  'malamute': {'vrai positif': 152,
#   'faux positif': 47,
#   'precision': 0.7638190954773869},
#  'Siberian_husky': {'vrai positif': 153,
#   'faux positif': 134,
#   'precision': 0.5331010452961672},
#  'affenpinscher': {'vrai positif': 133,
#   'faux positif': 26,
#   'precision': 0.8364779874213837},
#  'basenji': {'vrai positif': 233,
#   'faux positif': 63,
#   'precision': 0.7871621621621622},
#  'pug': {'vrai positif': 235,
#   'faux positif': 8,
#   'precision': 0.9670781893004116},
#  'Leonberg': {'vrai positif': 247,
#   'faux positif': 15,
#   'precision': 0.9427480916030534},
#  'Newfoundland': {'vrai positif': 204,
#   'faux positif': 33,
#   'precision': 0.8607594936708861},
#  'Great_Pyrenees': {'vrai positif': 213,
#   'faux positif': 54,
#   'precision': 0.797752808988764},
#  'Samoyed': {'vrai positif': 266,
#   'faux positif': 26,
#   'precision': 0.910958904109589},
#  'Pomeranian': {'vrai positif': 235,
#   'faux positif': 14,
#   'precision': 0.9437751004016064},
#  'chow': {'vrai positif': 240,
#   'faux positif': 2,
#   'precision': 0.9917355371900827},
#  'keeshond': {'vrai positif': 199,
#   'faux positif': 4,
#   'precision': 0.9802955665024631},
#  'Brabancon_griffon': {'vrai positif': 179,
#   'faux positif': 27,
#   'precision': 0.8689320388349514},
#  'Pembroke': {'vrai positif': 165,
#   'faux positif': 31,
#   'precision': 0.8418367346938775},
#  'Cardigan': {'vrai positif': 168,
#   'faux positif': 93,
#   'precision': 0.6436781609195402},
#  'toy_poodle': {'vrai positif': 124,
#   'faux positif': 57,
#   'precision': 0.6850828729281768},
#  'miniature_poodle': {'vrai positif': 77,
#   'faux positif': 96,
#   'precision': 0.44508670520231214},
#  'standard_poodle': {'vrai positif': 132,
#   'faux positif': 51,
#   'precision': 0.7213114754098361},
#  'Mexican_hairless': {'vrai positif': 169,
#   'faux positif': 23,
#   'precision': 0.8802083333333334},
#  'dingo': {'vrai positif': 160,
#   'faux positif': 26,
#   'precision': 0.8602150537634409},
#  'dhole': {'vrai positif': 160,
#   'faux positif': 8,
#   'precision': 0.9523809523809523},
#  'African_hunting_dog': {'vrai positif': 206,
#   'faux positif': 11,
#   'precision': 0.9493087557603687}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 2s 56ms/step - loss: 0.6204 - categorical_accuracy: 0.8189
# [0.6203764081001282, 0.8189415335655212]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# Staffordshire_bullterrier

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 23,818,872
# Trainable params: 23,769,336
# Non-trainable params: 49,536
# _________________________________________________________________

# %% [markdown]
# On visualise

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i])
        # plt.imsave(f'results_{name_image}/{name_image}_{layer_name}_{i}.jpg',f[0,:,:,i])
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 81ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 650 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8512582a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 118ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 651 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8510621790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 205ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 0s 326ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 0s 383ms/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)
