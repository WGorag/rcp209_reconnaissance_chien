# %% [markdown]
# Import des librairies nécessaire au bon fonctionnement du projet

# %%
import pathlib
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import tarfile
from os import path
from tensorflow.keras import layers
from tensorflow import keras
import python_splitter
import shutil
from tensorflow.keras.models import load_model

import zipfile
from PIL import Image
from bs4 import BeautifulSoup

from PIL import Image
import cv2
from tensorflow.keras.models import Model
from keras import callbacks

import shutil
import numpy as np

# %% [markdown]
# Activation de l'utilisation du GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Téléchargement du dataset

# %%
if not path.isdir('dataset'):
    data_dir = tf.keras.utils.get_file(
        "dataset.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/images.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/dataset/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Import d'annotation concernant les images du dataset

# %%
if not path.isdir('annotation'):
    data_dir = tf.keras.utils.get_file(
        "annotation.tar",
        "http://vision.stanford.edu/aditya86/ImageNetDogs/annotation.tar",
        extract=False)
    with tarfile.open(data_dir, 'r') as tar_ref:
        tar_ref.extractall(path='/data/annotation/')
    print('Dataset installé')
else:
    print('Dataset déja installé')
# Out:
# Dataset déja installé

# %% [markdown]
# Première phase de prétraitement qui consiste à isoler les chiens dans les images afin de limiter les informations superflu

# %%
if path.isdir('custom_dataset'):
    shutil.rmtree("custom_dataset")
os.mkdir('custom_dataset')
os.mkdir('custom_dataset/Images')

directories = os.listdir('annotation/Annotation')
for directory in directories:
    os.mkdir('custom_dataset/Images/' + directory)
    files = os.listdir('annotation/Annotation/' + directory)
    for file in files:
        old_name = 'annotation/Annotation/' + directory + '/' + file
        new_name = 'annotation/Annotation/' + directory + '/' + file + '.xml'
        os.rename(old_name, new_name)
        if path.exists("dataset/Images/" + directory + '/' + file + '.jpg'):
            with open(new_name, 'r') as f:
                data = f.read()
            Bs_data = BeautifulSoup(data, "xml")
            boxes = Bs_data.find('xmin')
            for i in range(len(boxes)):
                xmin = int(str(Bs_data.find_all('xmin')[i]).replace('<xmin>', '').replace('</xmin>', ''))
                ymin = int(str(Bs_data.find_all('ymin')[i]).replace('<ymin>', '').replace('</ymin>', ''))
                xmax = int(str(Bs_data.find_all('xmax')[i]).replace('<xmax>', '').replace('</xmax>', ''))
                ymax = int(str(Bs_data.find_all('ymax')[i]).replace('<ymax>', '').replace('</ymax>', ''))
                image = Image.open(r"dataset/Images/" + directory + "/" + file + ".jpg")
                image = image.convert('RGB')
                image = image.crop((xmin, ymin, xmax, ymax))
                image.save("custom_dataset/Images/" + directory + "/" + file + ".jpg")
        os.rename(new_name, old_name)

# %% [markdown]
# Séparation du dataset en données d'entrainement, validation et test
# python_splitter.split_from_folder a un bug et inverse le répertoire de test et de val donc il faut inverser les valeurs (voir pour changer la façon de split)

# %%
if path.isdir('Train_Test_Folder'):
    shutil.rmtree("Train_Test_Folder")
python_splitter.split_from_folder("/data/custom_dataset/Images", train = 0.7, test = 0.25)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.25
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------

# %% [markdown]
# Création d'un tableau contenant toutes les races

# %%
items = os.listdir('custom_dataset/Images')
items.sort()
dog_categories = [];
for item in items:
    dog_categories.append(item.split('-')[1])

# %% [markdown]
# Import des batch d'images et redimensionnement

# %%
BATCH_SIZE = 32
IMG_SIZE = 224
NB_CLASS = 120
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/train'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/test'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    pathlib.Path('Train_Test_Folder/val'),
    image_size=(IMG_SIZE,IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True
)

class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(3):
    ax = plt.subplot(1, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 14355 files belonging to 120 classes.
# Found 1077 files belonging to 120 classes.
# Found 5148 files belonging to 120 classes.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Je transforme mes classes en un vecteur one hot

# %%
train_dataset = train_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
validation_dataset = validation_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
test_dataset = test_dataset.map(lambda x, y: (x, tf.one_hot(y, depth=NB_CLASS)))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Seconde couche de prétraitement qui permet d'augmenter de manière artificielle le nombre de données d'entrainement

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomBrightness(0.3)
])

plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fa9045a8b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fa9045a89d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Import de la deapfeature ResNet101V2 préentrainé sur les poids d'imagenet

# %%
base_model = keras.applications.ResNet101V2(
    include_top=False, # Exclude ImageNet classifier at the top
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 10s 0us/step

# %% [markdown]
# base_model.trainable = FalseJe gèle les poids pour qu'ils ne soient pas mis à jour durant l'entrainement du réseau

# %%
base_model.trainable = False

# %% [markdown]
# Contruction du modèle

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.

# %% [markdown]
# Je met une couche de normalisation afin que toute mes images aient le même niveau de flou

# %%
layers.GaussianNoise(stddev=0.2)(x)
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'gaussian_noise')>

# %% [markdown]
# J'intégre ma deapfeature

# %%
x = keras.applications.resnet_v2.preprocess_input(x)
x = base_model(x, training=False)

# %% [markdown]
# J'ajoute les couches permettant la classifications des races de chiens

# %%
x = layers.GlobalAveragePooling2D()(x) # Average pooling operation
x = layers.BatchNormalization()(x) # Introduce batch norm
x = layers.Dropout(0.8)(x)  # Regularize with dropout
outputs = layers.Dense(NB_CLASS, activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# Je compile mon modèle

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# Je met en place un métrique d'early stopping afin d'éviter le sur apprentissage
# Si la fonction de perte sur mes données d'entrainement ne diminu pas significativement pendant 5 époques alors j'arrête l'entrainement et je restore les meilleurs poids pour le réseau

# %%
earlystopping = callbacks.EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    patience=5, 
    restore_best_weights=True,
    min_delta = 0.01
)

# %% [markdown]
# Définition d'une nouvelle métrique permettant d'obtenir la précision du modèle pour chacune des races

# %%
class Metrics(keras.callbacks.Callback):
    def __init__(self, val_data, dog_categories):
        super().__init__()
        self.validation_data = val_data
    def on_train_begin(self, logs={}):
        self._data = {}
        for dog_category in dog_categories:
                self._data[dog_category] = {
                        'vrai positif': 0,
                        'faux positif': 0,
                        'precision':0
                    }

    def on_epoch_end(self, batch, logs={}):
        for x_test, y_test in self.validation_data:
            y_predict = np.asarray(model.predict(x_test, verbose=0))

            true = np.argmax(y_test, axis=1)
            pred = np.argmax(y_predict, axis=1)
            predictions = zip(true, pred);
            for test, prediction in predictions:
                if test == prediction:
                    self._data[dog_categories[test]]['vrai positif'] = self._data[dog_categories[test]]['vrai positif'] + 1
                if test != prediction:
                    self._data[dog_categories[prediction]]['faux positif'] = self._data[dog_categories[prediction]]['faux positif'] + 1
        return

    def get_data(self):
        for data in self._data:
            self._data[data]['precision'] = self._data[data]['vrai positif'] / (self._data[data]['vrai positif'] + self._data[data]['faux positif'])
        return self._data
    
metrics = Metrics(val_data = validation_dataset, dog_categories = dog_categories)

# %% [markdown]
# Début de l'entrainement du modèle sur 25 époques

# %%
EPOCHS = 25

history = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[earlystopping, metrics]
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 449/449 [==============================] - 325s 705ms/step - loss: 3.9235 - categorical_accuracy: 0.2708 - val_loss: 0.6890 - val_categorical_accuracy: 0.7898
# Epoch 2/25
# 449/449 [==============================] - 311s 693ms/step - loss: 2.3893 - categorical_accuracy: 0.4831 - val_loss: 0.5977 - val_categorical_accuracy: 0.8079
# Epoch 3/25
# 449/449 [==============================] - 312s 694ms/step - loss: 2.0978 - categorical_accuracy: 0.5382 - val_loss: 0.5843 - val_categorical_accuracy: 0.8162
# Epoch 4/25
# 449/449 [==============================] - 309s 687ms/step - loss: 2.0255 - categorical_accuracy: 0.5512 - val_loss: 0.5630 - val_categorical_accuracy: 0.8263
# Epoch 5/25
# 449/449 [==============================] - 307s 683ms/step - loss: 1.9898 - categorical_accuracy: 0.5587 - val_loss: 0.5598 - val_categorical_accuracy: 0.8283
# Epoch 6/25
# 449/449 [==============================] - 318s 708ms/step - loss: 1.9007 - categorical_accuracy: 0.5781 - val_loss: 0.5470 - val_categorical_accuracy: 0.8287
# Epoch 7/25
# 449/449 [==============================] - 321s 716ms/step - loss: 1.8426 - categorical_accuracy: 0.5833 - val_loss: 0.5429 - val_categorical_accuracy: 0.8318
# Epoch 8/25
# 449/449 [==============================] - 325s 723ms/step - loss: 1.8375 - categorical_accuracy: 0.5829 - val_loss: 0.5355 - val_categorical_accuracy: 0.8316
# Epoch 9/25
# 449/449 [==============================] - 329s 733ms/step - loss: 1.7306 - categorical_accuracy: 0.5962 - val_loss: 0.5400 - val_categorical_accuracy: 0.8326
# Epoch 10/25
# 449/449 [==============================] - 316s 705ms/step - loss: 1.7222 - categorical_accuracy: 0.5947 - val_loss: 0.5486 - val_categorical_accuracy: 0.8275
# Epoch 11/25
# 449/449 [==============================] - 320s 712ms/step - loss: 1.6791 - categorical_accuracy: 0.5968 - val_loss: 0.5324 - val_categorical_accuracy: 0.8314
# Epoch 12/25
# 449/449 [==============================] - 328s 730ms/step - loss: 1.6681 - categorical_accuracy: 0.6031 - val_loss: 0.5255 - val_categorical_accuracy: 0.8361
# Epoch 13/25
# 449/449 [==============================] - 325s 724ms/step - loss: 1.5909 - categorical_accuracy: 0.6074 - val_loss: 0.5213 - val_categorical_accuracy: 0.8318
# Epoch 14/25
# 449/449 [==============================] - 316s 704ms/step - loss: 1.5512 - categorical_accuracy: 0.6192 - val_loss: 0.5191 - val_categorical_accuracy: 0.8328
# Epoch 15/25
# 449/449 [==============================] - 328s 730ms/step - loss: 1.5232 - categorical_accuracy: 0.6153 - val_loss: 0.5088 - val_categorical_accuracy: 0.8388
# Epoch 16/25
# 449/449 [==============================] - 326s 725ms/step - loss: 1.4945 - categorical_accuracy: 0.6217 - val_loss: 0.5008 - val_categorical_accuracy: 0.8421
# Epoch 17/25
# 449/449 [==============================] - 317s 705ms/step - loss: 1.4384 - categorical_accuracy: 0.6275 - val_loss: 0.5043 - val_categorical_accuracy: 0.8382
# Epoch 18/25
# 449/449 [==============================] - 324s 721ms/step - loss: 1.4107 - categorical_accuracy: 0.6316 - val_loss: 0.5005 - val_categorical_accuracy: 0.8409
# Epoch 19/25
# 449/449 [==============================] - 326s 726ms/step - loss: 1.3763 - categorical_accuracy: 0.6329 - val_loss: 0.4914 - val_categorical_accuracy: 0.8430
# Epoch 20/25
# 449/449 [==============================] - 326s 725ms/step - loss: 1.3695 - categorical_accuracy: 0.6329 - val_loss: 0.4898 - val_categorical_accuracy: 0.8405
# Epoch 21/25
# 449/449 [==============================] - 327s 728ms/step - loss: 1.3485 - categorical_accuracy: 0.6391 - val_loss: 0.4856 - val_categorical_accuracy: 0.8448
# Epoch 22/25
# 449/449 [==============================] - 319s 710ms/step - loss: 1.3154 - categorical_accuracy: 0.6380 - val_loss: 0.4921 - val_categorical_accuracy: 0.8397
# Epoch 23/25
# 449/449 [==============================] - 316s 703ms/step - loss: 1.3107 - categorical_accuracy: 0.6367 - val_loss: 0.4947 - val_categorical_accuracy: 0.8409
# Epoch 24/25
# 449/449 [==============================] - 316s 705ms/step - loss: 1.2835 - categorical_accuracy: 0.6423 - val_loss: 0.4879 - val_categorical_accuracy: 0.8434

# %% [markdown]
# Affichage de la précision pour chacune des races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 743,
#   'faux positif': 113,
#   'precision': 0.8679906542056075},
#  'Japanese_spaniel': {'vrai positif': 1012,
#   'faux positif': 201,
#   'precision': 0.8342951360263808},
#  'Maltese_dog': {'vrai positif': 1362,
#   'faux positif': 242,
#   'precision': 0.8491271820448878},
#  'Pekinese': {'vrai positif': 769,
#   'faux positif': 134,
#   'precision': 0.8516057585825028},
#  'Shih': {'vrai positif': 950,
#   'faux positif': 294,
#   'precision': 0.7636655948553055},
#  'Blenheim_spaniel': {'vrai positif': 1042,
#   'faux positif': 108,
#   'precision': 0.9060869565217391},
#  'papillon': {'vrai positif': 1148,
#   'faux positif': 80,
#   'precision': 0.9348534201954397},
#  'toy_terrier': {'vrai positif': 799,
#   'faux positif': 151,
#   'precision': 0.8410526315789474},
#  'Rhodesian_ridgeback': {'vrai positif': 797,
#   'faux positif': 340,
#   'precision': 0.7009674582233949},
#  'Afghan_hound': {'vrai positif': 1342,
#   'faux positif': 44,
#   'precision': 0.9682539682539683},
#  'basset': {'vrai positif': 907,
#   'faux positif': 145,
#   'precision': 0.8621673003802282},
#  'beagle': {'vrai positif': 1051,
#   'faux positif': 378,
#   'precision': 0.7354793561931421},
#  'bloodhound': {'vrai positif': 1059,
#   'faux positif': 121,
#   'precision': 0.8974576271186441},
#  'bluetick': {'vrai positif': 931,
#   'faux positif': 48,
#   'precision': 0.95097037793667},
#  'black': {'vrai positif': 775,
#   'faux positif': 136,
#   'precision': 0.8507135016465422},
#  'Walker_hound': {'vrai positif': 462,
#   'faux positif': 267,
#   'precision': 0.6337448559670782},
#  'English_foxhound': {'vrai positif': 613,
#   'faux positif': 384,
#   'precision': 0.6148445336008024},
#  'redbone': {'vrai positif': 638,
#   'faux positif': 179,
#   'precision': 0.780905752753978},
#  'borzoi': {'vrai positif': 823,
#   'faux positif': 45,
#   'precision': 0.9481566820276498},
#  'Irish_wolfhound': {'vrai positif': 866,
#   'faux positif': 161,
#   'precision': 0.8432327166504382},
#  'Italian_greyhound': {'vrai positif': 860,
#   'faux positif': 275,
#   'precision': 0.7577092511013216},
#  'whippet': {'vrai positif': 661,
#   'faux positif': 112,
#   'precision': 0.8551099611901681},
#  'Ibizan_hound': {'vrai positif': 1052,
#   'faux positif': 64,
#   'precision': 0.942652329749104},
#  'Norwegian_elkhound': {'vrai positif': 1151,
#   'faux positif': 84,
#   'precision': 0.9319838056680162},
#  'otterhound': {'vrai positif': 722,
#   'faux positif': 118,
#   'precision': 0.8595238095238096},
#  'Saluki': {'vrai positif': 1077,
#   'faux positif': 112,
#   'precision': 0.9058031959629941},
#  'Scottish_deerhound': {'vrai positif': 1269,
#   'faux positif': 424,
#   'precision': 0.7495569994093325},
#  'Weimaraner': {'vrai positif': 917,
#   'faux positif': 214,
#   'precision': 0.8107869142351901},
#  'Staffordshire_bullterrier': {'vrai positif': 598,
#   'faux positif': 410,
#   'precision': 0.5932539682539683},
#  'American_Staffordshire_terrier': {'vrai positif': 532,
#   'faux positif': 337,
#   'precision': 0.6121979286536249},
#  'Bedlington_terrier': {'vrai positif': 1009,
#   'faux positif': 100,
#   'precision': 0.9098286744815148},
#  'Border_terrier': {'vrai positif': 970,
#   'faux positif': 57,
#   'precision': 0.9444985394352483},
#  'Kerry_blue_terrier': {'vrai positif': 1008,
#   'faux positif': 98,
#   'precision': 0.9113924050632911},
#  'Irish_terrier': {'vrai positif': 801,
#   'faux positif': 90,
#   'precision': 0.898989898989899},
#  'Norfolk_terrier': {'vrai positif': 714,
#   'faux positif': 273,
#   'precision': 0.723404255319149},
#  'Norwich_terrier': {'vrai positif': 921,
#   'faux positif': 245,
#   'precision': 0.7898799313893653},
#  'Yorkshire_terrier': {'vrai positif': 694,
#   'faux positif': 208,
#   'precision': 0.7694013303769401},
#  'wire': {'vrai positif': 725,
#   'faux positif': 126,
#   'precision': 0.8519388954171563},
#  'Lakeland_terrier': {'vrai positif': 827,
#   'faux positif': 195,
#   'precision': 0.8091976516634051},
#  'Sealyham_terrier': {'vrai positif': 1140,
#   'faux positif': 97,
#   'precision': 0.9215844785772029},
#  'Airedale': {'vrai positif': 1059,
#   'faux positif': 230,
#   'precision': 0.821567106283941},
#  'cairn': {'vrai positif': 1006,
#   'faux positif': 292,
#   'precision': 0.7750385208012327},
#  'Australian_terrier': {'vrai positif': 883,
#   'faux positif': 409,
#   'precision': 0.68343653250774},
#  'Dandie_Dinmont': {'vrai positif': 956,
#   'faux positif': 75,
#   'precision': 0.92725509214355},
#  'Boston_bull': {'vrai positif': 1014,
#   'faux positif': 323,
#   'precision': 0.7584143605086013},
#  'miniature_schnauzer': {'vrai positif': 733,
#   'faux positif': 180,
#   'precision': 0.8028477546549836},
#  'giant_schnauzer': {'vrai positif': 788,
#   'faux positif': 283,
#   'precision': 0.7357609710550888},
#  'standard_schnauzer': {'vrai positif': 646,
#   'faux positif': 226,
#   'precision': 0.7408256880733946},
#  'Scotch_terrier': {'vrai positif': 870,
#   'faux positif': 238,
#   'precision': 0.7851985559566786},
#  'Tibetan_terrier': {'vrai positif': 1016,
#   'faux positif': 267,
#   'precision': 0.7918939984411536},
#  'silky_terrier': {'vrai positif': 647,
#   'faux positif': 195,
#   'precision': 0.7684085510688836},
#  'soft': {'vrai positif': 763,
#   'faux positif': 69,
#   'precision': 0.9170673076923077},
#  'West_Highland_white_terrier': {'vrai positif': 978,
#   'faux positif': 471,
#   'precision': 0.6749482401656315},
#  'Lhasa': {'vrai positif': 700,
#   'faux positif': 158,
#   'precision': 0.8158508158508159},
#  'flat': {'vrai positif': 780,
#   'faux positif': 125,
#   'precision': 0.861878453038674},
#  'curly': {'vrai positif': 819,
#   'faux positif': 112,
#   'precision': 0.8796992481203008},
#  'golden_retriever': {'vrai positif': 826,
#   'faux positif': 147,
#   'precision': 0.8489208633093526},
#  'Labrador_retriever': {'vrai positif': 876,
#   'faux positif': 278,
#   'precision': 0.7590987868284229},
#  'Chesapeake_Bay_retriever': {'vrai positif': 844,
#   'faux positif': 81,
#   'precision': 0.9124324324324324},
#  'German_short': {'vrai positif': 807,
#   'faux positif': 43,
#   'precision': 0.9494117647058824},
#  'vizsla': {'vrai positif': 791,
#   'faux positif': 139,
#   'precision': 0.8505376344086022},
#  'English_setter': {'vrai positif': 862,
#   'faux positif': 75,
#   'precision': 0.919957310565635},
#  'Irish_setter': {'vrai positif': 899,
#   'faux positif': 46,
#   'precision': 0.9513227513227513},
#  'Gordon_setter': {'vrai positif': 875,
#   'faux positif': 86,
#   'precision': 0.9105098855359001},
#  'Brittany_spaniel': {'vrai positif': 720,
#   'faux positif': 150,
#   'precision': 0.8275862068965517},
#  'clumber': {'vrai positif': 810,
#   'faux positif': 6,
#   'precision': 0.9926470588235294},
#  'English_springer': {'vrai positif': 861,
#   'faux positif': 209,
#   'precision': 0.8046728971962617},
#  'Welsh_springer_spaniel': {'vrai positif': 711,
#   'faux positif': 158,
#   'precision': 0.8181818181818182},
#  'cocker_spaniel': {'vrai positif': 820,
#   'faux positif': 143,
#   'precision': 0.8515057113187954},
#  'Sussex_spaniel': {'vrai positif': 886,
#   'faux positif': 49,
#   'precision': 0.9475935828877006},
#  'Irish_water_spaniel': {'vrai positif': 729,
#   'faux positif': 36,
#   'precision': 0.9529411764705882},
#  'kuvasz': {'vrai positif': 698,
#   'faux positif': 66,
#   'precision': 0.9136125654450262},
#  'schipperke': {'vrai positif': 840,
#   'faux positif': 86,
#   'precision': 0.9071274298056156},
#  'groenendael': {'vrai positif': 872,
#   'faux positif': 86,
#   'precision': 0.9102296450939458},
#  'malinois': {'vrai positif': 817,
#   'faux positif': 110,
#   'precision': 0.8813376483279396},
#  'briard': {'vrai positif': 721,
#   'faux positif': 169,
#   'precision': 0.8101123595505618},
#  'kelpie': {'vrai positif': 757,
#   'faux positif': 174,
#   'precision': 0.8131041890440387},
#  'komondor': {'vrai positif': 888,
#   'faux positif': 22,
#   'precision': 0.9758241758241758},
#  'Old_English_sheepdog': {'vrai positif': 1002,
#   'faux positif': 199,
#   'precision': 0.8343047460449625},
#  'Shetland_sheepdog': {'vrai positif': 660,
#   'faux positif': 138,
#   'precision': 0.8270676691729323},
#  'collie': {'vrai positif': 501,
#   'faux positif': 438,
#   'precision': 0.5335463258785943},
#  'Border_collie': {'vrai positif': 670,
#   'faux positif': 330,
#   'precision': 0.67},
#  'Bouvier_des_Flandres': {'vrai positif': 702,
#   'faux positif': 135,
#   'precision': 0.8387096774193549},
#  'Rottweiler': {'vrai positif': 832,
#   'faux positif': 51,
#   'precision': 0.942242355605889},
#  'German_shepherd': {'vrai positif': 783,
#   'faux positif': 68,
#   'precision': 0.9200940070505288},
#  'Doberman': {'vrai positif': 682,
#   'faux positif': 95,
#   'precision': 0.8777348777348777},
#  'miniature_pinscher': {'vrai positif': 1030,
#   'faux positif': 291,
#   'precision': 0.7797123391370174},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 711,
#   'faux positif': 151,
#   'precision': 0.8248259860788864},
#  'Bernese_mountain_dog': {'vrai positif': 1201,
#   'faux positif': 148,
#   'precision': 0.8902891030392883},
#  'Appenzeller': {'vrai positif': 458,
#   'faux positif': 107,
#   'precision': 0.8106194690265487},
#  'EntleBucher': {'vrai positif': 1061,
#   'faux positif': 687,
#   'precision': 0.6069794050343249},
#  'boxer': {'vrai positif': 692,
#   'faux positif': 105,
#   'precision': 0.8682559598494354},
#  'bull_mastiff': {'vrai positif': 882,
#   'faux positif': 181,
#   'precision': 0.8297271872060207},
#  'Tibetan_mastiff': {'vrai positif': 809,
#   'faux positif': 135,
#   'precision': 0.8569915254237288},
#  'French_bulldog': {'vrai positif': 766,
#   'faux positif': 130,
#   'precision': 0.8549107142857143},
#  'Great_Dane': {'vrai positif': 661,
#   'faux positif': 21,
#   'precision': 0.969208211143695},
#  'Saint_Bernard': {'vrai positif': 1008, 'faux positif': 0, 'precision': 1.0},
#  'Eskimo_dog': {'vrai positif': 485,
#   'faux positif': 823,
#   'precision': 0.37079510703363916},
#  'malamute': {'vrai positif': 835,
#   'faux positif': 297,
#   'precision': 0.7376325088339223},
#  'Siberian_husky': {'vrai positif': 403,
#   'faux positif': 242,
#   'precision': 0.6248062015503876},
#  'affenpinscher': {'vrai positif': 796,
#   'faux positif': 275,
#   'precision': 0.7432306255835668},
#  'basenji': {'vrai positif': 1111,
#   'faux positif': 98,
#   'precision': 0.9189412737799835},
#  'pug': {'vrai positif': 1075,
#   'faux positif': 55,
#   'precision': 0.9513274336283186},
#  'Leonberg': {'vrai positif': 1224, 'faux positif': 56, 'precision': 0.95625},
#  'Newfoundland': {'vrai positif': 1004,
#   'faux positif': 142,
#   'precision': 0.8760907504363001},
#  'Great_Pyrenees': {'vrai positif': 1131,
#   'faux positif': 253,
#   'precision': 0.8171965317919075},
#  'Samoyed': {'vrai positif': 1301,
#   'faux positif': 90,
#   'precision': 0.9352983465132998},
#  'Pomeranian': {'vrai positif': 1222,
#   'faux positif': 38,
#   'precision': 0.9698412698412698},
#  'chow': {'vrai positif': 1129, 'faux positif': 0, 'precision': 1.0},
#  'keeshond': {'vrai positif': 960,
#   'faux positif': 27,
#   'precision': 0.9726443768996961},
#  'Brabancon_griffon': {'vrai positif': 761,
#   'faux positif': 53,
#   'precision': 0.9348894348894349},
#  'Pembroke': {'vrai positif': 933,
#   'faux positif': 248,
#   'precision': 0.790008467400508},
#  'Cardigan': {'vrai positif': 697,
#   'faux positif': 152,
#   'precision': 0.8209658421672555},
#  'toy_poodle': {'vrai positif': 610,
#   'faux positif': 399,
#   'precision': 0.6045589692765114},
#  'miniature_poodle': {'vrai positif': 397,
#   'faux positif': 389,
#   'precision': 0.5050890585241731},
#  'standard_poodle': {'vrai positif': 725,
#   'faux positif': 250,
#   'precision': 0.7435897435897436},
#  'Mexican_hairless': {'vrai positif': 932,
#   'faux positif': 40,
#   'precision': 0.9588477366255144},
#  'dingo': {'vrai positif': 819,
#   'faux positif': 142,
#   'precision': 0.8522372528616025},
#  'dhole': {'vrai positif': 807,
#   'faux positif': 49,
#   'precision': 0.9427570093457944},
#  'African_hunting_dog': {'vrai positif': 1005,
#   'faux positif': 24,
#   'precision': 0.9766763848396501}}

# %% [markdown]
# Evaluation du modèle sur les données de test

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 6s 180ms/step - loss: 0.3931 - categorical_accuracy: 0.8654
# [0.39309847354888916, 0.8653667569160461]

# %% [markdown]
# Coubes permettant de voir l'évolution de l'entrainement

# %%
def plot_accuracy(hist):
    plt.plot(hist.history['categorical_accuracy'])
    plt.plot(hist.history['val_categorical_accuracy'])
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
def plot_loss(hist):
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.show()

plot_accuracy(history)
plot_loss(history)

# %% [markdown]
# Maintenant on passe au fine tunning du modèle

# %% [markdown]
# Nombre de variable de base entrainable par le modèle

# %%
len(model.trainable_variables)
print(len(model.variables))
print(len(model.trainable_variables))
print(len(base_model.variables))
print(len(base_model.trainable_variables))
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# 548
# 346
# 542
# 342
# Number of layers in the base model:  377

# %% [markdown]
# On fait passer les 15 dernières couches en entrainable, le nombre de variable augmente

# %%
for layer in model.layers[-15:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
        
len(model.trainable_variables)
# Out:
# 346

# %% [markdown]
# On recompile le modèle avec ces nouveaux paramètre et on met un ratio d'apprentissage faible pour éviter le sur apprentissage

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0000075),
    loss=keras.losses.CategoricalCrossentropy(),
    metrics=[keras.metrics.CategoricalAccuracy()]
)

# %% [markdown]
# on diminue le nombre d'époque dans un même soucis de sur apprentissage

# %%
EPOCHS = history.epoch[-1] + 5

history_finetunning = model.fit(
    train_dataset, 
    epochs=EPOCHS, 
    initial_epoch=history.epoch[-1],
    validation_data=validation_dataset, 
    verbose=1,
    callbacks =[metrics]
)
# Out:
# Epoch 24/28
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 2023-03-12 02:36:51.371734: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.372064: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.401561: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.401597: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.781718: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.781776: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.995586: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:51.995645: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:52.017063: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-03-12 02:36:52.017098: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 449/449 [==============================] - 500s 1s/step - loss: 1.2820 - categorical_accuracy: 0.6571 - val_loss: 0.5292 - val_categorical_accuracy: 0.8380
# Epoch 25/28
# 449/449 [==============================] - 461s 1s/step - loss: 1.1451 - categorical_accuracy: 0.6820 - val_loss: 0.5223 - val_categorical_accuracy: 0.8380
# Epoch 26/28
# 449/449 [==============================] - 462s 1s/step - loss: 1.0989 - categorical_accuracy: 0.6935 - val_loss: 0.5506 - val_categorical_accuracy: 0.8326
# Epoch 27/28
# 449/449 [==============================] - 463s 1s/step - loss: 1.0400 - categorical_accuracy: 0.7057 - val_loss: 0.5534 - val_categorical_accuracy: 0.8291
# Epoch 28/28
# 449/449 [==============================] - 463s 1s/step - loss: 0.9828 - categorical_accuracy: 0.7161 - val_loss: 0.5281 - val_categorical_accuracy: 0.8405

# %% [markdown]
# On regarde la précision par races

# %%
metrics.get_data()
# Out:
# {'Chihuahua': {'vrai positif': 159,
#   'faux positif': 43,
#   'precision': 0.7871287128712872},
#  'Japanese_spaniel': {'vrai positif': 212,
#   'faux positif': 43,
#   'precision': 0.8313725490196079},
#  'Maltese_dog': {'vrai positif': 281,
#   'faux positif': 43,
#   'precision': 0.8672839506172839},
#  'Pekinese': {'vrai positif': 156,
#   'faux positif': 22,
#   'precision': 0.8764044943820225},
#  'Shih': {'vrai positif': 229,
#   'faux positif': 77,
#   'precision': 0.7483660130718954},
#  'Blenheim_spaniel': {'vrai positif': 217,
#   'faux positif': 16,
#   'precision': 0.9313304721030042},
#  'papillon': {'vrai positif': 239,
#   'faux positif': 24,
#   'precision': 0.908745247148289},
#  'toy_terrier': {'vrai positif': 162,
#   'faux positif': 30,
#   'precision': 0.84375},
#  'Rhodesian_ridgeback': {'vrai positif': 185,
#   'faux positif': 93,
#   'precision': 0.6654676258992805},
#  'Afghan_hound': {'vrai positif': 283,
#   'faux positif': 13,
#   'precision': 0.956081081081081},
#  'basset': {'vrai positif': 184,
#   'faux positif': 38,
#   'precision': 0.8288288288288288},
#  'beagle': {'vrai positif': 209,
#   'faux positif': 75,
#   'precision': 0.7359154929577465},
#  'bloodhound': {'vrai positif': 215,
#   'faux positif': 16,
#   'precision': 0.9307359307359307},
#  'bluetick': {'vrai positif': 204,
#   'faux positif': 21,
#   'precision': 0.9066666666666666},
#  'black': {'vrai positif': 173,
#   'faux positif': 43,
#   'precision': 0.8009259259259259},
#  'Walker_hound': {'vrai positif': 99,
#   'faux positif': 65,
#   'precision': 0.6036585365853658},
#  'English_foxhound': {'vrai positif': 126,
#   'faux positif': 78,
#   'precision': 0.6176470588235294},
#  'redbone': {'vrai positif': 128,
#   'faux positif': 29,
#   'precision': 0.8152866242038217},
#  'borzoi': {'vrai positif': 175,
#   'faux positif': 4,
#   'precision': 0.9776536312849162},
#  'Irish_wolfhound': {'vrai positif': 191,
#   'faux positif': 55,
#   'precision': 0.7764227642276422},
#  'Italian_greyhound': {'vrai positif': 174,
#   'faux positif': 53,
#   'precision': 0.7665198237885462},
#  'whippet': {'vrai positif': 163,
#   'faux positif': 33,
#   'precision': 0.8316326530612245},
#  'Ibizan_hound': {'vrai positif': 219,
#   'faux positif': 14,
#   'precision': 0.9399141630901288},
#  'Norwegian_elkhound': {'vrai positif': 239,
#   'faux positif': 23,
#   'precision': 0.9122137404580153},
#  'otterhound': {'vrai positif': 143,
#   'faux positif': 32,
#   'precision': 0.8171428571428572},
#  'Saluki': {'vrai positif': 225,
#   'faux positif': 9,
#   'precision': 0.9615384615384616},
#  'Scottish_deerhound': {'vrai positif': 248,
#   'faux positif': 73,
#   'precision': 0.7725856697819314},
#  'Weimaraner': {'vrai positif': 194,
#   'faux positif': 50,
#   'precision': 0.7950819672131147},
#  'Staffordshire_bullterrier': {'vrai positif': 120,
#   'faux positif': 68,
#   'precision': 0.6382978723404256},
#  'American_Staffordshire_terrier': {'vrai positif': 114,
#   'faux positif': 87,
#   'precision': 0.5671641791044776},
#  'Bedlington_terrier': {'vrai positif': 215,
#   'faux positif': 14,
#   'precision': 0.9388646288209607},
#  'Border_terrier': {'vrai positif': 203,
#   'faux positif': 12,
#   'precision': 0.9441860465116279},
#  'Kerry_blue_terrier': {'vrai positif': 211,
#   'faux positif': 10,
#   'precision': 0.9547511312217195},
#  'Irish_terrier': {'vrai positif': 164,
#   'faux positif': 21,
#   'precision': 0.8864864864864865},
#  'Norfolk_terrier': {'vrai positif': 146,
#   'faux positif': 41,
#   'precision': 0.7807486631016043},
#  'Norwich_terrier': {'vrai positif': 194,
#   'faux positif': 44,
#   'precision': 0.8151260504201681},
#  'Yorkshire_terrier': {'vrai positif': 130,
#   'faux positif': 35,
#   'precision': 0.7878787878787878},
#  'wire': {'vrai positif': 148,
#   'faux positif': 18,
#   'precision': 0.891566265060241},
#  'Lakeland_terrier': {'vrai positif': 185,
#   'faux positif': 47,
#   'precision': 0.7974137931034483},
#  'Sealyham_terrier': {'vrai positif': 238,
#   'faux positif': 21,
#   'precision': 0.918918918918919},
#  'Airedale': {'vrai positif': 222,
#   'faux positif': 49,
#   'precision': 0.8191881918819188},
#  'cairn': {'vrai positif': 223,
#   'faux positif': 75,
#   'precision': 0.7483221476510067},
#  'Australian_terrier': {'vrai positif': 184,
#   'faux positif': 96,
#   'precision': 0.6571428571428571},
#  'Dandie_Dinmont': {'vrai positif': 204,
#   'faux positif': 22,
#   'precision': 0.9026548672566371},
#  'Boston_bull': {'vrai positif': 213,
#   'faux positif': 47,
#   'precision': 0.8192307692307692},
#  'miniature_schnauzer': {'vrai positif': 160,
#   'faux positif': 52,
#   'precision': 0.7547169811320755},
#  'giant_schnauzer': {'vrai positif': 167,
#   'faux positif': 64,
#   'precision': 0.7229437229437229},
#  'standard_schnauzer': {'vrai positif': 123,
#   'faux positif': 44,
#   'precision': 0.7365269461077845},
#  'Scotch_terrier': {'vrai positif': 179,
#   'faux positif': 52,
#   'precision': 0.7748917748917749},
#  'Tibetan_terrier': {'vrai positif': 210,
#   'faux positif': 46,
#   'precision': 0.8203125},
#  'silky_terrier': {'vrai positif': 136,
#   'faux positif': 59,
#   'precision': 0.6974358974358974},
#  'soft': {'vrai positif': 159,
#   'faux positif': 12,
#   'precision': 0.9298245614035088},
#  'West_Highland_white_terrier': {'vrai positif': 202,
#   'faux positif': 70,
#   'precision': 0.7426470588235294},
#  'Lhasa': {'vrai positif': 152,
#   'faux positif': 21,
#   'precision': 0.8786127167630058},
#  'flat': {'vrai positif': 170,
#   'faux positif': 27,
#   'precision': 0.8629441624365483},
#  'curly': {'vrai positif': 169,
#   'faux positif': 26,
#   'precision': 0.8666666666666667},
#  'golden_retriever': {'vrai positif': 163,
#   'faux positif': 22,
#   'precision': 0.8810810810810811},
#  'Labrador_retriever': {'vrai positif': 189,
#   'faux positif': 60,
#   'precision': 0.7590361445783133},
#  'Chesapeake_Bay_retriever': {'vrai positif': 178,
#   'faux positif': 19,
#   'precision': 0.9035532994923858},
#  'German_short': {'vrai positif': 163,
#   'faux positif': 9,
#   'precision': 0.9476744186046512},
#  'vizsla': {'vrai positif': 164,
#   'faux positif': 22,
#   'precision': 0.8817204301075269},
#  'English_setter': {'vrai positif': 184,
#   'faux positif': 18,
#   'precision': 0.9108910891089109},
#  'Irish_setter': {'vrai positif': 183,
#   'faux positif': 9,
#   'precision': 0.953125},
#  'Gordon_setter': {'vrai positif': 166,
#   'faux positif': 5,
#   'precision': 0.9707602339181286},
#  'Brittany_spaniel': {'vrai positif': 150,
#   'faux positif': 24,
#   'precision': 0.8620689655172413},
#  'clumber': {'vrai positif': 168,
#   'faux positif': 1,
#   'precision': 0.9940828402366864},
#  'English_springer': {'vrai positif': 175,
#   'faux positif': 38,
#   'precision': 0.8215962441314554},
#  'Welsh_springer_spaniel': {'vrai positif': 153,
#   'faux positif': 31,
#   'precision': 0.8315217391304348},
#  'cocker_spaniel': {'vrai positif': 171,
#   'faux positif': 30,
#   'precision': 0.8507462686567164},
#  'Sussex_spaniel': {'vrai positif': 184,
#   'faux positif': 5,
#   'precision': 0.9735449735449735},
#  'Irish_water_spaniel': {'vrai positif': 149,
#   'faux positif': 1,
#   'precision': 0.9933333333333333},
#  'kuvasz': {'vrai positif': 139,
#   'faux positif': 10,
#   'precision': 0.9328859060402684},
#  'schipperke': {'vrai positif': 174,
#   'faux positif': 23,
#   'precision': 0.883248730964467},
#  'groenendael': {'vrai positif': 176,
#   'faux positif': 14,
#   'precision': 0.9263157894736842},
#  'malinois': {'vrai positif': 168,
#   'faux positif': 12,
#   'precision': 0.9333333333333333},
#  'briard': {'vrai positif': 162,
#   'faux positif': 43,
#   'precision': 0.7902439024390244},
#  'kelpie': {'vrai positif': 149,
#   'faux positif': 35,
#   'precision': 0.8097826086956522},
#  'komondor': {'vrai positif': 181,
#   'faux positif': 8,
#   'precision': 0.9576719576719577},
#  'Old_English_sheepdog': {'vrai positif': 206,
#   'faux positif': 71,
#   'precision': 0.7436823104693141},
#  'Shetland_sheepdog': {'vrai positif': 165,
#   'faux positif': 33,
#   'precision': 0.8333333333333334},
#  'collie': {'vrai positif': 98, 'faux positif': 42, 'precision': 0.7},
#  'Border_collie': {'vrai positif': 146,
#   'faux positif': 67,
#   'precision': 0.6854460093896714},
#  'Bouvier_des_Flandres': {'vrai positif': 145,
#   'faux positif': 22,
#   'precision': 0.8682634730538922},
#  'Rottweiler': {'vrai positif': 168,
#   'faux positif': 5,
#   'precision': 0.9710982658959537},
#  'German_shepherd': {'vrai positif': 164,
#   'faux positif': 19,
#   'precision': 0.8961748633879781},
#  'Doberman': {'vrai positif': 149,
#   'faux positif': 15,
#   'precision': 0.9085365853658537},
#  'miniature_pinscher': {'vrai positif': 214,
#   'faux positif': 76,
#   'precision': 0.7379310344827587},
#  'Greater_Swiss_Mountain_dog': {'vrai positif': 162,
#   'faux positif': 39,
#   'precision': 0.8059701492537313},
#  'Bernese_mountain_dog': {'vrai positif': 262,
#   'faux positif': 35,
#   'precision': 0.8821548821548821},
#  'Appenzeller': {'vrai positif': 108,
#   'faux positif': 26,
#   'precision': 0.8059701492537313},
#  'EntleBucher': {'vrai positif': 220,
#   'faux positif': 94,
#   'precision': 0.7006369426751592},
#  'boxer': {'vrai positif': 136,
#   'faux positif': 28,
#   'precision': 0.8292682926829268},
#  'bull_mastiff': {'vrai positif': 181,
#   'faux positif': 48,
#   'precision': 0.7903930131004366},
#  'Tibetan_mastiff': {'vrai positif': 158,
#   'faux positif': 19,
#   'precision': 0.8926553672316384},
#  'French_bulldog': {'vrai positif': 174,
#   'faux positif': 36,
#   'precision': 0.8285714285714286},
#  'Great_Dane': {'vrai positif': 136,
#   'faux positif': 1,
#   'precision': 0.9927007299270073},
#  'Saint_Bernard': {'vrai positif': 209, 'faux positif': 0, 'precision': 1.0},
#  'Eskimo_dog': {'vrai positif': 91,
#   'faux positif': 137,
#   'precision': 0.3991228070175439},
#  'malamute': {'vrai positif': 169,
#   'faux positif': 60,
#   'precision': 0.7379912663755459},
#  'Siberian_husky': {'vrai positif': 111,
#   'faux positif': 72,
#   'precision': 0.6065573770491803},
#  'affenpinscher': {'vrai positif': 165,
#   'faux positif': 52,
#   'precision': 0.7603686635944701},
#  'basenji': {'vrai positif': 236,
#   'faux positif': 19,
#   'precision': 0.9254901960784314},
#  'pug': {'vrai positif': 220,
#   'faux positif': 25,
#   'precision': 0.8979591836734694},
#  'Leonberg': {'vrai positif': 254,
#   'faux positif': 8,
#   'precision': 0.9694656488549618},
#  'Newfoundland': {'vrai positif': 209,
#   'faux positif': 30,
#   'precision': 0.8744769874476988},
#  'Great_Pyrenees': {'vrai positif': 246,
#   'faux positif': 68,
#   'precision': 0.7834394904458599},
#  'Samoyed': {'vrai positif': 269,
#   'faux positif': 20,
#   'precision': 0.9307958477508651},
#  'Pomeranian': {'vrai positif': 244,
#   'faux positif': 8,
#   'precision': 0.9682539682539683},
#  'chow': {'vrai positif': 228, 'faux positif': 0, 'precision': 1.0},
#  'keeshond': {'vrai positif': 200,
#   'faux positif': 6,
#   'precision': 0.970873786407767},
#  'Brabancon_griffon': {'vrai positif': 166,
#   'faux positif': 6,
#   'precision': 0.9651162790697675},
#  'Pembroke': {'vrai positif': 208,
#   'faux positif': 49,
#   'precision': 0.8093385214007782},
#  'Cardigan': {'vrai positif': 138,
#   'faux positif': 15,
#   'precision': 0.9019607843137255},
#  'toy_poodle': {'vrai positif': 133,
#   'faux positif': 99,
#   'precision': 0.5732758620689655},
#  'miniature_poodle': {'vrai positif': 73,
#   'faux positif': 66,
#   'precision': 0.5251798561151079},
#  'standard_poodle': {'vrai positif': 149,
#   'faux positif': 41,
#   'precision': 0.7842105263157895},
#  'Mexican_hairless': {'vrai positif': 190,
#   'faux positif': 10,
#   'precision': 0.95},
#  'dingo': {'vrai positif': 167,
#   'faux positif': 17,
#   'precision': 0.907608695652174},
#  'dhole': {'vrai positif': 170,
#   'faux positif': 7,
#   'precision': 0.96045197740113},
#  'African_hunting_dog': {'vrai positif': 210,
#   'faux positif': 6,
#   'precision': 0.9722222222222222}}

# %% [markdown]
# On évalue le modèle

# %%
model.evaluate(test_dataset)
# Out:
# 34/34 [==============================] - 5s 151ms/step - loss: 0.4055 - categorical_accuracy: 0.8728
# [0.40546759963035583, 0.8727948069572449]

# %% [markdown]
# On affiche les courbes résultat du finetunning

# %%
def plot_accuracy_fine(hist, hist_fine):
    train_histo = hist.history['categorical_accuracy'] + hist_fine.history['categorical_accuracy']
    validation_histo = hist.history['val_categorical_accuracy'] + hist_fine.history['val_categorical_accuracy']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.plot([history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning')
    plt.legend(['train', 'validation', 'start finetunnig'], loc='lower right')
    plt.show()
    
def plot_loss_fine(hist, hist_fine):
    train_histo = hist.history['loss'] + hist_fine.history['loss']
    validation_histo = hist.history['val_loss'] + hist_fine.history['val_loss']
    plt.plot(train_histo)
    plt.plot(validation_histo)
    plt.title('Categorical loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.plot(
        [history.epoch[-1],history.epoch[-1]],
          plt.ylim(), label='Start Fine Tuning'
    )
    plt.legend(['train', 'validation', 'start finetunnig'], loc='upper right')
    plt.show()
    
plot_accuracy_fine(history, history_finetunning)
plot_loss_fine(history, history_finetunning)

# %% [markdown]
# On va maintenant chercher à voir comment le modèle visualise les images

# %%
image = cv2.imread('tyson.jpg')
new_image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
plt.axis('off')
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# On fait une prediction sur l'image

# %%
img = np.expand_dims(cv2.resize(image,(IMG_SIZE, IMG_SIZE)), axis=0)
y_predict = np.asarray(model.predict(img, verbose=0))
pred = np.argmax(y_predict, axis=1)
print(dog_categories[pred[0]])
# Out:
# American_Staffordshire_terrier

# %% [markdown]
# On affiche les détails du modèle

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  resnet101v2 (Functional)    (None, 7, 7, 2048)        42626560
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 120)               245880
#
# =================================================================
# Total params: 42,880,632
# Trainable params: 42,778,872
# Non-trainable params: 101,760
# _________________________________________________________________

# %% [markdown]
# On visualise les filtres

# %%
def display_image_filtered(name_image,model,layer_name,image):
    inp= model.inputs 
    out1= model.get_layer(layer_name).output  
    feature_map_1= Model(inputs= inp, outputs= out1)  
    img=cv2.resize(image,(IMG_SIZE,IMG_SIZE))              
    input_img= np.expand_dims(img, axis=0)      
    f=feature_map_1.predict(input_img) 
    dim = f.shape[1]
    print(dim)
    print(f'{layer_name} | Features Shape: {f.shape}')
    
    fig= plt.figure(figsize=(30,30))
    
    if not os.path.exists(f'results_{name_image}'):
        os.makedirs(f'results_{name_image}')        
    for i in range(dim):
        ax = fig.add_subplot(int(dim), int(dim),i+1)
        ax.axis('off')
        ax.imshow(f[0,:,:,i], cmap='gray')
        # plt.imsave(f'results_{name_image}/{name_image}_{layer_name}_{i}.jpg',f[0,:,:,i])
        
display_image_filtered('test', base_model, f'conv2_block1_0_conv', new_image)
display_image_filtered('test', base_model, f'conv2_block2_1_conv', new_image)  
display_image_filtered('test', base_model, f'conv3_block1_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv4_block1_0_conv', new_image) 
display_image_filtered('test', base_model, f'conv4_block5_2_conv', new_image)  
display_image_filtered('test', base_model, f'conv5_block2_1_conv', new_image)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 56
# conv2_block1_0_conv | Features Shape: (1, 56, 56, 256)
# 1/1 [==============================] - 0s 92ms/step
# 56
# conv2_block2_1_conv | Features Shape: (1, 56, 56, 64)
# WARNING:tensorflow:5 out of the last 649 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa7dbe8cee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 148ms/step
# 28
# conv3_block1_2_conv | Features Shape: (1, 28, 28, 128)
# WARNING:tensorflow:6 out of the last 650 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa7dac2e8b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 220ms/step
# 14
# conv4_block1_0_conv | Features Shape: (1, 14, 14, 1024)
# 1/1 [==============================] - 0s 379ms/step
# 14
# conv4_block5_2_conv | Features Shape: (1, 14, 14, 256)
# 1/1 [==============================] - 1s 801ms/step
# 7
# conv5_block2_1_conv | Features Shape: (1, 7, 7, 512)

# %% [markdown]
# A faire : visualiser les features map optionnel

# %%
model.save('Modele_fine_v2.h5')
